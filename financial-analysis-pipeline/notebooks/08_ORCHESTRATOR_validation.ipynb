# %%
import sys
import os
sys.path.append(os.path.abspath(".."))  # point to project root

import pandas as pd
from orchestrator.orchestrator import run_full_analysis

financials = pd.read_csv("../data/cleaned/financial_statements.csv")
results = run_full_analysis(financials, client_config={})

# inspect results
results["tables"]["ratios"].head()
results["signals"]["trend"][:2]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       3 sys.path.append(os.path.abspath(".."))  # point to project root
#       5 import pandas as pd
# ----> 6 from orchestrator.orchestrator import run_full_analysis
#       8 financials = pd.read_csv("../data/cleaned/financial_statements.csv")
#       9 results = run_full_analysis(financials, client_config={})
#
# ImportError: cannot import name 'run_full_analysis' from 'orchestrator.orchestrator' (c:\Users\ADMIN\Documents\My Documents\MyDataAnalysis\Financial statement analysis\financial-analysis-pipeline\orchestrator\orchestrator.py)
