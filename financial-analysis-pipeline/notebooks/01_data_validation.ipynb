# %% [markdown]
# Cell 1 — Kernel & Version Check

# %%
import sys
print(sys.version)
# Out:
# 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]

# %% [markdown]
# Cell 2 — Imports

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# Cell 3 — Define Paths (AFAP Style)

# %%
RAW = Path("../data/raw")
CLEANED = Path("../data/cleaned")

# %% [markdown]
# Cell 4 — Load All Datasets

# %%
trial_balance = pd.read_csv(RAW / "trial_balance.csv")
account_mapping = pd.read_csv(RAW / "account_mapping.csv")

financials = pd.read_csv(CLEANED / "financial_statements.csv")
ratios_ref = pd.read_csv(CLEANED / "ratios_reference.csv")

# %% [markdown]
# Cell 5 — Quick Structural Checks (No Logic)

# %%
trial_balance.head()

financials.head()

ratios_ref.head()
# Out:
#                   Company  Year  Current Ratio  Gross Margin  Debt/Equity  \
# 0  Acme Manufacturing Ltd  2020       1.587642      0.867371     0.072627
# 1  Acme Manufacturing Ltd  2021       3.079486      0.854884     0.432276
# 2  Acme Manufacturing Ltd  2022       3.410933      0.968294     0.094384
# 3  Acme Manufacturing Ltd  2023       4.672886      0.771416     1.006217
# 4        Banyan Retail Co  2020       2.513537      0.757082     0.531476
#
#    Net Margin
# 0   -1.546148
# 1   -0.787051
# 2    0.301875
# 3    0.182190
# 4    0.180853

# %% [markdown]
# Cell 6 — Sanity Assertions

# %%
assert trial_balance.shape[0] > 0
assert financials.shape[0] > 0

assert "Company" in financials.columns
assert "Year" in financials.columns
