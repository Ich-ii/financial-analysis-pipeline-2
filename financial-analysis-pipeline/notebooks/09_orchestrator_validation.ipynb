# %% [markdown]
# # AFAP Orchestrator Validation Notebook
# ## Profile-by-Profile Simulation & Contract Assurance
#
# ### Purpose
# This notebook validates the AFAP orchestrator across all supported
# Analysis Interpretation Frameworks (AIFs).
#
# Each profile is treated as an **independent client case**, ensuring:
# - Correct engine selection
# - Stable output contracts
# - Profile-aware AI interpretation
# - Reproducible, auditable execution
#
# This notebook is intentionally structured to support:
# - Engineering validation
# - Audit defensibility
# - Investor / stakeholder review

# %%
# ---------------------------------------------------------------
# Environment setup
# ---------------------------------------------------------------

import sys
import os
import pandas as pd
from pprint import pprint

# Ensure project root is on PYTHONPATH
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print("Project root resolved to:", PROJECT_ROOT)
# Out:
# Project root resolved to: c:\Users\ADMIN\Documents\My Documents\MyDataAnalysis\Financial statement analysis\financial-analysis-pipeline

# %% [markdown]
# ### Step 1: Import AFAP Orchestrator & Frozen Contracts
#
# This cell imports:
# - The AFAP orchestrator
# - The frozen output contract
# - All supported analysis profiles
#
# These are treated as **non-negotiable system interfaces**.

# %%
from orchestrator.orchestrator import (
    afap_run,
    ANALYSIS_PROFILES,
    AFAP_OUTPUT_KEYS
)

pprint(ANALYSIS_PROFILES)
# Out:
# {'full_diagnostic': {'engines': ['ratio',
#                                  'trend',
#                                  'cash_flow',
#                                  'anomaly',
#                                  'solvency',
#                                  'composite_risk'],
#                      'metrics_scope': 'all'},
#  'going_concern_screen': {'engines': ['ratio',
#                                       'trend',
#                                       'solvency',
#                                       'composite_risk'],
#                           'metrics_scope': 'critical_only'},
#  'liquidity_focus': {'engines': ['ratio',
#                                  'trend',
#                                  'cash_flow',
#                                  'composite_risk'],
#                      'metrics_scope': ['current_ratio',
#                                        'quick_ratio',
#                                        'cash_ratio']},
#  'performance_focus': {'engines': ['ratio', 'trend'],
#                        'metrics_scope': ['operating_margin',
#                                          'net_margin',
#                                          'asset_turnover']},
#  'risk_scan': {'engines': ['ratio', 'solvency', 'anomaly', 'composite_risk'],
#                'metrics_scope': 'all'},
#  'solvency_focus': {'engines': ['ratio', 'solvency', 'composite_risk'],
#                     'metrics_scope': ['debt_to_equity',
#                                       'interest_coverage',
#                                       'equity_ratio']}}

# %% [markdown]
# ### Step 2: Load Financial Statements
#
# This dataset simulates a **single recurring client**
# across multiple years, allowing trend and risk analysis.

# %%
financials_df = pd.read_csv("../data/cleaned/financial_statements.csv")
financials_df.head()
# Out:
#                   Company  Year FS Category      FS Subcategory  \
# 0  Acme Manufacturing Ltd  2020      Assets      Current Assets
# 1  Acme Manufacturing Ltd  2020      Assets  Non-Current Assets
# 2  Acme Manufacturing Ltd  2020      Equity              Equity
# 3  Acme Manufacturing Ltd  2020    Expenses                COGS
# 4  Acme Manufacturing Ltd  2020    Expenses       Finance Costs
#
#           Statement   Amount
# 0     Balance Sheet  3109667
# 1     Balance Sheet   905812
# 2     Balance Sheet  2152630
# 3  Income Statement   373114
# 4  Income Statement  2929304

# %% [markdown]
# ### Step 3: Define Validation Functions
#
# These validators ensure:
# - Output contract integrity
# - AI interpretation structural consistency
#
# They deliberately avoid business logic
# and only validate **system correctness**.

# %%
def validate_output_contract(outputs: dict):
    """
    Ensures all required AFAP output keys are present.
    """
    missing = set(AFAP_OUTPUT_KEYS) - set(outputs.keys())
    assert not missing, f"Missing output keys: {missing}"


def validate_ai_interpretation(ai_output):
    """
    Validates AI interpretation structure (schema-level).
    """
    assert isinstance(ai_output, list)
    assert len(ai_output) > 0

    for rec in ai_output:
        assert "Company" in rec
        assert "Year" in rec
        assert "interpretation" in rec

# %% [markdown]
# ### Step 4: Define Independent Client Analysis Cases
#
# Each profile below represents a **realistic engagement scenario**:
# - Targeted diagnostics
# - Focused decision support
# - Reduced computational scope
#
# Each will be run **independently**.

# %%
CLIENT_CASES = [
    "full_diagnostic",
    "solvency_focus",
    "liquidity_focus",
    "performance_focus",
    "risk_scan",
    "going_concern_screen"
]

# %% [markdown]
# ## Step 5: Execute a Single AFAP Profile (Case Simulation)
#
# This cell is the **canonical execution pattern**.
# It will be reused for every profile.
#
# We:
# 1. Run the orchestrator
# 2. Validate the output contract
# 3. Validate AI interpretation
# 4. Inspect executed engines
# 5. Review sample outputs

# %%
# Select profile to simulate
profile_name = "solvency_focus"

print(f"\n--- Running AFAP Case: {profile_name} ---")

outputs = afap_run(
    financials_df=financials_df,
    analysis_profile=profile_name,
    use_mock_ai=False  # toggle True for fast dry-runs
)

# --- Contract validation ---
validate_output_contract(outputs)
print("✅ Output contract validated")

# --- AI validation ---
validate_ai_interpretation(outputs["ai_interpretation"])
print("✅ AI interpretation structure validated")

# --- Inspect executed engines ---
engines_ran = [
    k for k in AFAP_OUTPUT_KEYS
    if k in outputs and outputs[k]
]

print("Engines executed:", engines_ran)
# Out:
# --- Running AFAP Case: solvency_focus ---
# ✅ ratio_engine output validated successfully.
# ✅ solvency_engine output validated successfully.
# ✅ Output contract validated
# ✅ AI interpretation structure validated
# Engines executed: ['profile_used', 'ratios', 'solvency', 'ai_interpretation']

# %%
outputs
# Out:
# {'ratios': [{'engine': 'ratio_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2020,
#    'metrics': {'current_ratio': np.float64(1.5876421245028514),
#     'quick_ratio': np.float64(1.5876421245028514),
#     'gross_margin': np.float64(0.8673714331416791),
#     'operating_margin': np.float64(0.28910663029085837),
#     'net_margin': np.float64(-1.5461482817762533),
#     'debt_equity': np.float64(0.9825237035626188),
#     'interest_coverage': np.float64(0.2776502541217982),
#     'asset_turnover': np.float64(0.7005951220265378),
#     'roa': np.float64(-1.0832239441421558),
#     'roe': np.float64(-2.020627325643515)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2021,
#    'metrics': {'current_ratio': np.float64(3.0794864428132476),
#     'quick_ratio': np.float64(3.0794864428132476),
#     'gross_margin': np.float64(0.8548843465641977),
#     'operating_margin': np.float64(0.21215872425920793),
#     'net_margin': np.float64(-0.7870506702278115),
#     'debt_equity': np.float64(1.3584280927054282),
#     'interest_coverage': np.float64(0.38882463675949536),
#     'asset_turnover': np.float64(0.7721640230460904),
#     'roa': np.float64(-0.6077322118642288),
#     'roe': np.float64(-2.1321761290705408)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2022,
#    'metrics': {'current_ratio': np.float64(3.4109333800409956),
#     'quick_ratio': np.float64(3.4109333800409956),
#     'gross_margin': np.float64(0.9682938776163919),
#     'operating_margin': np.float64(0.6803346187657713),
#     'net_margin': np.float64(0.30187505116222785),
#     'debt_equity': np.float64(0.6969581313037093),
#     'interest_coverage': np.float64(2.4466303752204883),
#     'asset_turnover': np.float64(1.9903341261309764),
#     'roa': np.float64(0.6008322161557166),
#     'roe': np.float64(1.5484389021911336)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2023,
#    'metrics': {'current_ratio': np.float64(4.67288599769455),
#     'quick_ratio': np.float64(4.67288599769455),
#     'gross_margin': np.float64(0.7714157526645563),
#     'operating_margin': np.float64(0.5105960440756842),
#     'net_margin': np.float64(0.18219037429368373),
#     'debt_equity': np.float64(1.4765422770808412),
#     'interest_coverage': np.float64(2.003210910410521),
#     'asset_turnover': np.float64(1.9655580591753654),
#     'roa': np.float64(0.3581057584971264),
#     'roe': np.float64(1.1372509883115411)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2020,
#    'metrics': {'current_ratio': np.float64(2.513537113097586),
#     'quick_ratio': np.float64(2.513537113097586),
#     'gross_margin': np.float64(0.7570815081561904),
#     'operating_margin': np.float64(0.6320364408373867),
#     'net_margin': np.float64(0.1808532960683669),
#     'debt_equity': np.float64(1.0475669775251273),
#     'interest_coverage': np.float64(2.0234432912631317),
#     'asset_turnover': np.float64(3.234804131397151),
#     'roa': np.float64(0.5850249892987454),
#     'roe': np.float64(0.7964040393138676)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2021,
#    'metrics': {'current_ratio': np.float64(1.705065795230575),
#     'quick_ratio': np.float64(1.705065795230575),
#     'gross_margin': np.float64(0.036190131992312705),
#     'operating_margin': np.float64(-0.645849592470911),
#     'net_margin': np.float64(-1.4828070712439492),
#     'debt_equity': np.float64(1.489352259975552),
#     'interest_coverage': np.float64(-1.3247712442403285),
#     'asset_turnover': np.float64(0.6247211597221303),
#     'roa': np.float64(-0.9263409531916953),
#     'roe': np.float64(-2.149827600380422)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2022,
#    'metrics': {'current_ratio': np.float64(2.8880221437700584),
#     'quick_ratio': np.float64(2.8880221437700584),
#     'gross_margin': np.float64(0.46355089147479067),
#     'operating_margin': np.float64(-0.7773550310153549),
#     'net_margin': np.float64(-2.844341904355056),
#     'debt_equity': np.float64(1.145902657513021),
#     'interest_coverage': np.float64(-0.5798847289076459),
#     'asset_turnover': np.float64(0.35425196482946286),
#     'roa': np.float64(-1.0076137082645549),
#     'roe': np.float64(-2.4682502584760235)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2023,
#    'metrics': {'current_ratio': np.float64(4.923702527898028),
#     'quick_ratio': np.float64(4.923702527898028),
#     'gross_margin': np.float64(-0.11390166943340603),
#     'operating_margin': np.float64(-0.41496528435997965),
#     'net_margin': np.float64(-1.5468585844806295),
#     'debt_equity': np.float64(0.9426738069314495),
#     'interest_coverage': np.float64(-0.3848879737836593),
#     'asset_turnover': np.float64(0.38154533353184256),
#     'roa': np.float64(-0.5901966745422557),
#     'roe': np.float64(-1.7612566839121644)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2020,
#    'metrics': {'current_ratio': np.float64(2.6595517030991243),
#     'quick_ratio': np.float64(2.6595517030991243),
#     'gross_margin': np.float64(0.7615568333804935),
#     'operating_margin': np.float64(0.5005495913726487),
#     'net_margin': np.float64(0.1743594460892191),
#     'debt_equity': np.float64(0.9334139689971799),
#     'interest_coverage': np.float64(1.7170438831816865),
#     'asset_turnover': np.float64(0.982691925376737),
#     'roa': np.float64(0.17134161978503612),
#     'roe': np.float64(0.43850881020066296)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2021,
#    'metrics': {'current_ratio': np.float64(0.561032784219196),
#     'quick_ratio': np.float64(0.561032784219196),
#     'gross_margin': np.float64(0.9458410901437198),
#     'operating_margin': np.float64(0.5649557985018869),
#     'net_margin': np.float64(-0.04403853116841385),
#     'debt_equity': np.float64(1.0512095331783222),
#     'interest_coverage': np.float64(1.9469377656975635),
#     'asset_turnover': np.float64(2.9958220772873867),
#     'roa': np.float64(-0.1319316039256429),
#     'roe': np.float64(-0.10333263434460556)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2022,
#    'metrics': {'current_ratio': np.float64(1.497355441654077),
#     'quick_ratio': np.float64(1.497355441654077),
#     'gross_margin': np.float64(0.6689321263372527),
#     'operating_margin': np.float64(-0.04577331706518147),
#     'net_margin': np.float64(-0.43930163886447265),
#     'debt_equity': np.float64(9.052038324909445),
#     'interest_coverage': np.float64(-0.2615676420299185),
#     'asset_turnover': np.float64(1.1311255947841239),
#     'roa': np.float64(-0.496905327550217),
#     'roe': np.float64(-6.333509146352113)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2023,
#    'metrics': {'current_ratio': np.float64(2.820819828360691),
#     'quick_ratio': np.float64(2.820819828360691),
#     'gross_margin': np.float64(0.2183365393189722),
#     'operating_margin': np.float64(-0.05100050814518515),
#     'net_margin': np.float64(-1.0075802805697454),
#     'debt_equity': np.float64(0.6654615509665709),
#     'interest_coverage': np.float64(-0.13251534735104648),
#     'asset_turnover': np.float64(0.7573690860405826),
#     'roa': np.float64(-0.7631101562076219),
#     'roe': np.float64(-1.3711091199201195)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2020,
#    'metrics': {'current_ratio': np.float64(0.9865731878822),
#     'quick_ratio': np.float64(0.9865731878822),
#     'gross_margin': np.float64(0.48323157541916334),
#     'operating_margin': np.float64(0.26659873471846185),
#     'net_margin': np.float64(-0.08069130977892434),
#     'debt_equity': np.float64(2.3412518134993867),
#     'interest_coverage': np.float64(2.1728832068686335),
#     'asset_turnover': np.float64(1.1769195025013348),
#     'roa': np.float64(-0.09496717616119273),
#     'roe': np.float64(-0.2871865477026018)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2021,
#    'metrics': {'current_ratio': np.float64(0.26879146143204413),
#     'quick_ratio': np.float64(0.26879146143204413),
#     'gross_margin': np.float64(-0.10620507243479971),
#     'operating_margin': np.float64(-0.7397205567652724),
#     'net_margin': np.float64(-2.11117805572711),
#     'debt_equity': np.float64(1.2932004023982646),
#     'interest_coverage': np.float64(-0.6429647536528281),
#     'asset_turnover': np.float64(1.1501651976694978),
#     'roa': np.float64(-2.428203525780877),
#     'roe': np.float64(-2.3442004418046682)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2022,
#    'metrics': {'current_ratio': np.float64(3.984205868573114),
#     'quick_ratio': np.float64(3.984205868573114),
#     'gross_margin': np.float64(0.7304995383252916),
#     'operating_margin': np.float64(0.4703583867876457),
#     'net_margin': np.float64(-0.09334803982215213),
#     'debt_equity': np.float64(1.1926658130896073),
#     'interest_coverage': np.float64(2.9276479739936097),
#     'asset_turnover': np.float64(1.6391282858217209),
#     'roa': np.float64(-0.15300941249850197),
#     'roe': np.float64(-0.6394616910210652)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2023,
#    'metrics': {'current_ratio': np.float64(0.6057853424475104),
#     'quick_ratio': np.float64(0.6057853424475104),
#     'gross_margin': np.float64(0.8045170831549584),
#     'operating_margin': np.float64(0.6851559001305129),
#     'net_margin': np.float64(-0.03111315263977513),
#     'debt_equity': np.float64(2.129646453152001),
#     'interest_coverage': np.float64(2.1585751198589107),
#     'asset_turnover': np.float64(3.7809784354566274),
#     'roa': np.float64(-0.11763815919006021),
#     'roe': np.float64(-0.14313859119660216)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'}],
#  'trend': [],
#  'cash_flow': [],
#  'anomaly': [],
#  'solvency': [{'engine': 'solvency_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2020,
#    'metrics': {'debt_equity': 0.9825237035626188,
#     'interest_coverage': 0.2776502541217982},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2021,
#    'metrics': {'debt_equity': 1.3584280927054282,
#     'interest_coverage': 0.38882463675949536},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2022,
#    'metrics': {'debt_equity': 0.6969581313037093,
#     'interest_coverage': 2.4466303752204883},
#    'flags': {'high_leverage': False, 'weak_coverage': False},
#    'severity': 'stable',
#    'explanation': 'Solvency position acceptable.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2023,
#    'metrics': {'debt_equity': 1.4765422770808412,
#     'interest_coverage': 2.003210910410521},
#    'flags': {'high_leverage': False, 'weak_coverage': False},
#    'severity': 'stable',
#    'explanation': 'Solvency position acceptable.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2020,
#    'metrics': {'debt_equity': 1.0475669775251273,
#     'interest_coverage': 2.0234432912631317},
#    'flags': {'high_leverage': False, 'weak_coverage': False},
#    'severity': 'stable',
#    'explanation': 'Solvency position acceptable.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2021,
#    'metrics': {'debt_equity': 1.489352259975552,
#     'interest_coverage': -1.3247712442403285},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2022,
#    'metrics': {'debt_equity': 1.145902657513021,
#     'interest_coverage': -0.5798847289076459},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2023,
#    'metrics': {'debt_equity': 0.9426738069314495,
#     'interest_coverage': -0.3848879737836593},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2020,
#    'metrics': {'debt_equity': 0.9334139689971799,
#     'interest_coverage': 1.7170438831816865},
#    'flags': {'high_leverage': False, 'weak_coverage': False},
#    'severity': 'stable',
#    'explanation': 'Solvency position acceptable.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2021,
#    'metrics': {'debt_equity': 1.0512095331783222,
#     'interest_coverage': 1.9469377656975635},
#    'flags': {'high_leverage': False, 'weak_coverage': False},
#    'severity': 'stable',
#    'explanation': 'Solvency position acceptable.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2022,
#    'metrics': {'debt_equity': 9.052038324909445,
#     'interest_coverage': -0.2615676420299185},
#    'flags': {'high_leverage': True, 'weak_coverage': True},
#    'severity': 'action',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2023,
#    'metrics': {'debt_equity': 0.6654615509665709,
#     'interest_coverage': -0.13251534735104648},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2020,
#    'metrics': {'debt_equity': 2.3412518134993867,
#     'interest_coverage': 2.1728832068686335},
#    'flags': {'high_leverage': True, 'weak_coverage': False},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2021,
#    'metrics': {'debt_equity': 1.2932004023982646,
#     'interest_coverage': -0.6429647536528281},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2022,
#    'metrics': {'debt_equity': 1.1926658130896073,
#     'interest_coverage': 2.9276479739936097},
#    'flags': {'high_leverage': False, 'weak_coverage': False},
#    'severity': 'stable',
#    'explanation': 'Solvency position acceptable.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2023,
#    'metrics': {'debt_equity': 2.129646453152001,
#     'interest_coverage': 2.1585751198589107},
#    'flags': {'high_leverage': True, 'weak_coverage': False},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'}],
#  'composite_risk': [],
#  'ai_interpretation': [{'Company': 'Acme Manufacturing Ltd',
#    'Year': 2020,
#    'analysis_profile': None,
#    'interpretation': 'summary:\nAcme Manufacturing Ltd — 2020 solvency-focused summary. Current and quick ratios are 1.588 (equal values) indicating short-term liquidity marginally above a conservative 1.50 threshold. Gross margin (86.737%) and operating margin (28.911%) are materially positive and exceed conservative profitability thresholds. However, net margin is negative (−154.615%), return on assets (−108.322%) and return on equity (−202.063%) are substantially adverse. Debt-to-equity is 0.983 (approximately 0.98). Interest coverage is very low at 0.278, indicating operating income is insufficient to meet interest expense. Asset turnover is 0.701. Overall, liquidity at the current/current-asset level appears acceptable by conservative liquidity cut-offs, but solvency and profitability at the net and return levels are concerning given the negative net income and inadequate interest coverage.\n\nkey_risks:\n- Insufficient interest coverage: Interest coverage ratio 0.2777 is well below a conservative threshold of 1.0, indicating operating profit does not cover interest expense. This presents a near-term risk to debt service capacity.\n- Negative bottom-line profitability: Net margin (−1.546) reflects a loss after tax; negative ROA (−1.083) and ROE (−2.021) confirm that the company is destroying shareholder and asset value in 2020.\n- Leverage and refinancing risk: Debt-to-equity of 0.983, while below or near a conservative 1.0 threshold, combined with very low interest coverage increases refinancing and covenant breach risk if earnings do not improve.\n- Liquidity concentration risk: Although current and quick ratios (1.588) exceed a conservative 1.50 threshold, the margin above the threshold is narrow; any deterioration in receivables, inventory realizations, or cash flows could rapidly weaken short-term liquidity.\n- Operational cash-flow risk: The combination of positive gross and operating margins with a negative net margin suggests non-operating charges, interest expense or exceptional items materially reduced net income; if recurrent, these items threaten solvency.\n\nrecommendations:\n- Prioritize restoring interest coverage: negotiate interest terms, consider temporary interest relief, or reprofile debt maturities to reduce near-term interest burden.\n- Address sources of net loss: undertake a detailed expense and non-operating-charge review to identify and, where appropriate, reduce non-operating losses, extraordinary items, or tax effects contributing to the negative net margin.\n- Strengthen liquidity buffers: maintain or increase available cash and committed facilities to provide coverage below the current 1.588 current ratio buffer; implement tighter working-capital controls to protect quick assets.\n- Review capital structure alternatives: consider modest deleveraging where feasible or equity injections to improve coverage ratios and reduce refinancing risk, subject to creditor and shareholder analysis.\n- Implement covenant monitoring and contingency planning: establish early-warning triggers given low interest coverage and negative net income; prepare contingency financing and cost-reduction plans.\n\nconfidence_notes:\n- Analysis is based solely on the provided 2020 ratio values. No additional financial statements, notes, cash-flow details, or prior-year comparisons were available. Conclusions are therefore limited to the ratios supplied.\n- Conservative thresholds cited (current/quick 1.50, interest coverage 1.0) are applied for risk-identification purposes in this report; these thresholds are being used explicitly and may not reflect all stakeholders’ tolerances or contractual covenant definitions.\n- Recommendations are conditional and should be validated against full financial statements, cash-flow schedules, and lender covenants before execution.'},
#   {'Company': 'Acme Manufacturing Ltd',
#    'Year': 2021,
#    'analysis_profile': None,
#    'interpretation': 'summary:\nAcme Manufacturing Ltd — 2021. Liquidity measures are strong (current_ratio and quick_ratio ~3.08), and gross_margin is high (≈85%). However, profitability and solvency indicators show material concerns: net_margin is deeply negative (≈-78.7%), return on assets and equity are negative (ROA ≈-60.8%, ROE ≈-213.2%), debt/equity is elevated (≈1.36), and interest coverage is below 1 (≈0.39). These metrics indicate the company is generating losses despite adequate short-term liquidity and high gross margin; ability to service debt from operating earnings is weak.\n\nkey_risks:\n- Negative net profitability: net_margin = -0.7870506702278115. The company reported a substantial net loss in 2021, which is a primary solvency and going-concern risk.\n- Insufficient operating earnings to cover interest: interest_coverage = 0.38882463675949536. Operating income appears inadequate to meet interest obligations from recurring operations.\n- Elevated leverage: debt_equity = 1.3584280927054282. Debt relative to equity is above conservative thresholds, increasing financial risk if losses continue.\n- Negative returns: roa = -0.6077322118642288 and roe = -2.1321761290705408. These indicate that both asset base and shareholders’ equity are generating negative returns, consistent with the net loss.\n- Mismatch between high gross margin and net loss: gross_margin = 0.8548843465641977 vs operating_margin = 0.21215872425920793 and net_margin negative. This suggests significant non‑gross costs (operating expenses, financing costs, taxes, or one‑off items) are driving the bottom‑line loss; such items increase solvency risk if persistent.\n\n(reported metrics exceeding conservative thresholds)\n- net_margin (-0.7870506702278115) — exceeds conservative threshold for acceptable performance (negative vs threshold of 0).\n- interest_coverage (0.38882463675949536) — exceeds conservative warning threshold (below 1.0).\n- debt_equity (1.3584280927054282) — exceeds conservative leverage threshold (above 1.0).\n- roa (-0.6077322118642288) — exceeds conservative threshold for acceptable return (negative).\n- roe (-2.1321761290705408) — exceeds conservative threshold for acceptable return (negative).\n\nrecommendations:\n- Investigate drivers of the net loss: obtain detailed reconciliations of operating expenses, non‑operating items, financing costs, and any one‑off charges to determine persistence and remediation options.\n- Stress test debt service capacity under scenarios where operating income remains depressed; consider refinancing, covenant waivers, or deleveraging options if results show tightening liquidity or covenant breach risk.\n- Improve interest coverage by reducing interest expense (refinancing/repayment) or increasing operating income (cost controls, margin recovery initiatives); prioritize actions that do not materially deplete liquidity.\n- Monitor liquidity despite current strong ratios: document cash runway under conservative cash flow projections, including downside scenarios reflecting continued losses.\n- Enhance governance and reporting: require monthly solvency-focused dashboards for management and the board highlighting operating cash flow, interest payable, covenant compliance, and capital structure metrics.\n- Consider external review: an independent financial review or audit emphasis on going-concern assessment may be appropriate given the magnitude of losses and leverage.\n\nconfidence_notes:\n- The analysis is based solely on the provided ratio values for 2021. No source documents, trend data, or notes were reviewed. Conclusions are limited to those ratios and do not reflect off‑balance sheet arrangements, subsequent events, or qualitative factors not supplied.\n- Recommendations are precautionary and should be validated with the company’s detailed financial statements, cash flow schedules, and management explanations.'},
#   {'Company': 'Acme Manufacturing Ltd',
#    'Year': 2022,
#    'analysis_profile': None,
#    'interpretation': 'summary\n- This solvency-focused assessment of Acme Manufacturing Ltd for year 2022 is based solely on the provided financial ratios. Using conservative benchmark thresholds (defined below), the company demonstrates strong reported liquidity and profitability metrics, a moderate leverage position, but a potentially concerning level of interest coverage. No trend analysis or external data was available; conclusions are limited to the snapshot conveyed by the supplied ratios.\n\nkey_risks\n- Interest coverage shortfall: Using a conservative threshold of interest coverage > 3.0x, the reported interest_coverage of 2.447x is below that threshold. This indicates a reduced margin of safety for servicing interest expense from operating earnings under a conservative standard.\n- Possible working-capital inefficiency: The current_ratio and quick_ratio are both high at 3.41 (threshold used: > 2.0 as conservative). While a high ratio reduces short-term liquidity risk, it may also indicate inefficient use of capital (excess cash, inventories or receivables). This is a solvency-related operational risk to monitor.\n- Concentration of performance on profitability metrics: Extremely high margins and returns are reported (gross_margin 96.83%, operating_margin 68.03%, net_margin 30.19%, roa 60.08%, roe 154.84%). Using conservative thresholds (gross_margin > 50%, operating_margin > 15%, net_margin > 10%, ROA > 5%, ROE > 15%), these metrics materially exceed those thresholds. Such levels warrant verification in audit workpapers to confirm accuracy, sustainability and the absence of one-off or nonrecurring items that could affect future solvency.\n- Leverage exposure: Debt to equity is 0.697 (conservative maximum threshold used: 1.0). This is below the conservative maximum but is material enough that combined with lower interest coverage it could increase refinancing or interest-rate sensitivity risk.\n\nrecommendations\n- Verify interest expense and EBIT components: Perform detailed audit procedures on interest expense, interest-bearing liabilities, and operating earnings (EBIT) to confirm the 2.447x interest coverage figure and identify any non-operating items that may be influencing coverage.\n- Assess sustainability of exceptionally high profitability: Reconcile revenue recognition, cost of goods sold, and any unusual items or one-time gains that could have elevated gross, operating and net margins. Obtain supporting documentation to confirm margins are repeatable and not inflating solvency metrics.\n- Review working capital composition: Analyze cash, receivables and inventory composition supporting the current and quick ratios to determine whether excess liquidity is temporary, structural, or tied up in slow-moving assets. Consider recommendations to management to optimize working capital if appropriate.\n- Stress-test debt servicing under adverse scenarios: Given the lower-than-conservative interest coverage, model the company’s ability to service debt under stressed earnings assumptions (e.g., reduced EBITDA or higher interest rates) and evaluate covenant compliance risk.\n- Consider capital structure options: If stress testing shows material vulnerability, evaluate options such as reducing interest-bearing debt, refinancing to longer maturities, or securing committed credit lines to bolster solvency buffers.\n\nconfidence_notes\n- Basis: This assessment is limited to the supplied 2022 ratios and a solvency-focused mandate. No additional financial statements, notes, cash-flow detail, audit workpapers, or external data were provided.\n- Limitations: Ratios have not been decomposed beyond the high-level verification and threshold comparisons stated above. The identification of items as “material” or “warranting verification” is based on conservative threshold settings declared in this report; these thresholds are judgmental and may be adjusted per client or auditor policy.\n- Recommended procedures in this report are pro ...
#   {'Company': 'Acme Manufacturing Ltd',
#    'Year': 2023,
#    'analysis_profile': None,
#    'interpretation': 'summary:\nAcme Manufacturing Ltd’s 2023 ratios show strong liquidity and profitability but a leveraged capital structure with borderline interest coverage. Key figures: current and quick ratios of 4.67, gross margin 77.14%, operating margin 51.06%, net margin 18.22%, debt-to-equity 1.48, interest coverage ~2.00, return on assets 35.81% and return on equity 113.73%. These results indicate high short-term asset coverage and strong operating profitability, alongside material reliance on debt and limited ability to absorb interest cost increases.\n\nkey_risks:\n- Excessive liquidity (potential inefficient capital deployment): current_ratio = 4.6729 and quick_ratio = 4.6729 — both exceed a conservative upper threshold of 2.5. Excess liquidity may indicate idle cash or working capital that could be put to higher-yield uses.\n- Leverage concentration: debt_equity = 1.4765 — exceeds a conservative threshold of 1.0, indicating material use of debt relative to equity and higher solvency risk in adverse scenarios.\n- Interest coverage shortfall: interest_coverage = 2.0032 — below a conservative minimum threshold of 3.0, signalling limited buffer to meet interest obligations from operating results.\n- Elevated equity return requiring review: roe = 1.1373 (113.73%) — exceeds a conservative benchmark of 15% by a wide margin. Such a high ROE can result from high profitability or a small equity base; this warrants review of equity composition and any accounting or one-off items that may inflate ROE.\n- Concentration of operating margins: gross_margin = 0.7714 and operating_margin = 0.5106 — both materially exceed conservative benchmarks (e.g., gross >40%, operating >15%). While positive for profitability, their magnitude suggests reviewing margin drivers for sustainability and any non-recurring items.\n\nrecommendations:\n- Capital allocation review: assess uses for excess working capital (current/quick ratios) — potential actions include investing in productive assets, targeted share buybacks, debt reduction, or short-term investments consistent with risk appetite and liquidity needs.\n- Debt structure & refinancing: evaluate the maturity profile and covenants of outstanding debt and consider partial deleveraging or refinancing to reduce interest burden and improve interest coverage ratio toward or above 3.0.\n- Detailed ROE and equity analysis: perform an audit-focused review of equity components (shareholder distributions, share count, reserves) and one-off items affecting net income to confirm the sustainability and sources of the high ROE.\n- Stress test interest and earnings sensitivity: run conservative scenario analyses on earnings and interest rates to determine solvency under downside cases, given the current interest coverage.\n- Working capital optimization: investigate components of current assets and liabilities to identify specific sources of elevated current ratio (e.g., cash, receivables, inventory) and opportunities to optimize cycles without compromising operational needs.\n- Disclose and monitor contingent exposures: ensure full disclosure and monitoring of contingent liabilities, off-balance-sheet items, and covenant triggers that could affect solvency.\n\nconfidence_notes:\n- Observations are based solely on the provided 2023 ratios. No additional financial statement detail, segment breakdowns, cash flow data, or notes were available for review.\n- Recommendations are precautionary and intended for further analysis; they do not rely on unprovided trend data or assumptions about future performance.\n- Further audit procedures recommended: review of the 2023 balance sheet and cash flow statement, maturity schedule of debt, detailed composition of current assets, and disclosure schedules to confirm causes of the highlighted metrics and to quantify potential remediation actions.'},
#   {'Company': 'Banyan Retail Co',
#    'Year': 2020,
#    'analysis_profile': None,
#    'interpretation': 'summary\nBanyan Retail Co (2020) displays strong liquidity and unusually high profitability alongside moderate leverage. Using conservative thresholds (defined below), current and quick ratios indicate ample short-term liquidity, gross and operating margins are materially elevated, and return measures are high. Debt-to-equity is marginally above a conservative leverage benchmark, while interest coverage is below a conservative coverage benchmark. The observations below are based solely on the supplied ratios for 2020.\n\nkey_risks\n- Elevated leverage relative to conservative benchmark: debt_equity = 1.0476 (conservative threshold: >1.0). This indicates debt slightly exceeds equity on a conservative basis and could increase solvency risk if earnings weaken.\n- Insufficient interest buffer: interest_coverage = 2.0234 (conservative threshold: <3.0 is a concern). Earnings available to cover interest are limited on a conservative standard, increasing risk of distress if operating income falls or interest costs rise.\n- Concentration of very high profitability metrics: gross_margin = 75.71%, operating_margin = 63.20%, net_margin = 18.09%. While positive for cash generation, such elevated margins merit scrutiny for sustainability—if margins revert toward industry norms, leverage and coverage ratios could deteriorate materially.\n- Reliance on short-term liquidity: current_ratio and quick_ratio = 2.5135 (conservative thresholds noted below). While these ratios are strong, they do not by themselves confirm the quality or timing of current assets (e.g., receivables collectability, inventory obsolescence).\n- Large returns that may mask underlying risk: roa = 58.50% and roe = 79.64% are very high versus conservative profitability expectations; these may reflect one-time items, accounting treatments, or an atypically small equity base and should be validated.\n\nrecommendations\n- Validate quality and timing of current assets: perform a detailed review of accounts receivable aging, inventory valuation, and other current asset components to confirm that reported liquidity is realizable under stress.\n- Stress-test interest and earnings: run sensitivity analyses on operating income declines (e.g., -10%, -25%) and interest-rate increases to quantify effects on interest_coverage and debt-servicing capacity.\n- Pursue measured deleveraging: evaluate options to reduce debt or extend maturities (e.g., targeted repayments, refinancing to longer terms) to lower debt_equity below conservative thresholds and improve solvency resilience.\n- Preserve liquidity cushions: maintain or increase cash reserves and committed credit facilities to cover at least short-term interest and principal obligations under adverse scenarios.\n- Investigate sustainability of margins: review pricing, cost structure, and any non-recurring items or accounting adjustments that materially contributed to the high gross/operating margins to assess whether current profitability is sustainable.\n- Enhance reporting disclosure: ensure management provides clear disclosure of debt maturities, covenants, off-balance-sheet obligations, and any materially non-recurring income or expense items to support solvency assessment.\n\nconfidence_notes\n- Analysis is limited to the supplied 2020 ratio set and does not incorporate underlying financial statements, cash-flow schedules, debt maturity profiles, industry comparatives, or subsequent-period developments.\n- Conservative thresholds applied for highlighting purposes: current_ratio > 2.0, quick_ratio > 1.0, debt_equity > 1.0 (flag for elevated leverage), interest_coverage < 3.0 (flag for limited coverage), net_margin > 10%, roa > 5%, roe > 15%, gross/operating margins > 40% (used to identify unusually high profitability). These thresholds are applied solely for risk-signaling in a solvency-focused review.\n- Recommendations should be validated with full financial statements, notes, and management discussion; additio ...
#   {'Company': 'Banyan Retail Co',
#    'Year': 2021,
#    'analysis_profile': None,
#    'interpretation': "summary\nBanyan Retail Co (2021) shows materially weakened profitability and solvency metrics. Liquidity ratios indicate modest near-term coverage of current obligations. Leverage and coverage measures are elevated and negative respectively, indicating potential stress servicing debt. Profitability and returns are broadly negative. These conditions warrant caution regarding the company's ability to meet obligations from operating cash flows without corrective action or external support.\n\nkey_risks\n- Operating loss: Operating margin = -64.5849% (threshold: < 0%). The negative operating margin indicates core operations are not covering operating costs.\n- Net loss: Net margin = -148.2807% (threshold: < 0%). The company reported a substantial net loss relative to revenue.\n- Negative interest coverage: Interest coverage = -1.3248 (conservative threshold: < 3.0; critical if ≤ 0). The negative value indicates operating income does not cover interest expense and interest obligations may require non-operational funding.\n- Elevated leverage: Debt-to-equity = 1.4894 (conservative threshold: > 1.0). Debt exceeds equity, increasing solvency risk in a downturn.\n- Negative returns: ROA = -92.6341% and ROE = -214.9828% (thresholds: < 0%). These indicate assets and equity are generating negative returns.\n- Low gross margin: Gross margin = 3.6190% (conservative threshold: < 20%). Very thin gross margin leaves limited room to absorb operating costs or interest.\n- Low asset efficiency: Asset turnover = 0.6247 (conservative threshold: < 1.0). Asset base generates less than one dollar of revenue per dollar of assets annually, limiting revenue growth for a given asset base.\n- Liquidity concentration: Current ratio and quick ratio = 1.7051 (conservative threshold: < 1.5 flagged as marginal). Although above 1.0, the ratios are modest for a retail business with low margins and elevated leverage.\n\nrecommendations\n- Prioritize short-term liquidity planning: prepare a rolling 12-month cash flow forecast, stress-tested for lower sales scenarios, and identify committed and uncommitted borrowing lines.\n- Address operating losses: investigate cost structure and gross-margin drivers (pricing, procurement, promotions, shrinkage) and implement targeted margin improvements or cost reductions.\n- Rebalance capital structure: evaluate options to reduce leverage (debt repayment using non-core asset sales, refinancing on better terms, or equity injection) to reduce solvency pressure and interest burden.\n- Interest burden mitigation: negotiate with lenders for temporary covenant relief, interest deferrals, or amendment of payment schedules if forecasts indicate near-term covenant risk.\n- Asset utilization: review store/network footprint and inventory management to improve asset turnover and free cash.\n- Regular monitoring and reporting: establish monthly covenant and liquidity dashboards for the board and lenders; escalate deviations promptly.\n- Conservative contingency: maintain access to contingency liquidity (credit lines or committed facilities) equal to at least 3–6 months of fixed cash outflows given current negative operating results.\n\nconfidence_notes\n- Analysis is based solely on the provided 2021 ratio values and standard conservative threshold definitions cited above. No additional financial statement detail, cash flow amounts, maturity profile of debt, or off-balance-sheet exposures were provided.\n- Recommendations are precautionary and contingent on corroborating financial schedules (income statement, balance sheet, cash flow, debt schedule) and management disclosure. Further audit-level review of underlying balances and confirmations is recommended to validate ratios and support decision-making."},
#   {'Company': 'Banyan Retail Co',
#    'Year': 2022,
#    'analysis_profile': None,
#    'interpretation': "summary\nBanyan Retail Co's 2022 financial ratios indicate liquidity appears adequate while profitability and solvency show material weaknesses. The company reports a current ratio and quick ratio of 2.89, suggesting short-term liquidity coverage above commonly used conservative benchmarks. However, profitability and leverage measures are unfavorable: operating margin (-77.74%), net margin (-284.43%), negative interest coverage, and return metrics (ROA -100.76%, ROE -246.83%) indicate the company is generating operating losses and negative returns on assets and equity. Debt/equity is 1.15, reflecting a leverage level above conservative comfort levels. Asset turnover is low at 0.35. Overall, liquidity appears sufficient for near-term obligations but solvency and earnings performance present significant concerns.\n\nkey_risks\n- Negative interest coverage (-0.58): Interest coverage is below the conservative threshold of 1.0, indicating operating income is insufficient to cover interest expense and increasing risk of distress if interest costs persist or rise.\n- High leverage (debt/equity 1.15): Debt-to-equity exceeds a conservative threshold of 1.0, implying elevated financial leverage that increases insolvency risk if earnings do not recover.\n- Large operating loss (operating margin -77.74%): Operating margin is well below a conservative 0% threshold, signalling core operations are not profitable and reducing capacity to service debt from operating cash flow.\n- Deep net loss (net margin -284.43%): Net margin far below 0% highlights substantial bottom-line losses, which will deplete equity if sustained.\n- Negative returns (ROA -100.76%, ROE -246.83%): Both returns are below conservative expectations (ROA and ROE >0%), indicating assets and equity are not generating positive returns.\n- Low asset efficiency (asset turnover 0.35): Asset turnover is below conservative benchmarks (often >1.0 for efficient retail operations), suggesting low revenue generation relative to asset base, which compounds solvency pressure if margins remain negative.\n\nrecommendations\n- Prioritize restoration of operating profitability: Undertake a detailed cost and revenue review to identify actions that can reduce operating losses (cost reductions, pricing adjustments, SKU rationalization). Link actions to quantifiable cash flow improvements.\n- Reduce leverage or restructure debt: Explore refinancing, covenant negotiation, or partial deleveraging using asset sales or equity injections to lower debt/equity toward or below conservative levels (≤1.0), reducing interest burden and insolvency risk.\n- Improve interest coverage: Given negative interest coverage, initiate measures to reduce interest expense and/or increase operating income. Model sensitivity of interest coverage to revenue and cost scenarios.\n- Improve asset efficiency: Review fixed asset utilization and inventory management to increase asset turnover; consider disposing of underutilized assets.\n- Strengthen liquidity contingency planning: Despite current adequate current ratio, prepare contingency plans (credit lines, staged cost reductions) to preserve liquidity if operating losses persist.\n- Enhance financial monitoring and reporting: Implement more frequent solvency-focused reporting (monthly cash flow, covenant headroom, interest coverage projections) to detect deterioration early and support timely management decisions.\n\nconfidence_notes\n- The assessment is based exclusively on the provided 2022 ratio values. No additional financial statement detail, trend data, or forecasts were provided.\n- Thresholds referenced above are conservative benchmarks commonly used in solvency analysis (e.g., interest coverage >1.0, debt/equity ≤1.0, ROA/ROE >0%). They are cited for risk identification; specific suitability depends on company context and industry norms.\n- Recommendations are precautionary and should be confirmed with full financial statements, cash flow anal ...
#   {'Company': 'Banyan Retail Co',
#    'Year': 2023,
#    'analysis_profile': None,
# ...
#   {'Company': 'Emerald Energy Inc',
#    'Year': 2020,
#    'analysis_profile': None,
#    'interpretation': 'summary:\nEmerald Energy Inc. (2020) shows operational profitability at the gross and operating levels but material solvency and profitability concerns at the net-income and equity-holder level. Liquidity as measured by the current and quick ratios is marginally below conservative expectations. Leverage is elevated and interest-bearing coverage is limited. These factors together indicate increased risk to creditors and a constrained capacity to absorb adverse shocks.\n\nkey_risks:\n- Liquidity shortfall: current_ratio = 0.9866 and quick_ratio = 0.9866, each below the conservative threshold of 1.0. This indicates current liabilities exceed readily available current assets on a conservative basis.\n- Elevated leverage: debt_equity = 2.3413, above a conservative benchmark of 1.5. High leverage increases creditor exposure and reduces financial flexibility.\n- Limited interest coverage: interest_coverage = 2.1729, below a conservative benchmark of 3.0. Coverage at this level provides a limited cushion for meeting interest obligations if operating income declines.\n- Negative net profitability: net_margin = -0.0807, indicating net losses after all expenses and financing costs; this reduces equity and the firm’s ability to build reserves.\n- Negative returns: roa = -0.09497 and roe = -0.28719, both negative, indicating the company delivered negative returns to assets and to shareholders in 2020.\n- Combined solvency strain: The mix of negative net income, high leverage and limited interest coverage increases the probability of covenant pressure or the need for additional financing under adverse conditions.\n\nrecommendations:\n- Immediate covenant and maturity review: identify upcoming debt maturities and covenant tests; prioritize negotiations or refinancing for near-term obligations where required.\n- Targeted deleveraging plan: prepare a conservative plan to reduce debt levels (e.g., asset dispositions, targeted free-cash-flow allocation to debt reduction) with scenario analysis showing post-action debt_equity outcomes.\n- Strengthen interest coverage buffer: assess measures to increase EBIT (cost controls, efficiency improvements) and/or reduce interest expense (refinancing to lower rates or extended maturities) to approach an interest_coverage > 3.0 under a conservative scenario.\n- Liquidity contingency: establish or confirm committed liquidity lines and maintain liquid reserves to raise current_ratio and quick_ratio to at least 1.0 under base-case stress.\n- Profitability diagnostics: perform line-item analysis to isolate drivers of the negative net margin (non-operating items, financing costs, tax effects) and prioritize actions that improve net income retention.\n- Monitoring and reporting: institute monthly solvency dashboards covering cash runway, covenant headroom, and interest_coverage sensitivities; escalate to senior management and lenders if buffers tighten.\n\nconfidence_notes:\n- Assessment is based solely on the supplied 2020 ratio values and conservative benchmark thresholds stated above. No temporal trends, balance-sheet detail, cash-flow statements, or covenant specifics were provided.\n- Conclusions are conditional on the accuracy and completeness of the provided ratios. Additional financial statement detail could materially affect the recommendations and risk prioritization.'},
#   {'Company': 'Emerald Energy Inc',
#    'Year': 2021,
#    'analysis_profile': None,
#    'interpretation': 'summary:\nEmerald Energy Inc.’s 2021 financial ratios indicate materially weak solvency and profitability. Liquidity is severely constrained (current_ratio 0.269; quick_ratio 0.269). Leverage is elevated (debt_equity 1.293). Profitability and coverage measures are negative (gross_margin -10.62%, operating_margin -73.97%, net_margin -211.12%, roa -2.428, roe -2.344, interest_coverage -0.643). Asset turnover (1.150) is not itself a solvency strength given the magnitude of losses and low liquidity. Overall, the profile suggests significant short-term liquidity pressure and elevated default risk if current conditions persist.\n\nkey_risks:\n- Liquidity shortfall: current_ratio 0.2688 and quick_ratio 0.2688 — materially below conservative thresholds (typically ≥1.0), indicating difficulty meeting near-term obligations.\n- Insufficient interest coverage: interest_coverage -0.6429 — negative coverage indicates operating income is insufficient to service interest, increasing default and refinancing risk.\n- Elevated leverage: debt_equity 1.2932 — exceeds conservative leverage threshold (commonly ≤1.0), amplifying creditor risk given weak earnings.\n- Operating losses: operating_margin -73.97% and net_margin -211.12% — persistent operating losses reduce internal cash generation and impair solvency.\n- Negative returns: roa -2.428 and roe -2.344 — negative returns on assets and equity imply capital erosion, increasing the risk that equity and asset cushions will be depleted.\n- Gross margin deterioration: gross_margin -10.62% — negative gross margin undermines core product/service viability and limits ability to restore profitability without structural changes.\n\nrecommendations:\n- Prioritize near-term liquidity preservation: prepare a short-term cash forecast and identify non-essential cash outflows for suspension or deferral.\n- Engage creditors proactively: seek covenant waivers, maturity extensions, or temporary forbearance to reduce imminent default risk given negative interest coverage.\n- Evaluate deleveraging options: consider asset sales of non-core assets or negotiated debt-for-equity conversions to reduce debt_equity toward conservative levels.\n- Implement cost and margin remediation: conduct a disciplined review of variable and fixed costs and pricing to correct negative gross and operating margins; quantify expected savings before implementation.\n- Contingency capital planning: assess options for secured short-term financing or equity injections; prioritize sources that minimally increase immediate cash-burn risk.\n- Strengthen monitoring and reporting: adopt weekly cash reporting and rolling 13-week cash forecasts until liquidity and interest coverage materially improve.\n\nconfidence_notes:\n- Analysis is solely based on the provided 2021 ratio values. No time-series, balance sheet, income statement, cash flow amounts, or qualitative information were available for trend analysis or validation.\n- Recommendations are conservative and contingent on verification of underlying financial statement amounts, covenant specifics, and available liquidity. Further, more granular analysis (cash flow detail, maturity schedules, creditor positions) is required to prioritize and quantify actions.'},
#   {'Company': 'Emerald Energy Inc',
#    'Year': 2022,
#    'analysis_profile': None,
#    'interpretation': 'summary\nEmerald Energy Inc — 2022: Liquidity is strong by conventional conservative measures; the company shows materially positive gross and operating margins but reports a net loss and negative returns. Leverage is moderately elevated and coverage of interest expense is marginal by conservative standards. The combination of a net loss, negative ROA and ROE, and leverage creates solvency and earnings-quality concerns despite ample short-term liquidity.\n\nkey_risks\n- Negative profitability metrics\n  - Net margin: -0.0933 (net loss). A negative net margin indicates the company did not generate positive net income in 2022.\n  - ROA: -0.1530 and ROE: -0.6395. Both return measures are negative, indicating losses relative to assets and equity.\n- Leverage and coverage concerns (breaches of conservative thresholds)\n  - Debt/Equity: 1.1927. This exceeds a conservative leverage threshold of 1.0, indicating higher reliance on debt financing relative to equity.\n  - Interest coverage: 2.9276. This is marginally below a conservative minimum threshold of 3.0, indicating limited buffer to cover interest expense from operating earnings.\n- Liquidity observations (not a current solvency shortfall)\n  - Current ratio and quick ratio: 3.9842. These are above common conservative minimums (e.g., 1.5–2.0) and indicate substantial short-term liquidity. However, strong liquidity does not offset the solvency and profitability weaknesses noted above.\n- Earnings quality and sustainability\n  - High gross margin (0.7305) and operating margin (0.4704) contrast with the net loss, suggesting non-operating items, financing costs, or one-time charges materially affected net results. These items warrant review for their impact on sustainability of earnings and solvency.\n\nrecommendations\n- Immediate financial review\n  - Reconcile and disclose the primary drivers of the net loss despite strong operating margins (e.g., interest expense, impairments, tax items, one-time charges). Prioritize items that are recurring versus non-recurring.\n- Capital-structure actions\n  - Consider measures to reduce leverage (debt/equity) toward or below 1.0 where feasible: refinance to longer maturities, negotiate covenant relief, or evaluate selective equity issuance if market conditions allow and dilution is acceptable.\n- Interest-cost mitigation\n  - Evaluate opportunities to improve interest coverage: reduce short-term debt where possible, refinance at lower rates, or improve operating cash flow through cost control.\n- Liquidity preservation\n  - Maintain the strong current liquidity position while addressing solvency items. Avoid material cash distributions (dividends, share buybacks) until sustained net profitability and improved coverage metrics are demonstrated.\n- Reporting and monitoring\n  - Provide transparent, itemized disclosure in interim and annual financial reports of non-operating and financing charges that produced the net loss.\n  - Establish monthly monitoring of interest coverage, free cash flow, and debt maturities through 12–24 months to ensure solvency risk is tracked and managed.\n\nconfidence_notes\n- Analysis is limited to the supplied 2022 ratio values. No underlying financial statement line-item detail, trend history (prior years), or balance-sheet maturity schedule was provided.\n- Thresholds cited (e.g., debt/equity of 1.0; interest coverage of 3.0; current ratio minimums) reflect conservative benchmarks commonly used in solvency-focused analysis and are explicitly stated where referenced.\n- Recommendations are conditioned on further review of underlying financial statements and any subsequent periods; actions should be informed by complete financial data and management disclosures.'},
#   {'Company': 'Emerald Energy Inc',
#    'Year': 2023,
#    'analysis_profile': None,
#    'interpretation': 'summary\nEmerald Energy Inc. (2023) exhibits materially constrained liquidity and elevated financial leverage. Key liquidity ratios (current and quick) are materially below conventional conservative benchmarks, and debt-to-equity is above a conservative leverage threshold. Profitability measures are mixed: very high gross and operating margins indicate strong unit economics before financing and other non-operating items, while net margin, return on assets (ROA), and return on equity (ROE) are negative, indicating losses after interest, tax, and non-operating items. Interest coverage is positive but below conservative safety levels. These indicators collectively point to elevated solvency risk and limited near-term liquidity buffer.\n\nkey_risks\n- Liquidity shortfall: Current ratio = 0.606 and Quick ratio = 0.606. Both are below the conservative benchmark of 1.0, indicating current liabilities exceed current assets and limited near-term liquidity headroom.\n- High leverage: Debt-to-equity = 2.130. This exceeds conservative leverage thresholds (commonly around 1.0–2.0) and indicates the company relies heavily on debt financing relative to equity.\n- Limited interest coverage: Interest coverage = 2.159. This is below conservative comfort levels (often 3.0 or higher), signalling limited capacity to absorb increases in interest expense or operating volatility.\n- Post-financing losses: Net margin = -0.031 (negative). Despite strong gross (0.805) and operating (0.685) margins, the company reports a net loss, indicating non-operating charges, financing costs, taxes, or other items are driving a loss at the bottom line.\n- Negative returns: ROA = -0.118 and ROE = -0.143. Negative returns on assets and equity reflect the net loss and suggest capital is not generating positive returns in the reported year.\n- Concentration of solvency pressure despite operational efficiency: Asset turnover is high (3.781), demonstrating efficient use of assets to generate revenue, but this efficiency is insufficient to offset financing and non-operating impacts on net results and solvency.\n\nrecommendations\n- Prioritize short-term liquidity actions: assess working capital management opportunities (receivables collection, inventory levels if applicable, payable terms) and consider short-term financing or committed credit facilities to cover current liabilities until structural improvements take effect.\n- Address capital structure: evaluate options to reduce leverage, including debt refinancing to extend maturities, converting short-term debt to longer-term instruments, negotiating covenant relief where required, or selectively augmenting equity capital if feasible and appropriate.\n- Strengthen interest coverage buffer: consider reducing variable-rate debt, locking in lower fixed rates if available, or reducing overall debt to increase coverage and resilience to interest rate movements.\n- Investigate drivers of net loss: perform a detailed reconciliation of operating profit to net income to identify material non-operating charges, one-time items, or excessive financing costs that can be managed or mitigated.\n- Implement scenario planning: conduct stress tests on cash flow and covenant compliance under downside scenarios (e.g., revenue decline, interest rate increases) to inform contingency funding plans.\n- Communicate with stakeholders: proactively engage lenders and key counterparties with a clear remediation plan to reduce the risk of covenant breaches or liquidity shocks.\n\nconfidence_notes\n- The assessment is based solely on the supplied 2023 ratios. No additional financial statement detail, trend history, or forward-looking information was provided.\n- Conclusions are limited to the presented metrics; any material items not reflected in these ratios (e.g., off-balance-sheet obligations, committed undrawn facilities, contingent liabilities, one-time non-recurring items) could materially affect solvency assessment.\n- Re ...
#  'profile_used': 'solvency_focus'}

# %% [markdown]
# ### Step 6: Inspect AI Interpretation Output
#
# This validates **semantic usability**, not correctness.

# %%
sample_interp = outputs["ai_interpretation"][0]

print("Company:", sample_interp["Company"])
print("Year:", sample_interp["Year"])
print("\n--- AI Interpretation ---\n")
print(sample_interp["interpretation"])
# Out:
# Company: Acme Manufacturing Ltd
# Year: 2020
#
# --- AI Interpretation ---
#
# summary:
# Acme Manufacturing Ltd — 2020 solvency-focused summary. Current and quick ratios are 1.588 (equal values) indicating short-term liquidity marginally above a conservative 1.50 threshold. Gross margin (86.737%) and operating margin (28.911%) are materially positive and exceed conservative profitability thresholds. However, net margin is negative (−154.615%), return on assets (−108.322%) and return on equity (−202.063%) are substantially adverse. Debt-to-equity is 0.983 (approximately 0.98). Interest coverage is very low at 0.278, indicating operating income is insufficient to meet interest expense. Asset turnover is 0.701. Overall, liquidity at the current/current-asset level appears acceptable by conservative liquidity cut-offs, but solvency and profitability at the net and return levels are concerning given the negative net income and inadequate interest coverage.
#
# key_risks:
# - Insufficient interest coverage: Interest coverage ratio 0.2777 is well below a conservative threshold of 1.0, indicating operating profit does not cover interest expense. This presents a near-term risk to debt service capacity.
# - Negative bottom-line profitability: Net margin (−1.546) reflects a loss after tax; negative ROA (−1.083) and ROE (−2.021) confirm that the company is destroying shareholder and asset value in 2020.
# - Leverage and refinancing risk: Debt-to-equity of 0.983, while below or near a conservative 1.0 threshold, combined with very low interest coverage increases refinancing and covenant breach risk if earnings do not improve.
# - Liquidity concentration risk: Although current and quick ratios (1.588) exceed a conservative 1.50 threshold, the margin above the threshold is narrow; any deterioration in receivables, inventory realizations, or cash flows could rapidly weaken short-term liquidity.
# - Operational cash-flow risk: The combination of positive gross and operating margins with a negative net margin suggests non-operating charges, interest expense or exceptional items materially reduced net income; if recurrent, these items threaten solvency.
#
# recommendations:
# - Prioritize restoring interest coverage: negotiate interest terms, consider temporary interest relief, or reprofile debt maturities to reduce near-term interest burden.
# - Address sources of net loss: undertake a detailed expense and non-operating-charge review to identify and, where appropriate, reduce non-operating losses, extraordinary items, or tax effects contributing to the negative net margin.
# - Strengthen liquidity buffers: maintain or increase available cash and committed facilities to provide coverage below the current 1.588 current ratio buffer; implement tighter working-capital controls to protect quick assets.
# - Review capital structure alternatives: consider modest deleveraging where feasible or equity injections to improve coverage ratios and reduce refinancing risk, subject to creditor and shareholder analysis.
# - Implement covenant monitoring and contingency planning: establish early-warning triggers given low interest coverage and negative net income; prepare contingency financing and cost-reduction plans.
#
# confidence_notes:
# - Analysis is based solely on the provided 2020 ratio values. No additional financial statements, notes, cash-flow details, or prior-year comparisons were available. Conclusions are therefore limited to the ratios supplied.
# - Conservative thresholds cited (current/quick 1.50, interest coverage 1.0) are applied for risk-identification purposes in this report; these thresholds are being used explicitly and may not reflect all stakeholders’ tolerances or contractual covenant definitions.
# - Recommendations are conditional and should be validated against full financial statements, cash-flow schedules, and lender covenants before execution.

# %% [markdown]
# ### Step 7: Inspect Numerical Engine Outputs
#
# This confirms:
# - Ratios exist
# - Engines populated data
# - Schema consistency

# %%
if outputs.get("ratios"):
    display(pd.DataFrame(outputs["ratios"]).head())

if outputs.get("solvency"):
    display(pd.DataFrame(outputs["solvency"]).head())
# Out:
#          engine                 Company  Year  \
# 0  ratio_engine  Acme Manufacturing Ltd  2020
# 1  ratio_engine  Acme Manufacturing Ltd  2021
# 2  ratio_engine  Acme Manufacturing Ltd  2022
# 3  ratio_engine  Acme Manufacturing Ltd  2023
# 4  ratio_engine        Banyan Retail Co  2020
#
#                                              metrics flags severity  \
# 0  {'current_ratio': 1.5876421245028514, 'quick_r...    {}   stable
# 1  {'current_ratio': 3.0794864428132476, 'quick_r...    {}   stable
# 2  {'current_ratio': 3.4109333800409956, 'quick_r...    {}   stable
# 3  {'current_ratio': 4.67288599769455, 'quick_rat...    {}   stable
# 4  {'current_ratio': 2.513537113097586, 'quick_ra...    {}   stable
#
#                   explanation
# 0  Canonical financial ratios
# 1  Canonical financial ratios
# 2  Canonical financial ratios
# 3  Canonical financial ratios
# 4  Canonical financial ratios
#             engine                 Company  Year  \
# 0  solvency_engine  Acme Manufacturing Ltd  2020
# 1  solvency_engine  Acme Manufacturing Ltd  2021
# 2  solvency_engine  Acme Manufacturing Ltd  2022
# 3  solvency_engine  Acme Manufacturing Ltd  2023
# 4  solvency_engine        Banyan Retail Co  2020
#
#                                              metrics  \
# 0  {'debt_equity': 0.9825237035626188, 'interest_...
# 1  {'debt_equity': 1.3584280927054282, 'interest_...
# 2  {'debt_equity': 0.6969581313037093, 'interest_...
# 3  {'debt_equity': 1.4765422770808412, 'interest_...
# 4  {'debt_equity': 1.0475669775251273, 'interest_...
#
#                                               flags severity  \
# 0   {'high_leverage': False, 'weak_coverage': True}    watch
# 1   {'high_leverage': False, 'weak_coverage': True}    watch
# 2  {'high_leverage': False, 'weak_coverage': False}   stable
# 3  {'high_leverage': False, 'weak_coverage': False}   stable
# 4  {'high_leverage': False, 'weak_coverage': False}   stable
#
#                               explanation
# 0  Capital structure shows solvency risk.
# 1  Capital structure shows solvency risk.
# 2           Solvency position acceptable.
# 3           Solvency position acceptable.
# 4           Solvency position acceptable.

# %% [markdown]
# ## Step 8: Full System Validation (All Profiles)
#
# This cell simulates **multiple client engagements**,
# ensuring no profile breaks the orchestrator.

# %%
results_by_profile = {}

for profile_name in CLIENT_CASES:
    print(f"\n--- Executing profile: {profile_name} ---")

    outputs = afap_run(
        financials_df=financials_df,
        analysis_profile=profile_name,
        use_mock_ai=False
    )

    validate_output_contract(outputs)
    validate_ai_interpretation(outputs["ai_interpretation"])

    engines_ran = [
        k for k in AFAP_OUTPUT_KEYS
        if k in outputs and outputs[k]
    ]

    print("Engines executed:", engines_ran)

    results_by_profile[profile_name] = outputs

print("\n✅ All AFAP profiles validated successfully")
# Out:
# --- Executing profile: full_diagnostic ---
# ✅ ratio_engine output validated successfully.
# ✅ trend_engine output validated successfully.
# ✅ cash_flow_engine output validated successfully.
# ✅ anomaly_efficiency_engine output validated successfully.
# ✅ solvency_engine output validated successfully.
# Engines executed: ['profile_used', 'ratios', 'trend', 'cash_flow', 'anomaly', 'solvency', 'composite_risk', 'ai_interpretation']
#
# --- Executing profile: solvency_focus ---
# ✅ ratio_engine output validated successfully.
# ✅ solvency_engine output validated successfully.
# Engines executed: ['profile_used', 'ratios', 'solvency', 'ai_interpretation']
#
# --- Executing profile: liquidity_focus ---
# ✅ ratio_engine output validated successfully.
# ✅ trend_engine output validated successfully.
# ✅ cash_flow_engine output validated successfully.
# Engines executed: ['profile_used', 'ratios', 'trend', 'cash_flow', 'composite_risk', 'ai_interpretation']
#
# --- Executing profile: performance_focus ---
# ✅ ratio_engine output validated successfully.
# ✅ trend_engine output validated successfully.
# Engines executed: ['profile_used', 'ratios', 'trend', 'ai_interpretation']
#
# --- Executing profile: risk_scan ---
# ✅ ratio_engine output validated successfully.
# ✅ anomaly_efficiency_engine output validated successfully.
# ✅ solvency_engine output validated successfully.
# Engines executed: ['profile_used', 'ratios', 'anomaly', 'solvency', 'ai_interpretation']
#
# --- Executing profile: going_concern_screen ---
# ✅ ratio_engine output validated successfully.
# ✅ trend_engine output validated successfully.
# ✅ solvency_engine output validated successfully.
# Engines executed: ['profile_used', 'ratios', 'trend', 'solvency', 'composite_risk', 'ai_interpretation']
#
# ✅ All AFAP profiles validated successfully

# %% [markdown]
# ### Step 9: Compare AI Interpretations Across Profiles
#
# This demonstrates the **profile-aware reasoning differences**.

# %%
for profile, outputs in results_by_profile.items():
    interp = outputs["ai_interpretation"][0]
    print(f"\n=== {profile.upper()} ===")
    print(interp["interpretation"][:1200], "...")
# Out:
# === FULL_DIAGNOSTIC ===
# summary:
# Acme Manufacturing Ltd — 2020 financial ratio diagnostic. Liquidity appears marginally adequate on a textbook current and quick ratio of 1.59, which is just above a conservative liquidity threshold. Profitability and returns are materially weak: gross margin is high at 86.74% but operating margin is 28.91% while net margin is negative at -154.61%, producing negative return on assets (ROA -1.08%) and return on equity (ROE -2.02%). Leverage is near a conservative limit with a debt-to-equity ratio of 0.98. Interest coverage is very low at 0.28, indicating operating earnings do not cover interest expense. Asset turnover is 0.70. Overall, the ratios indicate adequate short-term liquidity but significant earnings and solvency stress at the net income and interest-coverage level.
#
# key_risks:
# - Net profitability breach: net margin = -154.61% (conservative threshold: 0%). The company reported a material net loss relative to revenue in 2020.
# - Interest coverage breach: interest_coverage = 0.28 (conservative threshold: 1.5). Operating earnings are insufficient to cover interest expense by a wide margin.
# - Negative returns: ROA = -1.08% and ROE = -2.02% (conservative thresholds: 0%).  ...
#
# === SOLVENCY_FOCUS ===
# summary
# Acme Manufacturing Ltd — 2020 solvency-focused summary: Liquidity measures (current and quick ratios) are above conservative liquidity thresholds and indicate short-term obligations are likely coverable by current assets. Operating profitability (gross margin 86.7%, operating margin 28.9%) is positive; however, the company reports a material net loss (net margin -154.6%) and negative returns on assets and equity (ROA -1.083%, ROE -2.021%). Leverage is near parity (debt/equity 0.983) and interest coverage is substantially below conservative safety benchmarks (interest coverage 0.278). Taken together, the profile indicates adequate short-term liquidity but significant solvency risk driven by poor net profitability and weak ability to service interest-bearing debt.
#
# key_risks
# - Interest coverage (0.2777) — exceeds conservative concern threshold: interest coverage < 1.5. This low value indicates insufficient operating earnings relative to interest expense and a heightened risk of covenant breach or inability to meet interest payments from operating income.
# - Net margin (-1.546) — exceeds conservative concern threshold: net margin < 0. A large negative net margin signals net los ...
#
# === LIQUIDITY_FOCUS ===
# summary
# Acme Manufacturing Ltd — fiscal year 2020: Liquidity and solvency indicators present material concerns despite strong gross and operating margins. The company reports a current and quick ratio of 1.59, which on the surface indicates short-term coverage of current liabilities by current assets. However, profitability and coverage metrics are weak: net margin, return on assets (ROA), return on equity (ROE), and interest coverage are negative or well below conservative benchmarks. Debt levels are material relative to equity. These points raise liquidity and going-concern considerations that warrant further investigation.
#
# key_risks
# - Interest coverage: 0.2777. Conservative benchmark used: interest coverage < 2.0 signals potential difficulty meeting interest obligations. The reported value materially breaches this threshold and indicates limited ability to service interest from operating earnings.
# - Net margin: -1.5461 (i.e., negative). Conservative expectation: positive net margin. A negative net margin indicates losses at the bottom line, which erode equity and cash buffers.
# - Return metrics (ROA: -1.0832; ROE: -2.0206): Conservative expectation: positive returns. Negative re ...
#
# === PERFORMANCE_FOCUS ===
# summary
# Acme Manufacturing Ltd — Fiscal Year 2020
# The company presents a mixed profitability and liquidity profile. Liquidity (current and quick ratios at 1.588) is modestly positive but below conservative “strong” levels. Gross and operating margins are high (gross margin 86.7%; operating margin 28.9%), but the net margin is negative (−154.6%), producing negative returns on assets and equity (ROA −108.3%; ROE −202.1%). Leverage is material (debt-to-equity 0.983) and interest coverage is weak (0.278). Asset turnover is moderate (0.701). The combination of negative net profitability and poor interest coverage is the principal concern for going-concern and solvency assessment.
#
# key_risks
# - Negative net margin (−1.546 or −154.6%): This indicates that, after all expenses and non-operating items, the entity reported a net loss. This materially increases going-concern and capital-preservation risk.
# - Interest coverage (0.278): Interest expense appears to exceed operating income on a multiple basis; coverage well below 1.0 indicates insufficient operating earnings to meet interest obligations.
# - Negative returns (ROA −1.083; ROE −2.021): The company is generating negative returns on asset ...
#
# === RISK_SCAN ===
# summary
# Acme Manufacturing Ltd — 2020: The company reports generally adequate short-term liquidity (current and quick ratios ~1.59) and strong gross and operating margins (86.7% and 28.9%, respectively). However, profitability at the net level is materially negative (net margin -154.6%), and returns are negative (ROA -108.3%, ROE -202.1%). Coverage of interest obligations is very low (interest coverage 0.28). Leverage is moderate (debt/equity 0.98) and asset turnover is below 1.0 (0.70). These mixed signals warrant cautious assessment of non-operating items, financing structure and sustainability of earnings.
#
# key_risks
# - Net margin: -1.546 ( -154.6% ) — materially negative net profitability. This exceeds conservative acceptability (net margin < 0). Immediate explanation required for losses at the net level given positive operating margins.
# - Interest coverage: 0.278 — well below conservative threshold of 2.0. This indicates insufficient operating earnings to cover interest expense and presents a high risk of distress if financing costs persist or increase.
# - Return measures: ROA -1.083 ( -108.3% ), ROE -2.021 ( -202.1% ) — both negative, exceeding conservative thresholds of 0. The ...
#
# === GOING_CONCERN_SCREEN ===
# summary
# - Based on the provided 2020 financial ratios for Acme Manufacturing Ltd, there are material indicators of liquidity and profitability stress. Key strengths include a current and quick ratio of 1.588 (both identical), and a high gross margin (0.867). However, profitability and solvency metrics show significant weakness: net margin, return on assets, return on equity, and interest coverage are all deeply concerning. These indicators raise substantial doubt about the company’s ability to operate as a going concern without remedial action or external support.
#
# key_risks
# - Interest coverage: interest_coverage = 0.27765. This is well below conservative thresholds (typically ≥1.0) and indicates operating income is insufficient to meet interest expense. This is a primary solvency risk.
# - Net profitability: net_margin = -1.54615 (negative). A negative net margin signals losses at the bottom line and is inconsistent with long-term viability without corrective measures.
# - Returns: roa = -1.08322 and roe = -2.02063 (both negative). These negative returns indicate assets and equity are generating losses rather than profits.
# - Liquidity/working capital concentration risk despite nominal ...
