# %%
import sys
from pathlib import Path

# Explicit project root
PROJECT_ROOT = Path.cwd().parent  # adjust if notebook is nested
sys.path.insert(0, str(PROJECT_ROOT))

# Debug
print("Project root:", PROJECT_ROOT)
print("sys.path includes:", sys.path[0])
print("Folder contents:", list(PROJECT_ROOT.iterdir()))

# Import
from orchestrator.orchestrator import afap_run
print("Import successful!")
# Out:
# Project root: c:\Users\ADMIN\Documents\My Documents\MyDataAnalysis\Financial statement analysis\financial-analysis-pipeline
# sys.path includes: c:\Users\ADMIN\Documents\My Documents\MyDataAnalysis\Financial statement analysis\financial-analysis-pipeline
# Folder contents: [WindowsPath('c:/Users/ADMIN/Documents/My Documents/MyDataAnalysis/Financial statement analysis/financial-analysis-pipeline/afap_ai_engine'), WindowsPath('c:/Users/ADMIN/Documents/My Documents/MyDataAnalysis/Financial statement analysis/financial-analysis-pipeline/config'), WindowsPath('c:/Users/ADMIN/Documents/My Documents/MyDataAnalysis/Financial statement analysis/financial-analysis-pipeline/Contracts'), WindowsPath('c:/Users/ADMIN/Documents/My Documents/MyDataAnalysis/Financial statement analysis/financial-analysis-pipeline/data'), WindowsPath('c:/Users/ADMIN/Documents/My Documents/MyDataAnalysis/Financial statement analysis/financial-analysis-pipeline/docs'), WindowsPath('c:/Users/ADMIN/Documents/My Documents/MyDataAnalysis/Financial statement analysis/financial-analysis-pipeline/engines'), WindowsPath('c:/Users/ADMIN/Documents/My Documents/MyDataAnalysis/Financial statement analysis/financial-analysis-pipeline/notebooks'), WindowsPath('c:/Users/ADMIN/Documents/My Documents/MyDataAnalysis/Financial statement analysis/financial-analysis-pipeline/orchestrator'), WindowsPath('c:/Users/ADMIN/Documents/My Documents/MyDataAnalysis/Financial statement analysis/financial-analysis-pipeline/outputs'), WindowsPath('c:/Users/ADMIN/Documents/My Documents/MyDataAnalysis/Financial statement analysis/financial-analysis-pipeline/visuals')]
# Import successful!

# %%
import sys
import os
import yaml
import pandas as pd
from pathlib import Path

# Resolve AFAP project root explicitly
PROJECT_ROOT = PPROJECT_ROOT = Path.cwd().parent
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print("AFAP project root:", PROJECT_ROOT)

from orchestrator.orchestrator import afap_run
# Out:
# AFAP project root: c:\Users\ADMIN\Documents\My Documents\MyDataAnalysis\Financial statement analysis\financial-analysis-pipeline

# %%
import yaml
from orchestrator.orchestrator import afap_run

from pathlib import Path

client_cfg_path = Path(PROJECT_ROOT) / "config" / "clients" / "client_acme.yaml"

with open(client_cfg_path, "r") as f:
    client_config = yaml.safe_load(f)

print("Loaded client config from:", client_cfg_path)


data_path = PROJECT_ROOT / client_config["inputs"]["data_path"]

financials_df = pd.read_csv(data_path)

print("Loaded financials from:", data_path)

# Run orchestrator
outputs = afap_run(financials_df, client_config=client_config)
# Out:
# Loaded client config from: c:\Users\ADMIN\Documents\My Documents\MyDataAnalysis\Financial statement analysis\financial-analysis-pipeline\config\clients\client_acme.yaml
# Loaded financials from: c:\Users\ADMIN\Documents\My Documents\MyDataAnalysis\Financial statement analysis\financial-analysis-pipeline\data\cleaned\financial_statements.csv
# ✅ ratio_engine output validated successfully.
# ✅ trend_engine output validated successfully.
# ✅ cash_flow_engine output validated successfully.
# ✅ anomaly_efficiency_engine output validated successfully.
# ✅ solvency_engine output validated successfully.

# %%
outputs
# Out:
# {'ratios': [{'engine': 'ratio_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2020,
#    'metrics': {'current_ratio': np.float64(1.5876421245028514),
#     'quick_ratio': np.float64(1.5876421245028514),
#     'gross_margin': np.float64(0.8673714331416791),
#     'operating_margin': np.float64(0.28910663029085837),
#     'net_margin': np.float64(-1.5461482817762533),
#     'debt_equity': np.float64(0.9825237035626188),
#     'interest_coverage': np.float64(0.2776502541217982),
#     'asset_turnover': np.float64(0.7005951220265378),
#     'roa': np.float64(-1.0832239441421558),
#     'roe': np.float64(-2.020627325643515)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2021,
#    'metrics': {'current_ratio': np.float64(3.0794864428132476),
#     'quick_ratio': np.float64(3.0794864428132476),
#     'gross_margin': np.float64(0.8548843465641977),
#     'operating_margin': np.float64(0.21215872425920793),
#     'net_margin': np.float64(-0.7870506702278115),
#     'debt_equity': np.float64(1.3584280927054282),
#     'interest_coverage': np.float64(0.38882463675949536),
#     'asset_turnover': np.float64(0.7721640230460904),
#     'roa': np.float64(-0.6077322118642288),
#     'roe': np.float64(-2.1321761290705408)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2022,
#    'metrics': {'current_ratio': np.float64(3.4109333800409956),
#     'quick_ratio': np.float64(3.4109333800409956),
#     'gross_margin': np.float64(0.9682938776163919),
#     'operating_margin': np.float64(0.6803346187657713),
#     'net_margin': np.float64(0.30187505116222785),
#     'debt_equity': np.float64(0.6969581313037093),
#     'interest_coverage': np.float64(2.4466303752204883),
#     'asset_turnover': np.float64(1.9903341261309764),
#     'roa': np.float64(0.6008322161557166),
#     'roe': np.float64(1.5484389021911336)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2023,
#    'metrics': {'current_ratio': np.float64(4.67288599769455),
#     'quick_ratio': np.float64(4.67288599769455),
#     'gross_margin': np.float64(0.7714157526645563),
#     'operating_margin': np.float64(0.5105960440756842),
#     'net_margin': np.float64(0.18219037429368373),
#     'debt_equity': np.float64(1.4765422770808412),
#     'interest_coverage': np.float64(2.003210910410521),
#     'asset_turnover': np.float64(1.9655580591753654),
#     'roa': np.float64(0.3581057584971264),
#     'roe': np.float64(1.1372509883115411)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2020,
#    'metrics': {'current_ratio': np.float64(2.513537113097586),
#     'quick_ratio': np.float64(2.513537113097586),
#     'gross_margin': np.float64(0.7570815081561904),
#     'operating_margin': np.float64(0.6320364408373867),
#     'net_margin': np.float64(0.1808532960683669),
#     'debt_equity': np.float64(1.0475669775251273),
#     'interest_coverage': np.float64(2.0234432912631317),
#     'asset_turnover': np.float64(3.234804131397151),
#     'roa': np.float64(0.5850249892987454),
#     'roe': np.float64(0.7964040393138676)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2021,
#    'metrics': {'current_ratio': np.float64(1.705065795230575),
#     'quick_ratio': np.float64(1.705065795230575),
#     'gross_margin': np.float64(0.036190131992312705),
#     'operating_margin': np.float64(-0.645849592470911),
#     'net_margin': np.float64(-1.4828070712439492),
#     'debt_equity': np.float64(1.489352259975552),
#     'interest_coverage': np.float64(-1.3247712442403285),
#     'asset_turnover': np.float64(0.6247211597221303),
#     'roa': np.float64(-0.9263409531916953),
#     'roe': np.float64(-2.149827600380422)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2022,
#    'metrics': {'current_ratio': np.float64(2.8880221437700584),
#     'quick_ratio': np.float64(2.8880221437700584),
#     'gross_margin': np.float64(0.46355089147479067),
#     'operating_margin': np.float64(-0.7773550310153549),
#     'net_margin': np.float64(-2.844341904355056),
#     'debt_equity': np.float64(1.145902657513021),
#     'interest_coverage': np.float64(-0.5798847289076459),
#     'asset_turnover': np.float64(0.35425196482946286),
#     'roa': np.float64(-1.0076137082645549),
#     'roe': np.float64(-2.4682502584760235)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2023,
#    'metrics': {'current_ratio': np.float64(4.923702527898028),
#     'quick_ratio': np.float64(4.923702527898028),
#     'gross_margin': np.float64(-0.11390166943340603),
#     'operating_margin': np.float64(-0.41496528435997965),
#     'net_margin': np.float64(-1.5468585844806295),
#     'debt_equity': np.float64(0.9426738069314495),
#     'interest_coverage': np.float64(-0.3848879737836593),
#     'asset_turnover': np.float64(0.38154533353184256),
#     'roa': np.float64(-0.5901966745422557),
#     'roe': np.float64(-1.7612566839121644)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2020,
#    'metrics': {'current_ratio': np.float64(2.6595517030991243),
#     'quick_ratio': np.float64(2.6595517030991243),
#     'gross_margin': np.float64(0.7615568333804935),
#     'operating_margin': np.float64(0.5005495913726487),
#     'net_margin': np.float64(0.1743594460892191),
#     'debt_equity': np.float64(0.9334139689971799),
#     'interest_coverage': np.float64(1.7170438831816865),
#     'asset_turnover': np.float64(0.982691925376737),
#     'roa': np.float64(0.17134161978503612),
#     'roe': np.float64(0.43850881020066296)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2021,
#    'metrics': {'current_ratio': np.float64(0.561032784219196),
#     'quick_ratio': np.float64(0.561032784219196),
#     'gross_margin': np.float64(0.9458410901437198),
#     'operating_margin': np.float64(0.5649557985018869),
#     'net_margin': np.float64(-0.04403853116841385),
#     'debt_equity': np.float64(1.0512095331783222),
#     'interest_coverage': np.float64(1.9469377656975635),
#     'asset_turnover': np.float64(2.9958220772873867),
#     'roa': np.float64(-0.1319316039256429),
#     'roe': np.float64(-0.10333263434460556)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2022,
#    'metrics': {'current_ratio': np.float64(1.497355441654077),
#     'quick_ratio': np.float64(1.497355441654077),
#     'gross_margin': np.float64(0.6689321263372527),
#     'operating_margin': np.float64(-0.04577331706518147),
#     'net_margin': np.float64(-0.43930163886447265),
#     'debt_equity': np.float64(9.052038324909445),
#     'interest_coverage': np.float64(-0.2615676420299185),
#     'asset_turnover': np.float64(1.1311255947841239),
#     'roa': np.float64(-0.496905327550217),
#     'roe': np.float64(-6.333509146352113)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2023,
#    'metrics': {'current_ratio': np.float64(2.820819828360691),
#     'quick_ratio': np.float64(2.820819828360691),
#     'gross_margin': np.float64(0.2183365393189722),
#     'operating_margin': np.float64(-0.05100050814518515),
#     'net_margin': np.float64(-1.0075802805697454),
#     'debt_equity': np.float64(0.6654615509665709),
#     'interest_coverage': np.float64(-0.13251534735104648),
#     'asset_turnover': np.float64(0.7573690860405826),
#     'roa': np.float64(-0.7631101562076219),
#     'roe': np.float64(-1.3711091199201195)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2020,
#    'metrics': {'current_ratio': np.float64(0.9865731878822),
#     'quick_ratio': np.float64(0.9865731878822),
#     'gross_margin': np.float64(0.48323157541916334),
#     'operating_margin': np.float64(0.26659873471846185),
#     'net_margin': np.float64(-0.08069130977892434),
#     'debt_equity': np.float64(2.3412518134993867),
#     'interest_coverage': np.float64(2.1728832068686335),
#     'asset_turnover': np.float64(1.1769195025013348),
#     'roa': np.float64(-0.09496717616119273),
#     'roe': np.float64(-0.2871865477026018)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2021,
#    'metrics': {'current_ratio': np.float64(0.26879146143204413),
#     'quick_ratio': np.float64(0.26879146143204413),
#     'gross_margin': np.float64(-0.10620507243479971),
#     'operating_margin': np.float64(-0.7397205567652724),
#     'net_margin': np.float64(-2.11117805572711),
#     'debt_equity': np.float64(1.2932004023982646),
#     'interest_coverage': np.float64(-0.6429647536528281),
#     'asset_turnover': np.float64(1.1501651976694978),
#     'roa': np.float64(-2.428203525780877),
#     'roe': np.float64(-2.3442004418046682)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2022,
#    'metrics': {'current_ratio': np.float64(3.984205868573114),
#     'quick_ratio': np.float64(3.984205868573114),
#     'gross_margin': np.float64(0.7304995383252916),
#     'operating_margin': np.float64(0.4703583867876457),
#     'net_margin': np.float64(-0.09334803982215213),
#     'debt_equity': np.float64(1.1926658130896073),
#     'interest_coverage': np.float64(2.9276479739936097),
#     'asset_turnover': np.float64(1.6391282858217209),
#     'roa': np.float64(-0.15300941249850197),
#     'roe': np.float64(-0.6394616910210652)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2023,
#    'metrics': {'current_ratio': np.float64(0.6057853424475104),
#     'quick_ratio': np.float64(0.6057853424475104),
#     'gross_margin': np.float64(0.8045170831549584),
#     'operating_margin': np.float64(0.6851559001305129),
#     'net_margin': np.float64(-0.03111315263977513),
#     'debt_equity': np.float64(2.129646453152001),
#     'interest_coverage': np.float64(2.1585751198589107),
#     'asset_turnover': np.float64(3.7809784354566274),
#     'roa': np.float64(-0.11763815919006021),
#     'roe': np.float64(-0.14313859119660216)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'}],
#  'trend': [{'engine': 'trend_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2023,
#    'metrics': {'ratio': 'current_ratio',
#     'trend_value': np.float64(3.0852438731916987),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.False_},
#    'severity': 'stable',
#    'explanation': 'current_ratio trend stable or improving.'},
#   {'engine': 'trend_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2023,
#    'metrics': {'ratio': 'gross_margin',
#     'trend_value': np.float64(-0.09595568047712277),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.True_},
#    'severity': 'watch',
#    'explanation': 'Negative trend observed in gross_margin.'},
#   {'engine': 'trend_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2023,
#    'metrics': {'ratio': 'net_margin',
#     'trend_value': np.float64(1.728338656069937),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.False_},
#    'severity': 'stable',
#    'explanation': 'net_margin trend stable or improving.'},
#   {'engine': 'trend_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2023,
#    'metrics': {'ratio': 'asset_turnover',
#     'trend_value': np.float64(1.2649629371488276),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.False_},
#    'severity': 'stable',
#    'explanation': 'asset_turnover trend stable or improving.'},
#   {'engine': 'trend_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2023,
#    'metrics': {'ratio': 'debt_equity',
#     'trend_value': np.float64(0.4940185735182224),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.False_},
#    'severity': 'stable',
#    'explanation': 'debt_equity trend stable or improving.'},
#   {'engine': 'trend_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2023,
#    'metrics': {'ratio': 'roe',
#     'trend_value': np.float64(3.157878313955056),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.False_},
#    'severity': 'stable',
#    'explanation': 'roe trend stable or improving.'},
#   {'engine': 'trend_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2023,
#    'metrics': {'ratio': 'current_ratio',
#     'trend_value': np.float64(2.410165414800442),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.False_},
#    'severity': 'stable',
#    'explanation': 'current_ratio trend stable or improving.'},
#   {'engine': 'trend_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2023,
#    'metrics': {'ratio': 'gross_margin',
#     'trend_value': np.float64(-0.8709831775895964),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.True_},
#    'severity': 'watch',
#    'explanation': 'Negative trend observed in gross_margin.'},
#   {'engine': 'trend_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2023,
#    'metrics': {'ratio': 'net_margin',
#     'trend_value': np.float64(-1.7277118805489964),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.True_},
#    'severity': 'watch',
#    'explanation': 'Negative trend observed in net_margin.'},
#   {'engine': 'trend_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2023,
#    'metrics': {'ratio': 'asset_turnover',
#     'trend_value': np.float64(-2.8532587978653083),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.True_},
#    'severity': 'watch',
#    'explanation': 'Negative trend observed in asset_turnover.'},
#   {'engine': 'trend_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2023,
#    'metrics': {'ratio': 'debt_equity',
#     'trend_value': np.float64(-0.10489317059367775),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.True_},
#    'severity': 'watch',
#    'explanation': 'Negative trend observed in debt_equity.'},
#   {'engine': 'trend_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2023,
#    'metrics': {'ratio': 'roe',
#     'trend_value': np.float64(-2.557660723226032),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.True_},
#    'severity': 'watch',
#    'explanation': 'Negative trend observed in roe.'},
#   {'engine': 'trend_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2023,
#    'metrics': {'ratio': 'current_ratio',
#     'trend_value': np.float64(0.16126812526156664),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.False_},
#    'severity': 'stable',
#    'explanation': 'current_ratio trend stable or improving.'},
#   {'engine': 'trend_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2023,
#    'metrics': {'ratio': 'gross_margin',
#     'trend_value': np.float64(-0.5432202940615213),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.True_},
#    'severity': 'watch',
#    'explanation': 'Negative trend observed in gross_margin.'},
#   {'engine': 'trend_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2023,
#    'metrics': {'ratio': 'net_margin',
#     'trend_value': np.float64(-1.1819397266589644),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.True_},
#    'severity': 'watch',
#    'explanation': 'Negative trend observed in net_margin.'},
#   {'engine': 'trend_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2023,
#    'metrics': {'ratio': 'asset_turnover',
#     'trend_value': np.float64(-0.22532283933615438),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.True_},
#    'severity': 'watch',
#    'explanation': 'Negative trend observed in asset_turnover.'},
#   {'engine': 'trend_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2023,
#    'metrics': {'ratio': 'debt_equity',
#     'trend_value': np.float64(-0.267952418030609),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.True_},
#    'severity': 'watch',
#    'explanation': 'Negative trend observed in debt_equity.'},
#   {'engine': 'trend_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2023,
#    'metrics': {'ratio': 'roe',
#     'trend_value': np.float64(-1.8096179301207824),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.True_},
#    'severity': 'watch',
#    'explanation': 'Negative trend observed in roe.'},
#   {'engine': 'trend_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2023,
#    'metrics': {'ratio': 'current_ratio',
#     'trend_value': np.float64(-0.3807878454346897),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.True_},
#    'severity': 'watch',
#    'explanation': 'Negative trend observed in current_ratio.'},
#   {'engine': 'trend_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2023,
#    'metrics': {'ratio': 'gross_margin',
#     'trend_value': np.float64(0.32128550773579506),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.False_},
#    'severity': 'stable',
#    'explanation': 'gross_margin trend stable or improving.'},
#   {'engine': 'trend_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2023,
#    'metrics': {'ratio': 'net_margin',
#     'trend_value': np.float64(0.04957815713914922),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.False_},
#    'severity': 'stable',
#    'explanation': 'net_margin trend stable or improving.'},
#   {'engine': 'trend_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2023,
#    'metrics': {'ratio': 'asset_turnover',
#     'trend_value': np.float64(2.604058932955293),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.False_},
#    'severity': 'stable',
#    'explanation': 'asset_turnover trend stable or improving.'},
#   {'engine': 'trend_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2023,
#    'metrics': {'ratio': 'debt_equity',
#     'trend_value': np.float64(-0.21160536034738575),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.True_},
#    'severity': 'watch',
#    'explanation': 'Negative trend observed in debt_equity.'},
#   {'engine': 'trend_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2023,
#    'metrics': {'ratio': 'roe',
#     'trend_value': np.float64(0.14404795650599966),
#     'from_year': 2020,
#     'to_year': 2023},
#    'flags': {'deteriorating_trend': np.False_},
#    'severity': 'stable',
#    'explanation': 'roe trend stable or improving.'}],
#  'cash_flow': [{'engine': 'cash_flow_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': np.int64(2020),
#    'metrics': {'operating_profit': np.int64(813322),
#     'coverage_proxy': np.float64(0.2776502541217982)},
#    'flags': {'negative_operating_profit': np.False_,
#     'weak_coverage': np.True_},
#    'severity': 'watch',
#    'explanation': 'Cash generation shows signs of pressure and warrants monitoring.'},
#   {'engine': 'cash_flow_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': np.int64(2021),
#    'metrics': {'operating_profit': np.int64(920171),
#     'coverage_proxy': np.float64(0.38882463675949536)},
#    'flags': {'negative_operating_profit': np.False_,
#     'weak_coverage': np.True_},
#    'severity': 'watch',
#    'explanation': 'Cash generation shows signs of pressure and warrants monitoring.'},
#   {'engine': 'cash_flow_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': np.int64(2022),
#    'metrics': {'operating_profit': np.int64(6116894),
#     'coverage_proxy': np.float64(2.4466303752204883)},
#    'flags': {'negative_operating_profit': np.False_,
#     'weak_coverage': np.False_},
#    'severity': 'stable',
#    'explanation': 'Operating activities appear sufficient to sustain financing needs.'},
#   {'engine': 'cash_flow_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': np.int64(2023),
#    'metrics': {'operating_profit': np.int64(4614813),
#     'coverage_proxy': np.float64(2.003210910410521)},
#    'flags': {'negative_operating_profit': np.False_,
#     'weak_coverage': np.False_},
#    'severity': 'stable',
#    'explanation': 'Operating activities appear sufficient to sustain financing needs.'},
#   {'engine': 'cash_flow_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': np.int64(2020),
#    'metrics': {'operating_profit': np.int64(5879677),
#     'coverage_proxy': np.float64(2.0234432912631317)},
#    'flags': {'negative_operating_profit': np.False_,
#     'weak_coverage': np.False_},
#    'severity': 'stable',
#    'explanation': 'Operating activities appear sufficient to sustain financing needs.'},
#   {'engine': 'cash_flow_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': np.int64(2021),
#    'metrics': {'operating_profit': np.int64(-1401037),
#     'coverage_proxy': np.float64(-1.3247712442403285)},
#    'flags': {'negative_operating_profit': np.True_, 'weak_coverage': np.True_},
#    'severity': 'action',
#    'explanation': 'Operating activities do not appear to generate sufficient cash to cover financing obligations.'},
#   {'engine': 'cash_flow_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': np.int64(2022),
#    'metrics': {'operating_profit': np.int64(-1457571),
#     'coverage_proxy': np.float64(-0.5798847289076459)},
#    'flags': {'negative_operating_profit': np.True_, 'weak_coverage': np.True_},
#    'severity': 'action',
#    'explanation': 'Operating activities do not appear to generate sufficient cash to cover financing obligations.'},
#   {'engine': 'cash_flow_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': np.int64(2023),
#    'metrics': {'operating_profit': np.int64(-936897),
#     'coverage_proxy': np.float64(-0.3848879737836593)},
#    'flags': {'negative_operating_profit': np.True_, 'weak_coverage': np.True_},
#    'severity': 'action',
#    'explanation': 'Operating activities do not appear to generate sufficient cash to cover financing obligations.'},
#   {'engine': 'cash_flow_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': np.int64(2020),
#    'metrics': {'operating_profit': np.int64(3003709),
#     'coverage_proxy': np.float64(1.7170438831816865)},
#    'flags': {'negative_operating_profit': np.False_,
#     'weak_coverage': np.False_},
#    'severity': 'stable',
#    'explanation': 'Operating activities appear sufficient to sustain financing needs.'},
#   {'engine': 'cash_flow_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': np.int64(2021),
#    'metrics': {'operating_profit': np.int64(3438956),
#     'coverage_proxy': np.float64(1.9469377656975635)},
#    'flags': {'negative_operating_profit': np.False_,
#     'weak_coverage': np.False_},
#    'severity': 'stable',
#    'explanation': 'Operating activities appear sufficient to sustain financing needs.'},
#   {'engine': 'cash_flow_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': np.int64(2022),
#    'metrics': {'operating_profit': np.int64(-188929),
#     'coverage_proxy': np.float64(-0.2615676420299185)},
#    'flags': {'negative_operating_profit': np.True_, 'weak_coverage': np.True_},
#    'severity': 'action',
#    'explanation': 'Operating activities do not appear to generate sufficient cash to cover financing obligations.'},
#   {'engine': 'cash_flow_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': np.int64(2023),
#    'metrics': {'operating_profit': np.int64(-180157),
#     'coverage_proxy': np.float64(-0.13251534735104648)},
#    'flags': {'negative_operating_profit': np.True_, 'weak_coverage': np.True_},
#    'severity': 'action',
#    'explanation': 'Operating activities do not appear to generate sufficient cash to cover financing obligations.'},
#   {'engine': 'cash_flow_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': np.int64(2020),
#    'metrics': {'operating_profit': np.int64(1269444),
#     'coverage_proxy': np.float64(2.1728832068686335)},
#    'flags': {'negative_operating_profit': np.False_,
#     'weak_coverage': np.False_},
#    'severity': 'stable',
#    'explanation': 'Operating activities appear sufficient to sustain financing needs.'},
#   {'engine': 'cash_flow_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': np.int64(2021),
#    'metrics': {'operating_profit': np.int64(-1813385),
#     'coverage_proxy': np.float64(-0.6429647536528281)},
#    'flags': {'negative_operating_profit': np.True_, 'weak_coverage': np.True_},
#    'severity': 'action',
#    'explanation': 'Operating activities do not appear to generate sufficient cash to cover financing obligations.'},
#   {'engine': 'cash_flow_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': np.int64(2022),
#    'metrics': {'operating_profit': np.int64(3364617),
#     'coverage_proxy': np.float64(2.9276479739936097)},
#    'flags': {'negative_operating_profit': np.False_,
#     'weak_coverage': np.False_},
#    'severity': 'stable',
#    'explanation': 'Operating activities appear sufficient to sustain financing needs.'},
#   {'engine': 'cash_flow_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': np.int64(2023),
#    'metrics': {'operating_profit': np.int64(4999832),
#     'coverage_proxy': np.float64(2.1585751198589107)},
#    'flags': {'negative_operating_profit': np.False_,
#     'weak_coverage': np.False_},
#    'severity': 'stable',
#    'explanation': 'Operating activities appear sufficient to sustain financing needs.'}],
#  'anomaly': [{'engine': 'anomaly_efficiency_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2020,
#    'metrics': {'roa_yoy': nan},
#    'flags': {'roa_shock': False},
#    'severity': 'normal',
#    'explanation': 'Efficiency metrics stable.'},
#   {'engine': 'anomaly_efficiency_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2021,
#    'metrics': {'roa_yoy': -0.43895976898339906},
#    'flags': {'roa_shock': True},
#    'severity': 'watch',
#    'explanation': 'Abnormal efficiency change detected.'},
#   {'engine': 'anomaly_efficiency_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2022,
#    'metrics': {'roa_yoy': -1.9886463222225026},
#    'flags': {'roa_shock': True},
#    'severity': 'watch',
#    'explanation': 'Abnormal efficiency change detected.'},
#   {'engine': 'anomaly_efficiency_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2023,
#    'metrics': {'roa_yoy': -0.40398375974513856},
#    'flags': {'roa_shock': True},
#    'severity': 'watch',
#    'explanation': 'Abnormal efficiency change detected.'},
#   {'engine': 'anomaly_efficiency_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2020,
#    'metrics': {'roa_yoy': nan},
#    'flags': {'roa_shock': False},
#    'severity': 'normal',
#    'explanation': 'Efficiency metrics stable.'},
#   {'engine': 'anomaly_efficiency_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2021,
#    'metrics': {'roa_yoy': -2.58342117026843},
#    'flags': {'roa_shock': True},
#    'severity': 'watch',
#    'explanation': 'Abnormal efficiency change detected.'},
#   {'engine': 'anomaly_efficiency_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2022,
#    'metrics': {'roa_yoy': 0.08773524995611548},
#    'flags': {'roa_shock': False},
#    'severity': 'normal',
#    'explanation': 'Efficiency metrics stable.'},
#   {'engine': 'anomaly_efficiency_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2023,
#    'metrics': {'roa_yoy': -0.4142629564272501},
#    'flags': {'roa_shock': True},
#    'severity': 'watch',
#    'explanation': 'Abnormal efficiency change detected.'},
#   {'engine': 'anomaly_efficiency_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2020,
#    'metrics': {'roa_yoy': nan},
#    'flags': {'roa_shock': False},
#    'severity': 'normal',
#    'explanation': 'Efficiency metrics stable.'},
#   {'engine': 'anomaly_efficiency_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2021,
#    'metrics': {'roa_yoy': -1.7699915764258751},
#    'flags': {'roa_shock': True},
#    'severity': 'watch',
#    'explanation': 'Abnormal efficiency change detected.'},
#   {'engine': 'anomaly_efficiency_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2022,
#    'metrics': {'roa_yoy': 2.7663858602846556},
#    'flags': {'roa_shock': False},
#    'severity': 'normal',
#    'explanation': 'Efficiency metrics stable.'},
#   {'engine': 'anomaly_efficiency_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2023,
#    'metrics': {'roa_yoy': 0.5357254468770059},
#    'flags': {'roa_shock': False},
#    'severity': 'normal',
#    'explanation': 'Efficiency metrics stable.'},
#   {'engine': 'anomaly_efficiency_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2020,
#    'metrics': {'roa_yoy': nan},
#    'flags': {'roa_shock': False},
#    'severity': 'normal',
#    'explanation': 'Efficiency metrics stable.'},
#   {'engine': 'anomaly_efficiency_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2021,
#    'metrics': {'roa_yoy': 24.56887151892735},
#    'flags': {'roa_shock': False},
#    'severity': 'normal',
#    'explanation': 'Efficiency metrics stable.'},
#   {'engine': 'anomaly_efficiency_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2022,
#    'metrics': {'roa_yoy': -0.9369865784008792},
#    'flags': {'roa_shock': True},
#    'severity': 'watch',
#    'explanation': 'Abnormal efficiency change detected.'},
#   {'engine': 'anomaly_efficiency_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2023,
#    'metrics': {'roa_yoy': -0.23117044063408887},
#    'flags': {'roa_shock': False},
#    'severity': 'normal',
#    'explanation': 'Efficiency metrics stable.'}],
#  'solvency': [{'engine': 'solvency_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2020,
#    'metrics': {'debt_equity': 0.9825237035626188,
#     'interest_coverage': 0.2776502541217982},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2021,
#    'metrics': {'debt_equity': 1.3584280927054282,
#     'interest_coverage': 0.38882463675949536},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2022,
#    'metrics': {'debt_equity': 0.6969581313037093,
#     'interest_coverage': 2.4466303752204883},
#    'flags': {'high_leverage': False, 'weak_coverage': False},
#    'severity': 'stable',
#    'explanation': 'Solvency position acceptable.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Acme Manufacturing Ltd',
#    'Year': 2023,
#    'metrics': {'debt_equity': 1.4765422770808412,
#     'interest_coverage': 2.003210910410521},
#    'flags': {'high_leverage': False, 'weak_coverage': False},
#    'severity': 'stable',
#    'explanation': 'Solvency position acceptable.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2020,
#    'metrics': {'debt_equity': 1.0475669775251273,
#     'interest_coverage': 2.0234432912631317},
#    'flags': {'high_leverage': False, 'weak_coverage': False},
#    'severity': 'stable',
#    'explanation': 'Solvency position acceptable.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2021,
#    'metrics': {'debt_equity': 1.489352259975552,
#     'interest_coverage': -1.3247712442403285},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2022,
#    'metrics': {'debt_equity': 1.145902657513021,
#     'interest_coverage': -0.5798847289076459},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Banyan Retail Co',
#    'Year': 2023,
#    'metrics': {'debt_equity': 0.9426738069314495,
#     'interest_coverage': -0.3848879737836593},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2020,
#    'metrics': {'debt_equity': 0.9334139689971799,
#     'interest_coverage': 1.7170438831816865},
#    'flags': {'high_leverage': False, 'weak_coverage': False},
#    'severity': 'stable',
#    'explanation': 'Solvency position acceptable.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2021,
#    'metrics': {'debt_equity': 1.0512095331783222,
#     'interest_coverage': 1.9469377656975635},
#    'flags': {'high_leverage': False, 'weak_coverage': False},
#    'severity': 'stable',
#    'explanation': 'Solvency position acceptable.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2022,
#    'metrics': {'debt_equity': 9.052038324909445,
#     'interest_coverage': -0.2615676420299185},
#    'flags': {'high_leverage': True, 'weak_coverage': True},
#    'severity': 'action',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Coastal Tech Ltd',
#    'Year': 2023,
#    'metrics': {'debt_equity': 0.6654615509665709,
#     'interest_coverage': -0.13251534735104648},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2020,
#    'metrics': {'debt_equity': 2.3412518134993867,
#     'interest_coverage': 2.1728832068686335},
#    'flags': {'high_leverage': True, 'weak_coverage': False},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2021,
#    'metrics': {'debt_equity': 1.2932004023982646,
#     'interest_coverage': -0.6429647536528281},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2022,
#    'metrics': {'debt_equity': 1.1926658130896073,
#     'interest_coverage': 2.9276479739936097},
#    'flags': {'high_leverage': False, 'weak_coverage': False},
#    'severity': 'stable',
#    'explanation': 'Solvency position acceptable.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Emerald Energy Inc',
#    'Year': 2023,
#    'metrics': {'debt_equity': 2.129646453152001,
#     'interest_coverage': 2.1585751198589107},
#    'flags': {'high_leverage': True, 'weak_coverage': False},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'}],
#  'composite_risk': [{'Company': 'Acme Manufacturing Ltd',
#    'Year': 2023,
#    'composite_score': 0,
#    'risk_band': 'low'},
#   {'Company': 'Banyan Retail Co',
#    'Year': 2023,
#    'composite_score': 0.25,
#    'risk_band': 'low'},
#   {'Company': 'Coastal Tech Ltd',
#    'Year': 2023,
#    'composite_score': 0.25,
#    'risk_band': 'low'},
#   {'Company': 'Emerald Energy Inc',
#    'Year': 2023,
#    'composite_score': 0,
#    'risk_band': 'low'}],
#  'ai_interpretation': [{'Company': 'Acme Manufacturing Ltd',
#    'Year': 2020,
#    'analysis_profile': None,
#    'interpretation': 'summary:\nAcme Manufacturing Ltd — 2020 financial diagnostic. The company reports adequate short-term liquidity on a raw basis (current_ratio 1.59; quick_ratio equal), a high gross margin (86.74%) and a positive operating margin (28.91%). Material concerns are present below operating profit: a negative net margin (−154.61%), negative returns (ROA −108.32%, ROE −202.06%), low interest coverage (0.28x), and leverage approaching or above conservative tolerance (debt_equity 0.98x). Asset turnover is moderate (0.70x). The combination indicates operating profitability is not translating into net earnings after financing, tax, or other non-operating items. The results warrant targeted review of non-operating charges, financing costs, and one-time items.\n\nkey_risks:\n- Net profitability risk: net_margin = −1.546 (−154.61%). Conservative threshold: net margin < 0 (loss). Highlighted: metric exceeds conservative threshold (negative), indicating a net loss for the year despite positive gross and operating margins.\n- Solvency / coverage risk: interest_coverage = 0.2777x. Conservative threshold: interest_coverage < 3.0x signals weak cushion; interest_coverage < 1.0x indicates inability to cover interest from operating earnings. Highlighted: metric materially exceeds conservative risk thresholds (below 1.0x), indicating operating income is insufficient to cover interest expense.\n- Leverage risk: debt_equity = 0.9825. Conservative threshold: debt_equity > 1.0x often increases financial strain; many conservative assessments use 0.5–1.0 as an upper bound. Highlighted: metric is at or near a conservative upper bound (≈0.98x), increasing sensitivity to earnings volatility and interest cost.\n- Returns and capital efficiency risk: ROA = −1.0832 (−108.32%), ROE = −2.0206 (−202.06%). Conservative threshold: ROA/ROE should be positive; negative values are highlighted as they indicate destruction of asset and shareholder value in 2020.\n- Earnings quality / non-operating items risk: Significant divergence between operating_margin = 0.2891 (28.91%) and net_margin = −1.546 (−154.61%). Highlighted: this divergence indicates substantial non-operating charges, financing costs, taxes, or one-off items materially impacting net result and warrants forensic review.\n\nrecommendations:\n- Immediate forensic review of income statement items below operating profit: isolate and quantify interest expense, one-time non-operating losses, impairment charges, tax items, and exceptional items to explain the large gap between operating margin and net margin.\n- Engage with lenders and treasury to assess interest expense profile and refinancing options. Given interest_coverage <1.0x and near-1.0 debt/equity, evaluate covenant risk, available headroom, and options to reduce interest burden (refinancing, interest-rate swaps, covenant waivers).\n- Short-term cash and working capital management: maintain liquidity given moderate current_ratio (1.59). Stress-test liquidity under downside scenarios and prepare a prioritized cash preservation plan (AR collection acceleration, discretionary CapEx deferral, inventory reduction).\n- Capital structure assessment: consider scenarios to reduce leverage or shore up equity (equity injection, asset disposals, or retained earnings recovery plan). Model impact on interest coverage and solvency metrics under conservative assumptions.\n- Operational control: review drivers of gross margin sustainability and asset turnover improvements. While gross and operating margins are strong, ensure these are sustainable and not distorted by pricing or input timing.\n- Reporting and governance: improve monthly reporting of non-operating items and covenant monitoring. Present clear management explanation of 2020 net loss and remedial action plans to stakeholders and lenders.\n\nconfidence_notes:\n- Analysis is based solely on the provided ratio values for 2020. No underlying financial statements, notes, or comparative periods w ...
#   {'Company': 'Acme Manufacturing Ltd',
#    'Year': 2021,
#    'analysis_profile': None,
#    'interpretation': 'summary\nAcme Manufacturing Ltd — 2021 financial diagnostic. Liquidity ratios indicate ample short-term coverage (current and quick ratios both 3.08). Profitability and returns are mixed: an unusually high gross margin (85.49%) and a positive operating margin (21.22%) contrast with a materially negative net margin (-78.71%), negative return on assets (-60.77%) and negative return on equity (-213.22%). Leverage appears elevated (debt-to-equity 1.36) while interest coverage is well below conservative comfort levels (0.39). Asset turnover is below 1 (0.77). The combination suggests operating profitability before non-operating items and finance costs, but serious losses at the net level and strained ability to service debt.\n\nkey_risks\n- Interest coverage breach: interest_coverage = 0.389 — materially below conservative coverage levels (commonly regarded as >=3 for conservative assessments). This indicates inadequate operating income to cover interest expense.\n- Leverage concern: debt_equity = 1.358 — exceeds a conservative threshold of 1.0, indicating higher reliance on debt financing relative to equity.\n- Net profitability failure: net_margin = -0.787 — negative net margin indicates the company is losing money after non-operating items, taxes and finance costs.\n- Returns impairment: roa = -0.608 and roe = -2.132 — both are negative and signal that asset and equity holders are experiencing losses rather than returns.\n- Liquidity and operational mismatch risk: current_ratio and quick_ratio = 3.079 — while indicating strong short-term coverage, such high ratios may reflect underutilized assets or working capital inefficiencies if not explained by seasonality or other factors. (Flagged for review rather than classified as positive without context.)\n- Concentration of margin drivers: gross_margin = 0.8549 and operating_margin = 0.2122 — large divergence between operating profitability and net loss suggests significant non-operating expenses, one-off charges, finance costs, or tax effects that require immediate audit-level investigation.\n\nrecommendations\n- Immediate review of non-operating items and finance costs: reconcile the components causing the large gap between operating profit and net loss (interest expense, one-time impairments, restructuring, tax adjustments). Provide supporting schedules and explanations.\n- Reassess debt structure and serviceability: given interest_coverage <1 and debt_equity >1, produce a debt maturity schedule, covenant status report, and cash flow projections under conservative scenarios to evaluate refinancing or restructuring needs.\n- Validate gross margin drivers: substantiate the unusually high gross margin with detailed cost and revenue analyses (pricing, cost allocation, inventory valuation methods) to rule out accounting anomalies.\n- Working capital optimization review: investigate accounts receivable, inventory, and accounts payable composition to determine why liquidity ratios are high and whether working capital can be deployed more efficiently.\n- Sensitivity and solvency analysis: prepare short-term (3–12 month) cash-flow forecasts and stress tests (e.g., lower sales, higher interest rates) to quantify solvency risk and inform contingency planning.\n- Audit documentation: ensure all significant adjustments, impairments, and related-party transactions that materially affect net income or leverage are fully documented and supported.\n\nconfidence_notes\n- Assessment is based solely on the provided ratios for the 2021 year. No raw financial statements, notes, or trend data were reviewed.\n- Thresholds cited are conservative benchmarks used for this diagnostic; they are stated explicitly where applied.\n- Recommendations are prescriptive for investigative and audit work but do not quantify remediation costs or likelihoods. Further analysis of source documents and management explanations is required to reach audit conclusions.'},
#   {'Company': 'Acme Manufacturing Ltd',
#    'Year': 2022,
#    'analysis_profile': None,
#    'interpretation': 'summary:\nAcme Manufacturing Ltd (2022) presents very strong liquidity and profitability metrics alongside moderate leverage. Key reported ratios: current_ratio 3.41, quick_ratio 3.41, gross_margin 96.83%, operating_margin 68.03%, net_margin 30.19%, debt_equity 0.70, interest_coverage 2.45, asset_turnover 1.99, return_on_assets (ROA) 60.08%, return_on_equity (ROE) 154.84%. These figures indicate high margins and efficient asset use in 2022 and a conservative balance of debt relative to equity; however interest coverage is below commonly used conservative benchmarks for comfortable coverage.\n\nkey_risks:\n- Interest coverage shortfall: interest_coverage = 2.45. Conservative practice typically regards interest_coverage < 3.0 as a potential liquidity/stress risk for servicing interest in adverse conditions. This metric is highlighted as exceeding a conservative risk threshold.\n- Very high profitability concentration: gross_margin (96.83%), operating_margin (68.03%), net_margin (30.19%), ROA (60.08%), and ROE (154.84%) materially exceed typical conservative profitability expectations. These metrics are explicitly highlighted as exceeding conservative thresholds for margin and return metrics; unusually high values warrant scrutiny for one-off items, accounting classifications, or non-recurring influences (note: no further data provided to confirm causes).\n- Liquidity-excess inefficiency risk: current_ratio and quick_ratio = 3.41. While liquidity is strong, conservative thresholds often consider ratios materially above 2.0 as potential indicators of inefficient capital deployment. This is highlighted as exceeding a conservative efficiency threshold.\n- Leverage and solvency balance: debt_equity = 0.70 indicates moderate leverage beneath higher-risk levels (>1.0), but given the interest_coverage shortfall, the company may face constrained flexibility if earnings decline.\n\nrecommendations:\n- Investigate drivers of elevated margins and returns: perform detailed audit procedures on revenue recognition, cost classifications, and any non-recurring items to confirm sustainability and appropriateness of margin and ROA/ROE levels.\n- Review interest expense and financing profile: assess near-term debt maturities, fixed vs. variable interest exposures, and contingency plans to improve interest_coverage above conservative thresholds (target > 3.0 under conservative practice).\n- Consider capital deployment options: given high liquidity (current_ratio/quick_ratio = 3.41), evaluate opportunities to optimize working capital or deploy excess cash toward productive uses while preserving adequate buffers.\n- Monitor covenant and stress scenarios: run sensitivity analyses on operating income and interest expense to quantify impact on interest_coverage and solvency under downside scenarios.\n- Document and disclose: ensure clear disclosure in financial statements concerning any items that materially affect margins or returns (for example, non-recurring gains, accounting policy elections), supported by audit evidence.\n\nconfidence_notes:\n- Assessment is limited to the provided 2022 ratio set and does not incorporate source financial statements, notes, or subsequent-period data.\n- Statements are based solely on the supplied metrics; no external data, trend analysis, or additional metrics were used or inferred.\n- Where conservative thresholds are referenced (e.g., interest_coverage 3.0, current_ratio 2.0), these reflect common conservative benchmarks for audit and financial-risk review and are applied for the purpose of highlighting items that merit further inquiry.'},
#   {'Company': 'Acme Manufacturing Ltd',
#    'Year': 2023,
#    'analysis_profile': None,
# ...
#   {'Company': 'Emerald Energy Inc',
#    'Year': 2020,
#    'analysis_profile': None,
#    'interpretation': 'summary\nEmerald Energy Inc. — Fiscal Year 2020: The company reported healthy gross (48.3%) and operating (26.7%) margins, and reasonable asset turnover (1.18). However, profitability at the bottom line is negative (net margin -8.07%), and returns are negative (ROA -9.50%, ROE -28.72%). Liquidity measures are below conservative benchmarks (current ratio and quick ratio both 0.99). Leverage is elevated (debt-to-equity 2.34) while interest coverage is modest (2.17). Overall, operating efficiency appears sound but capital structure and bottom-line profitability present material concerns for stakeholders.\n\nkey_risks\n- Liquidity shortfall: Current ratio = 0.99 and Quick ratio = 0.99. Both are below a conservative benchmark of 1.0, indicating limited near-term liquidity cushion to meet current obligations.\n- Elevated leverage: Debt-to-equity = 2.34, which exceeds a conservative leverage reference of 2.0. High leverage increases financial risk and sensitivity to adverse cash-flow changes.\n- Weak interest protection: Interest coverage = 2.17, which is below conservative comfort levels (commonly 3.0). This indicates limited ability to absorb earnings volatility while covering interest expense.\n- Loss-making at net level: Net margin = -8.07% and negative ROA (-9.50%) and ROE (-28.72%), indicating the company did not generate net income in 2020 and produced negative returns on assets and equity. This raises concerns about capital preservation and shareholder value.\n- Concentration of risk between operations and financing: While gross and operating margins are relatively strong, the combination of negative net income and high leverage suggests financing costs and/or non-operating items materially eroded operating profitability.\n\nrecommendations\n- Short-term liquidity management: Implement measures to improve current assets or reduce current liabilities (e.g., cash preservation, renegotiation of short-term payables, or conversion of short-term debt to longer maturities). Prioritize actions that raise the current and quick ratios above 1.0.\n- Deleveraging strategy: Evaluate options to reduce leverage, such as directed debt repayments, refinancing to longer-term maturities, or selective asset disposals. Model the impact of different deleveraging scenarios on interest coverage and solvency metrics.\n- Improve interest coverage: Pursue cost of debt reduction through refinancing or covenant renegotiation and protect operating income through margin preservation actions to increase the interest coverage ratio toward conservative levels (around 3.0).\n- Restore profitability: Conduct a focused review of non-operating expenses and tax effects that contributed to the negative net margin. If losses stem from one-off items, document and disclose; if recurring, implement revenue enhancement or cost-reduction initiatives aimed at returning net margin to positive territory.\n- Enhanced monitoring and reporting: Increase frequency of cash-flow forecasting and stress testing under downside scenarios to provide early warning of covenant breaches or liquidity shortfalls. Provide transparent disclosures to lenders and investors on remediation plans.\n\nconfidence_notes\n- The analysis is based solely on the provided 2020 ratio values and standard conservative reference points cited in the key_risks and recommendations. No additional financial statement detail, notes, or subsequent period information was provided.\n- Observations avoid speculation and are conditional on the ratios supplied; detailed root-cause analysis and quantified remediation planning require full financial statements, cash-flow schedules, debt terms, and management commentary.'},
#   {'Company': 'Emerald Energy Inc',
#    'Year': 2021,
#    'analysis_profile': None,
#    'interpretation': 'summary\nEmerald Energy Inc — 2021 financial diagnostics. The company exhibits materially weak short-term liquidity (current_ratio 0.269; quick_ratio 0.269), negative profitability at all reported margins (gross_margin -10.62%, operating_margin -73.97%, net_margin -211.12%), elevated leverage (debt_equity 1.293), negative interest coverage (-0.643) and negative returns on assets and equity (roa -2.428, roe -2.344). Asset turnover is 1.150. The profile indicates constrained liquidity, substantial operating losses, leverage that increases solvency risk, and inability to cover interest expense from operating results.\n\nkey_risks\n- Short-term liquidity risk: current_ratio (0.2688) and quick_ratio (0.2688) are well below conservative liquidity thresholds (commonly 1.0), indicating limited ability to meet near-term obligations from current assets.  \n- Persistent unprofitable operations: gross_margin (-10.62%), operating_margin (-73.97%), and net_margin (-211.12%) are negative, signaling that the company is not generating margin at the gross, operating, or net levels.  \n- Leverage and solvency risk: debt_equity (1.293) exceeds conservative leverage preferences (commonly ≤1.0), increasing financial risk and potential constraints on financing options.  \n- Interest coverage shortfall: interest_coverage (-0.643) is negative, indicating operating income is insufficient to cover interest expense. This raises risk of covenant breaches and refinancing difficulty.  \n- Negative returns: roa (-2.428) and roe (-2.344) are negative, reflecting losses relative to asset and equity bases and implying value erosion for shareholders.  \n- Operational dependency on turnover: asset_turnover (1.150) is positive but insufficient to offset negative margins; reliance on high turnover with negative margins increases business risk.\n\nrecommendations\n- Immediate liquidity assessment: prepare a short-term cashflow forecast and stress test to quantify funding needs for the next 3–12 months. Prioritize preserving cash and identifying non-core asset sales or working capital improvements.  \n- Cost and margin remediation: conduct a detailed margin analysis to identify controllable cost reductions (COGS and operating expenses) and price/product actions to arrest negative gross and operating margins.  \n- Capital structure review: evaluate options to reduce leverage (debt repayment, refinancing on more favorable terms, equity issuance if feasible) and engage lenders proactively regarding covenants and refinancing timelines.  \n- Interest obligation management: model scenarios for interest expense coverage and negotiate with creditors where necessary to avoid covenant breaches. Consider interest deferral or restructuring only subject to creditor consent and legal/financial advice.  \n- Governance and monitoring: increase reporting cadence (monthly cash and covenant reporting) and implement board-level oversight of turnaround actions.  \n- External advice: consider engaging restructuring and/or financial advisory specialists to evaluate options if liquidity or solvency risks materialize.\n\nconfidence_notes\n- The analysis is based solely on the supplied 2021 ratio values. No additional financial statement detail, footnote information, industry context, or trend data was provided.  \n- Recommendations are precautionary and intended for further investigation; they do not constitute predictions. Further diagnostic work (cashflow statements, debt schedule, covenant terms, and operational detail) is necessary to quantify actions and timelines.'},
#   {'Company': 'Emerald Energy Inc',
#    'Year': 2022,
#    'analysis_profile': None,
#    'interpretation': 'summary:\nEmerald Energy Inc. — Fiscal Year 2022. The company presents strong liquidity on a balance-sheet basis (current and quick ratios ~3.98) and a high gross margin (73.05%) and operating margin (47.04%). However, profitability at the bottom line is negative (net margin -9.33%), and returns are negative (ROA -15.30%, ROE -63.95%). Leverage is meaningful (debt-to-equity 1.193) and interest coverage is marginal (2.93). Asset turnover is relatively high (1.639). Overall, liquidity and margin at the gross/operating levels are strengths; solvency, net profitability, and returns on invested capital are material areas of concern.\n\nkey_risks:\n- Liquidity concentration and operating efficiency: Current ratio and quick ratio are 3.984. These exceed a conservative upper threshold of 3.0, which may indicate excess working capital or inefficient capital deployment. Excessive liquidity can depress returns.\n- Leverage risk: Debt-to-equity is 1.193, which exceeds a conservative threshold of 1.0 and indicates meaningful reliance on debt financing relative to equity.\n- Interest-service risk: Interest coverage is 2.928, marginally below a conservative threshold of 3.0, reducing the cushion to meet interest obligations if operating performance weakens.\n- Profitability and returns: Net margin is negative (-9.33%), ROA (-15.30%) and ROE (-63.95%) are materially negative. These metrics indicate the company is not generating positive net returns on assets or equity.\n- Concentration between operational and bottom-line performance: A high gross margin (73.05%) and operating margin (47.04%) contrast with the negative net margin, pointing to non-operating items, financing costs, taxes, or exceptional items materially impacting net results. This divergence warrants detailed audit scrutiny.\n- Efficiency vs. capital structure: Asset turnover (1.639) suggests productive asset use, but this is offset by leverage and negative net profitability — a combination that heightens downside risk to equity holders.\n\nrecommendations:\n- Investigate drivers of negative net margin: perform line-item review of non-operating expenses, interest expense, taxes, and any one-time impairments or adjustments that reduced net income. Reconcile to cash flows.\n- Stress-test interest servicing: run scenario analyses of EBITDA sensitivity to revenue declines and interest-rate increases to quantify default or covenant breach risk given interest coverage near 3.0.\n- Assess working capital deployment: review accounts receivable, inventory, and payable policies to determine whether liquidity can be reallocated to higher-return uses without compromising operations.\n- Review capital structure alternatives: evaluate scope to reduce debt or refinance to improve debt-equity profile and increase interest coverage, balancing cost of capital and operational requirements.\n- Monitor return-on-capital improvement plans: require management to present quantifiable actions (timelines and KPIs) expected to convert strong operating margins and asset turnover into positive net profitability and improved ROA/ROE.\n- Enhanced audit focus areas: non-operating expenses, financing costs, impairment assessments, valuation of assets supporting high asset turnover, and disclosure completeness around contingencies and covenant compliance.\n\nconfidence_notes:\n- Diagnostic is based solely on the supplied ratio values for fiscal year 2022. No underlying financial statements, notes, or trend data were provided.\n- Thresholds cited (e.g., current ratio >3.0, debt/equity >1.0, interest coverage <3.0) are conservative reference points used for this assessment; they should be validated against industry norms and the company’s strategic context.\n- Conclusions are limited to ratio-level analysis and do not substitute for a full financial statement audit or management-provided explanations. Further document review is recommended to substantiate causes and remedial measures.'},
#   {'Company': 'Emerald Energy Inc',
#    'Year': 2023,
#    'analysis_profile': None,
#    'interpretation': 'summary\nEmerald Energy Inc — 2023 diagnostic summary:\n- Liquidity: current ratio 0.6058 and quick ratio 0.6058 indicate liquidity below commonly used conservative benchmarks (see key risks).  \n- Profitability: gross margin 80.45% and operating margin 68.52% are strong on an operating basis; net margin is negative at -3.11%, indicating a loss at the bottom line.  \n- Leverage and coverage: debt-to-equity 2.1296 indicates high leverage; interest coverage 2.1586 is low relative to conservative standards.  \n- Efficiency and returns: asset turnover 3.78098 is high, but return on assets (ROA) -11.76% and return on equity (ROE) -14.31% are negative.  \n- Composite: provided composite_score = 0 and risk_band = low per source data; notwithstanding that composite label, several individual metrics fall outside common conservative thresholds and are identified below.\n\nkey_risks\n- Liquidity shortfall: current_ratio (0.6058) and quick_ratio (0.6058) are below the commonly applied conservative threshold of 1.0, indicating potential difficulty meeting short-term obligations without additional financing or asset conversion.  \n- High leverage: debt_equity (2.1296) exceeds a conservative threshold of 1.0, indicating reliance on debt financing relative to shareholders’ equity and increased financial risk.  \n- Weak interest coverage: interest_coverage (2.1586) is below a conservative benchmark of 3.0, suggesting limited buffer to cover interest expense from operating earnings.  \n- Negative net profitability: net_margin (-0.0311), ROA (-11.76%), and ROE (-14.31%) are adverse and indicate that, after non-operating items and financing costs, the company did not generate positive returns to equity holders in 2023.  \n- Earnings versus operating strength: while gross_margin (80.45%) and operating_margin (68.52%) exceed conservative expectations for operational profitability, the conversion to net income failed, presenting a structural concern where non-operating items, financing costs, taxes, or one-time items are eroding operating gains.\n\nrecommendations\n- Address short-term liquidity: consider measures to raise near-term liquidity (e.g., negotiate supplier terms, prioritize receivables collection, or secure short-term committed credit facilities) to mitigate risk given current and quick ratios below 1.0.  \n- Evaluate capital structure: perform a formal review of debt levels and refinancing options to reduce leverage or extend maturities; aim to improve debt-to-equity toward more conservative ranges where appropriate for the industry.  \n- Improve interest coverage: reduce interest burden through refinancing at lower rates, deleveraging, or increasing operating EBITDA to raise the interest coverage ratio above conservative minimums.  \n- Investigate earnings gap: conduct an itemized review of non-operating expenses, one-time charges, and tax impacts that converted strong operating margins into a net loss; implement corrective actions as appropriate.  \n- Stress-test liquidity and covenant resilience: prepare scenario analyses for cash flow under adverse conditions to confirm covenant compliance and funding needs, and document mitigation plans.\n\nconfidence_notes\n- This analysis is based solely on the supplied 2023 ratio values. No additional financial statements, notes, or trend data were provided.  \n- Conservative thresholds cited (e.g., current ratio 1.0, debt-to-equity 1.0, interest coverage 3.0) are commonly used benchmarks for cautionary assessment; they were referenced explicitly to identify metrics that exceed conservative boundaries.  \n- No trends, additional metrics, or causal explanations beyond the supplied ratios were inferred. Recommendations are conditional and should be validated against full financial statements and management disclosures.'}],
#  'profile_used': 'full_diagnostic'}
