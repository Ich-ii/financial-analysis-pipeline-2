# %% [markdown]
# # AFAP Orchestrator Validation Notebook
# ## Profile-by-Profile Simulation & Contract Assurance
#
# ### Purpose
# This notebook validates the AFAP orchestrator across all supported
# Analysis Interpretation Frameworks (AIFs).
#
# Each profile is treated as an **independent client case**, ensuring:
# - Correct engine selection
# - Stable output contracts
# - Profile-aware AI interpretation
# - Reproducible, auditable execution
#
# This notebook is intentionally structured to support:
# - Engineering validation
# - Audit defensibility
# - Investor / stakeholder review

# %%
# ---------------------------------------------------------------
# Environment setup
# ---------------------------------------------------------------

import sys
import os
import pandas as pd
from pprint import pprint

# Ensure project root is on PYTHONPATH
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print("Project root resolved to:", PROJECT_ROOT)
# Out:
# Project root resolved to: c:\Users\ADMIN\Documents\My Documents\MyDataAnalysis\Financial statement analysis\financial-analysis-pipeline

# %% [markdown]
# ### Step 1: Import AFAP Orchestrator & Frozen Contracts
#
# This cell imports:
# - The AFAP orchestrator
# - The frozen output contract
# - All supported analysis profiles
#
# These are treated as **non-negotiable system interfaces**.

# %%
from orchestrator.orchestrator import (
    afap_run,
    ANALYSIS_PROFILES,
    AFAP_OUTPUT_KEYS
)

pprint(ANALYSIS_PROFILES)
# Out:
# {'full_diagnostic': {'engines': ['ratio',
#                                  'trend',
#                                  'cash_flow',
#                                  'anomaly',
#                                  'solvency',
#                                  'composite_risk'],
#                      'metrics_scope': 'all'},
#  'going_concern_screen': {'engines': ['ratio',
#                                       'trend',
#                                       'solvency',
#                                       'composite_risk'],
#                           'metrics_scope': 'critical_only'},
#  'liquidity_focus': {'engines': ['ratio',
#                                  'trend',
#                                  'cash_flow',
#                                  'composite_risk'],
#                      'metrics_scope': ['current_ratio',
#                                        'quick_ratio',
#                                        'cash_ratio']},
#  'performance_focus': {'engines': ['ratio', 'trend'],
#                        'metrics_scope': ['operating_margin',
#                                          'net_margin',
#                                          'asset_turnover']},
#  'risk_scan': {'engines': ['ratio', 'solvency', 'anomaly', 'composite_risk'],
#                'metrics_scope': 'all'},
#  'solvency_focus': {'engines': ['ratio', 'solvency', 'composite_risk'],
#                     'metrics_scope': ['debt_to_equity',
#                                       'interest_coverage',
#                                       'equity_ratio']}}

# %% [markdown]
# ### Step 2: Load Financial Statements
#
# This dataset simulates a **single recurring client**
# across multiple years, allowing trend and risk analysis.

# %%
financials_df = pd.read_csv("../data/cleaned/Kenya_Airways.csv")
financials_df.head()
# Out:
#          Company  Year  FS Category           FS Subcategory   Amount
# 0  Kenya Airways  2021       Assets           Current Assets   25,685
# 1  Kenya Airways  2021       Assets       Non-Current Assets  129,870
# 2  Kenya Airways  2021       Assets                Inventory    2,152
# 3  Kenya Airways  2021  Liabilities      Current Liabilities   80,965
# 4  Kenya Airways  2021  Liabilities  Non-Current Liabilities  157,927

# %% [markdown]
# ### Step 3: Define Validation Functions
#
# These validators ensure:
# - Output contract integrity
# - AI interpretation structural consistency
#
# They deliberately avoid business logic
# and only validate **system correctness**.

# %%
def validate_output_contract(outputs: dict):
    """
    Ensures all required AFAP output keys are present.
    """
    missing = set(AFAP_OUTPUT_KEYS) - set(outputs.keys())
    assert not missing, f"Missing output keys: {missing}"


def validate_ai_interpretation(ai_output):
    """
    Validates AI interpretation structure (schema-level).
    """
    assert isinstance(ai_output, list)
    assert len(ai_output) > 0

    for rec in ai_output:
        assert "Company" in rec
        assert "Year" in rec
        assert "interpretation" in rec

# %% [markdown]
# ### Step 4: Define Independent Client Analysis Cases
#
# Each profile below represents a **realistic engagement scenario**:
# - Targeted diagnostics
# - Focused decision support
# - Reduced computational scope
#
# Each will be run **independently**.

# %%
CLIENT_CASES = [
    "full_diagnostic",
    "solvency_focus",
    "liquidity_focus",
    "performance_focus",
    "risk_scan",
    "going_concern_screen"
]

# %% [markdown]
# ## Step 5: Execute a Single AFAP Profile (Case Simulation)
#
# This cell is the **canonical execution pattern**.
# It will be reused for every profile.
#
# We:
# 1. Run the orchestrator
# 2. Validate the output contract
# 3. Validate AI interpretation
# 4. Inspect executed engines
# 5. Review sample outputs

# %%
# Select profile to simulate
profile_name = "solvency_focus"

print(f"\n--- Running AFAP Case: {profile_name} ---")

# --- External context for Kenya Airways 2021-2024 ---
external_context = { 
    "macro": (
        "2021: Global recovery from COVID-19 uneven; travel restrictions in Europe, Middle East, Asia; economic activity suppressed. "
        "2022: Uneven global recovery; high fuel costs; currency volatility affects USD-denominated debt. "
        "2023: Airline demand rebounds post-pandemic; elevated financing and FX exposure challenge carriers. "
        "2024: Kenyan shilling strengthens vs USD; economic recovery supports demand; global aviation demand robust."
    ),
    "industry": (
        "2021: Passenger volumes ~65% lower than 2019; airline operations constrained; cargo growth supports revenue. "
        "2022: Domestic demand recovers faster than international; high fuel prices and operating costs persist. "
        "2023: Strong passenger rebound; cargo operations contribute positively; competition stable. "
        "2024: Regional airline industry sees strong passenger and cargo growth; operational efficiency rewarded."
    ),
    "company_notes": (
        "2021: Revenue up 33% (~KSh 70.2B); operating loss ~KSh 6.8B; net loss ~KSh 15.8B; focus on restructuring and cost control. "
        "2022: Revenue ~KSh 116B; net loss ~KSh 38.2B; Project Kifaru ongoing; cargo operations and Jambojet support revenue. "
        "2023: Operating profit ~KSh 10.5B (first in 7 years) but net loss ~KSh 22.7B; revenue recovery strong; FX losses still weigh. "
        "2024: Net profit ~KSh 5.4B; operating profit ~KSh 16.6B; revenue ~KSh 188B; cargo up 25%, passengers ~5.23M; FX gains drive turnaround."
    )
}

# --- Run AFAP with external context ---
outputs = afap_run(
    financials_df=financials_df,
    analysis_profile=profile_name,
    external_context=external_context,
    use_mock_ai=False  # toggle True for fast dry-runs
)

# --- Contract validation ---
validate_output_contract(outputs)
print("✅ Output contract validated")

# --- AI validation ---
validate_ai_interpretation(outputs["ai_interpretation"])
print("✅ AI interpretation structure validated")

# --- Inspect executed engines ---
engines_ran = [
    k for k in AFAP_OUTPUT_KEYS
    if k in outputs and outputs[k]
]

print("Engines executed:", engines_ran)
# Out:
# --- Running AFAP Case: solvency_focus ---
# ✅ ratio_engine output validated successfully.
# ✅ solvency_engine output validated successfully.
# ✅ Output contract validated
# ✅ AI interpretation structure validated
# Engines executed: ['profile_used', 'ratios', 'solvency', 'ai_interpretation']

# %% [markdown]
# ### Step 6: Inspect AI Interpretation Output
#
# This validates **semantic usability**, not correctness.

# %%
sample_interp = outputs["ai_interpretation"][0]

print("Company:", sample_interp["Company"])
print("Year:", sample_interp["Year"])
print("\n--- AI Interpretation ---\n")
print(sample_interp["interpretation"])
# Out:
# Company: Kenya Airways
# Year: 2021
#
# --- AI Interpretation ---
#
# summary:
# - Kenya Airways' 2021 financial condition had been weak and stressed. The company had operated at an operating loss and a material net loss while reporting severely constrained short-term liquidity and an elevated, unusual leverage profile. The dominant financial pressure in 2021 was solvency and liquidity (solvency via negative/elevated leverage and inability to cover interest; liquidity via very low current and quick ratios). The risk set was multi-dimensional but concentrated around funding capacity and capital structure rather than gross-margin generation.
#
# key_risks:
# 1) Capital-structure / solvency risk
#    - Supporting metrics: debt_equity = -2.8666; net_margin = -0.2284 (net loss of ~22.84% of revenue); roa = -0.1031 (negative return on assets).
#    - Interpretation/mechanism: The negative debt-to-equity ratio signaled an equity deficit or negative equity position, indicating that liabilities exceeded shareholders’ equity; combined with a material net loss and negative ROA, the balance sheet position reduced the firm's buffer to absorb further losses and constrained its ability to raise equity or debt on normal terms. This imbalance increased the probability that creditors or counterparties would demand restructuring or additional credit support.
#
# 2) Acute short-term liquidity risk
#    - Supporting metrics: current_ratio = 0.3172; quick_ratio = 0.2907.
#    - Interpretation/mechanism: Current and quick ratios substantially below 1.0 indicated that current liabilities materially exceeded readily available current assets. This condition implied limited headroom to meet near-term obligations (payables, short-term maturities, lease or lessor payments) from existing liquid resources, raising risk of covenant breaches, payment delays, or reliance on emergency financing.
#
# 3) Interest-serviceability and creditor-pressure risk
#    - Supporting metrics: interest_coverage = -0.7247; operating_margin = -0.0969 (operating loss ~9.69% of revenue).
#    - Interpretation/mechanism: Negative interest coverage indicated that operating income was insufficient to cover interest expense; with operating losses, the company lacked internal earnings to service debt. This dynamic elevated the risk of creditor enforcement, requirement for interest deferrals, and increased financing cost or refinancing difficulty.
#
# 4) Operating efficiency and profitability shortfall
#    - Supporting metrics: operating_margin = -0.0969; asset_turnover = 0.4514; roa = -0.1031.
#    - Interpretation/mechanism: Operating losses combined with a modest asset turnover ratio indicated that asset base usage did not generate adequate revenue to cover operating fixed costs. The combination reduced the firm’s ability to generate positive incremental cash from operations and to scale profitability without structural changes to revenue mix or cost base.
#
# period_specific_actions:
# - To address solvency risk in 2021, it would have been appropriate to arrange consensual capital-structure remedies during that reporting year, such as negotiated debt-for-equity conversions with creditors or secured shareholder equity injections, to restore positive equity and reduce leverage pressure.
# - To address acute liquidity shortfalls in 2021, it would have been appropriate to secure committed short-term liquidity (e.g., revolving credit or bridge facilities) sized to cover the company’s projected near-term working-capital and contractual outflows, and to negotiate near-term covenant waivers or maturity extensions with key lenders and lessors during 2021.
# - To address interest-serviceability risk in 2021, it would have been appropriate to negotiate interest payment relief (deferrals or capitalization) and to restructure interest terms with creditors in that year to align cash interest obligations with reduced operating cash generation.
# - To address operating profitability in 2021, it would have been appropriate to accelerate the company’s ongoing restructuring and cost-control initiatives (as had been a stated focus in 2021), and to prioritize higher-yielding revenue channels evident in that period (for example, cargo and related subsidiary operations) to improve operating cash receipts within 2021.
#
# structural_long_term_implications:
# - The 2021 metric pattern (negative equity signal, negative interest coverage, and very low liquidity) implied a structural vulnerability in financing resilience: absent timely capital support or substantive restructuring, the company would have faced prolonged dependence on external capital and repeated refinancing events.
# - Persistent operating losses combined with modest asset turnover suggested that, without sustainable improvement in operating margins or a reduction in asset intensity, returns on assets would have remained negative, constraining long-term return to investors and limiting internally generated capital for debt reduction.
# - The combination of solvency and liquidity weaknesses in 2021 would have tended to raise the company’s cost of capital and could have caused tighter lending terms or collateral demands in subsequent financings, thereby creating a structural constraint on profitable growth unless capital-structure restoration occurred.
#
# contextual_interpretation:
# - The provided structured external context (2021 macro and industry: uneven COVID recovery, travel restrictions, passenger volumes ~65% below 2019; company focus on restructuring and cost control) informed the interpretation by explaining plausible drivers of the revenue and operating-pressure metrics recorded in 2021. Specifically, the context amplified the interpretation that revenue and operating shortfalls in 2021 were related to weakened passenger demand and constrained operations.
# - The principal conclusions in this analysis remained primarily metric-driven: the ratios and reported operating/net losses provided the direct evidence of solvency and liquidity stress. The external context served to explain why those metric outcomes may have occurred but did not replace the metric-based assessment of financial pressure.
#
# confidence_notes:
# - The analysis was constrained by absence of several granular data items for 2021: a cash-flow statement and operating cash flows, debt maturity and currency profile (including USD versus KSh denomination), composition and timing of current liabilities, detailed covenant schedules, and off‑balance-sheet obligations (e.g., operating lease schedules or guarantees).
# - A notable internal inconsistency existed among supplied metrics (for example, roe = 0.1925 alongside a material net loss and a negative debt_equity ratio). That inconsistency could not be reconciled from the provided dataset and limited the ability to interpret equity returns precisely.
# - Interpretations focused strictly on the 2021 reporting year and on supplied metrics and context. Structural inferences about subsequent years were restricted to logical implications of the 2021 metric pattern and did not assume any unprovided events or outcomes.

# %% [markdown]
# ### Step 7: Inspect Numerical Engine Outputs
#
# This confirms:
# - Ratios exist
# - Engines populated data
# - Schema consistency

# %%
if outputs.get("ratios"):
    display(pd.DataFrame(outputs["ratios"]).head())

if outputs.get("solvency"):
    display(pd.DataFrame(outputs["solvency"]).head())
# Out:
#          engine        Company  Year  \
# 0  ratio_engine  Kenya Airways  2021
# 1  ratio_engine  Kenya Airways  2022
# 2  ratio_engine  Kenya Airways  2023
# 3  ratio_engine  Kenya Airways  2024
#
#                                              metrics flags severity  \
# 0  {'current_ratio': 0.3172358426480578, 'quick_r...    {}   stable
# 1  {'current_ratio': 0.3553302522298208, 'quick_r...    {}   stable
# 2  {'current_ratio': 0.41900024909402095, 'quick_...    {}   stable
# 3  {'current_ratio': 0.34834771979471035, 'quick_...    {}   stable
#
#                   explanation
# 0  Canonical financial ratios
# 1  Canonical financial ratios
# 2  Canonical financial ratios
# 3  Canonical financial ratios
#             engine        Company  Year  \
# 0  solvency_engine  Kenya Airways  2021
# 1  solvency_engine  Kenya Airways  2022
# 2  solvency_engine  Kenya Airways  2023
# 3  solvency_engine  Kenya Airways  2024
#
#                                              metrics  \
# 0  {'debt_equity': -2.866577870573695, 'interest_...
# 1  {'debt_equity': -2.5626977518734386, 'interest...
# 2  {'debt_equity': -2.3023474790494194, 'interest...
# 3  {'debt_equity': -2.5146087559513237, 'interest...
#
#                                              flags severity  \
# 0  {'high_leverage': False, 'weak_coverage': True}    watch
# 1  {'high_leverage': False, 'weak_coverage': True}    watch
# 2  {'high_leverage': False, 'weak_coverage': True}    watch
# 3  {'high_leverage': False, 'weak_coverage': True}    watch
#
#                               explanation
# 0  Capital structure shows solvency risk.
# 1  Capital structure shows solvency risk.
# 2  Capital structure shows solvency risk.
# 3  Capital structure shows solvency risk.

# %% [markdown]
# ## Step 8: Full System Validation (All Profiles)
#
# This cell simulates **multiple client engagements**,
# ensuring no profile breaks the orchestrator.

# %%
# --- Prepare external context for Kenya Airways 2021-2024 ---
external_context = { 
    "macro": (
        "2021: Global recovery from COVID-19 uneven; travel restrictions in Europe, Middle East, Asia; economic activity suppressed. "
        "2022: Uneven global recovery; high fuel costs; currency volatility affects USD-denominated debt. "
        "2023: Airline demand rebounds post-pandemic; elevated financing and FX exposure challenge carriers. "
        "2024: Kenyan shilling strengthens vs USD; economic recovery supports demand; global aviation demand robust."
    ),
    "industry": (
        "2021: Passenger volumes ~65% lower than 2019; airline operations constrained; cargo growth supports revenue. "
        "2022: Domestic demand recovers faster than international; high fuel prices and operating costs persist. "
        "2023: Strong passenger rebound; cargo operations contribute positively; competition stable. "
        "2024: Regional airline industry sees strong passenger and cargo growth; operational efficiency rewarded."
    ),
    "company_notes": (
        "2021: Revenue up 33% (~KSh 70.2B); operating loss ~KSh 6.8B; net loss ~KSh 15.8B; focus on restructuring and cost control. "
        "2022: Revenue ~KSh 116B; net loss ~KSh 38.2B; Project Kifaru ongoing; cargo operations and Jambojet support revenue. "
        "2023: Operating profit ~KSh 10.5B (first in 7 years) but net loss ~KSh 22.7B; revenue recovery strong; FX losses still weigh. "
        "2024: Net profit ~KSh 5.4B; operating profit ~KSh 16.6B; revenue ~KSh 188B; cargo up 25%, passengers ~5.23M; FX gains drive turnaround."
    )
}

# --- Initialize results dictionary ---
results_by_profile = {}

# --- Loop through client cases with external context ---
for profile_name in CLIENT_CASES:
    print(f"\n--- Executing profile: {profile_name} ---")

    outputs = afap_run(
        financials_df=financials_df,
        analysis_profile=profile_name,
        external_context=external_context,  # <-- added context
        use_mock_ai=False
    )

    # --- Validate output contract and AI interpretation ---
    validate_output_contract(outputs)
    validate_ai_interpretation(outputs["ai_interpretation"])

    # --- Inspect executed engines ---
    engines_ran = [
        k for k in AFAP_OUTPUT_KEYS
        if k in outputs and outputs[k]
    ]

    print("Engines executed:", engines_ran)

    # --- Store outputs by profile ---
    results_by_profile[profile_name] = outputs

print("\n✅ All AFAP profiles validated successfully")
# Out:
# --- Executing profile: full_diagnostic ---
# ✅ ratio_engine output validated successfully.
# ✅ trend_engine output validated successfully.
# ✅ cash_flow_engine output validated successfully.
# ✅ anomaly_efficiency_engine output validated successfully.
# ✅ solvency_engine output validated successfully.
# Engines executed: ['profile_used', 'ratios', 'trend', 'cash_flow', 'anomaly', 'solvency', 'composite_risk', 'ai_interpretation']
#
# --- Executing profile: solvency_focus ---
# ✅ ratio_engine output validated successfully.
# ✅ solvency_engine output validated successfully.
# Engines executed: ['profile_used', 'ratios', 'solvency', 'ai_interpretation']
#
# --- Executing profile: liquidity_focus ---
# ✅ ratio_engine output validated successfully.
# ✅ trend_engine output validated successfully.
# ✅ cash_flow_engine output validated successfully.
# Engines executed: ['profile_used', 'ratios', 'trend', 'cash_flow', 'composite_risk', 'ai_interpretation']
#
# --- Executing profile: performance_focus ---
# ✅ ratio_engine output validated successfully.
# ✅ trend_engine output validated successfully.
# Engines executed: ['profile_used', 'ratios', 'trend', 'ai_interpretation']
#
# --- Executing profile: risk_scan ---
# ✅ ratio_engine output validated successfully.
# ✅ anomaly_efficiency_engine output validated successfully.
# ✅ solvency_engine output validated successfully.
# Engines executed: ['profile_used', 'ratios', 'anomaly', 'solvency', 'ai_interpretation']
#
# --- Executing profile: going_concern_screen ---
# ✅ ratio_engine output validated successfully.
# ✅ trend_engine output validated successfully.
# ✅ solvency_engine output validated successfully.
# Engines executed: ['profile_used', 'ratios', 'trend', 'solvency', 'composite_risk', 'ai_interpretation']
#
# ✅ All AFAP profiles validated successfully

# %%
outputs
# Out:
# {'ratios': [{'engine': 'ratio_engine',
#    'Company': 'Kenya Airways',
#    'Year': 2021,
#    'metrics': {'current_ratio': np.float64(0.3172358426480578),
#     'quick_ratio': np.float64(0.2906564564935466),
#     'gross_margin': np.float64(0.4139217612964783),
#     'operating_margin': np.float64(-0.09687985075689609),
#     'net_margin': np.float64(-0.22842169721308442),
#     'debt_equity': np.float64(-2.866577870573695),
#     'interest_coverage': np.float64(-0.7247256844572281),
#     'asset_turnover': np.float64(0.45142232650830894),
#     'roa': np.float64(-0.10311465398090708),
#     'roe': np.float64(0.1924715312526249)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Kenya Airways',
#    'Year': 2022,
#    'metrics': {'current_ratio': np.float64(0.3553302522298208),
#     'quick_ratio': np.float64(0.3359482920340399),
#     'gross_margin': np.float64(0.3170215863066951),
#     'operating_margin': np.float64(-0.04808754399034139),
#     'net_margin': np.float64(-0.32930035021021176),
#     'debt_equity': np.float64(-2.5626977518734386),
#     'interest_coverage': np.float64(-0.170735414829903),
#     'asset_turnover': np.float64(0.6914073600454674),
#     'roa': np.float64(-0.2276806858008904),
#     'roe': np.float64(0.3557960958460542)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Kenya Airways',
#    'Year': 2023,
#    'metrics': {'current_ratio': np.float64(0.41900024909402095),
#     'quick_ratio': np.float64(0.39647732842644895),
#     'gross_margin': np.float64(0.33876949623520974),
#     'operating_margin': np.float64(0.057782807457870206),
#     'net_margin': np.float64(-0.1292914126927214),
#     'debt_equity': np.float64(-2.3023474790494194),
#     'interest_coverage': np.float64(0.307339312851992),
#     'asset_turnover': np.float64(1.010661729317774),
#     'roa': np.float64(-0.1306698827379638),
#     'roe': np.float64(0.1671555739046667)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'},
#   {'engine': 'ratio_engine',
#    'Company': 'Kenya Airways',
#    'Year': 2024,
#    'metrics': {'current_ratio': np.float64(0.34834771979471035),
#     'quick_ratio': np.float64(0.32301303572475115),
#     'gross_margin': np.float64(0.32323403803814427),
#     'operating_margin': np.float64(0.08817740523621316),
#     'net_margin': np.float64(0.028451683068516406),
#     'debt_equity': np.float64(-2.5146087559513237),
#     'interest_coverage': np.float64(1.48893666577085),
#     'asset_turnover': np.float64(1.0524332231552618),
#     'roa': np.float64(0.02994349651599071),
#     'roe': np.float64(-0.045352682006917486)},
#    'flags': {},
#    'severity': 'stable',
#    'explanation': 'Canonical financial ratios'}],
#  'trend': [{'engine': 'trend_engine',
#    'Company': 'Kenya Airways',
#    'Year': 2024,
#    'metrics': {'ratio': 'current_ratio',
#     'trend_value': np.float64(0.031111877146652533),
#     'from_year': 2021,
#     'to_year': 2024},
#    'flags': {'deteriorating_trend': np.False_},
#    'severity': 'stable',
#    'explanation': 'current_ratio trend stable or improving.'},
#   {'engine': 'trend_engine',
#    'Company': 'Kenya Airways',
#    'Year': 2024,
#    'metrics': {'ratio': 'gross_margin',
#     'trend_value': np.float64(-0.09068772325833402),
#     'from_year': 2021,
#     'to_year': 2024},
#    'flags': {'deteriorating_trend': np.True_},
#    'severity': 'watch',
#    'explanation': 'Negative trend observed in gross_margin.'},
#   {'engine': 'trend_engine',
#    'Company': 'Kenya Airways',
#    'Year': 2024,
#    'metrics': {'ratio': 'net_margin',
#     'trend_value': np.float64(0.25687338028160084),
#     'from_year': 2021,
#     'to_year': 2024},
#    'flags': {'deteriorating_trend': np.False_},
#    'severity': 'stable',
#    'explanation': 'net_margin trend stable or improving.'},
#   {'engine': 'trend_engine',
#    'Company': 'Kenya Airways',
#    'Year': 2024,
#    'metrics': {'ratio': 'asset_turnover',
#     'trend_value': np.float64(0.6010108966469528),
#     'from_year': 2021,
#     'to_year': 2024},
#    'flags': {'deteriorating_trend': np.False_},
#    'severity': 'stable',
#    'explanation': 'asset_turnover trend stable or improving.'},
#   {'engine': 'trend_engine',
#    'Company': 'Kenya Airways',
#    'Year': 2024,
#    'metrics': {'ratio': 'debt_equity',
#     'trend_value': np.float64(0.3519691146223711),
#     'from_year': 2021,
#     'to_year': 2024},
#    'flags': {'deteriorating_trend': np.False_},
#    'severity': 'stable',
#    'explanation': 'debt_equity trend stable or improving.'},
#   {'engine': 'trend_engine',
#    'Company': 'Kenya Airways',
#    'Year': 2024,
#    'metrics': {'ratio': 'roe',
#     'trend_value': np.float64(-0.2378242132595424),
#     'from_year': 2021,
#     'to_year': 2024},
#    'flags': {'deteriorating_trend': np.True_},
#    'severity': 'watch',
#    'explanation': 'Negative trend observed in roe.'}],
#  'cash_flow': [],
#  'anomaly': [],
#  'solvency': [{'engine': 'solvency_engine',
#    'Company': 'Kenya Airways',
#    'Year': 2021,
#    'metrics': {'debt_equity': -2.866577870573695,
#     'interest_coverage': -0.7247256844572281},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Kenya Airways',
#    'Year': 2022,
#    'metrics': {'debt_equity': -2.5626977518734386,
#     'interest_coverage': -0.170735414829903},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Kenya Airways',
#    'Year': 2023,
#    'metrics': {'debt_equity': -2.3023474790494194,
#     'interest_coverage': 0.307339312851992},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'},
#   {'engine': 'solvency_engine',
#    'Company': 'Kenya Airways',
#    'Year': 2024,
#    'metrics': {'debt_equity': -2.5146087559513237,
#     'interest_coverage': 1.48893666577085},
#    'flags': {'high_leverage': False, 'weak_coverage': True},
#    'severity': 'watch',
#    'explanation': 'Capital structure shows solvency risk.'}],
#  'composite_risk': [{'Company': 'Kenya Airways',
#    'Year': 2024,
#    'composite_score': 0.25,
#    'risk_band': 'low'}],
#  'ai_interpretation': [{'Company': 'Kenya Airways',
#    'Year': 2021,
#    'analysis_profile': 'going_concern_screen',
#    'temporal_mode': 'retrospective',
#    'context_used': {'macro': '2021: Global recovery from COVID-19 uneven; travel restrictions in Europe, Middle East, Asia; economic activity suppressed. 2022: Uneven global recovery; high fuel costs; currency volatility affects USD-denominated debt. 2023: Airline demand rebounds post-pandemic; elevated financing and FX exposure challenge carriers. 2024: Kenyan shilling strengthens vs USD; economic recovery supports demand; global aviation demand robust.',
#     'industry': '2021: Passenger volumes ~65% lower than 2019; airline operations constrained; cargo growth supports revenue. 2022: Domestic demand recovers faster than international; high fuel prices and operating costs persist. 2023: Strong passenger rebound; cargo operations contribute positively; competition stable. 2024: Regional airline industry sees strong passenger and cargo growth; operational efficiency rewarded.',
#     'company_notes': '2021: Revenue up 33% (~KSh 70.2B); operating loss ~KSh 6.8B; net loss ~KSh 15.8B; focus on restructuring and cost control. 2022: Revenue ~KSh 116B; net loss ~KSh 38.2B; Project Kifaru ongoing; cargo operations and Jambojet support revenue. 2023: Operating profit ~KSh 10.5B (first in 7 years) but net loss ~KSh 22.7B; revenue recovery strong; FX losses still weigh. 2024: Net profit ~KSh 5.4B; operating profit ~KSh 16.6B; revenue ~KSh 188B; cargo up 25%, passengers ~5.23M; FX gains drive turnaround.'},
#    'interpretation': 'summary:\nIn 2021 Kenya Airways exhibited a financially distressed position. Liquidity was acute (current ratio 0.32; quick ratio 0.29), operating performance was loss-making (operating margin -9.69%; net margin -22.84%), and balance-sheet solvency showed a capital shortfall (debt-to-equity -2.87, interest coverage -0.72). The dominant financial pressure in 2021 was multi-dimensional but concentrated: immediate liquidity strain and solvency/leverage risk that were compounded by persistent operating losses. The risk profile was therefore concentrated on short-term cash coverage and capital structure fragility while profitability weaknesses amplified both.\n\nkey_risks:\n1) Acute short-term liquidity risk\n   - Supporting metrics: current ratio 0.317 and quick ratio 0.291.\n   - Financial mechanism: For each KSh1 of current liabilities Kenya Airways reportedly had only ~KSh0.32 of current assets and ~KSh0.29 of immediately liquid assets; this metric profile implied limited ability to meet near-term obligations from existing working capital and a likely reliance on external financing or covenant relief.\n\n2) Solvency / negative equity and high leverage\n   - Supporting metrics: debt-to-equity ratio -2.866 (indicating equity was a deficit) and interest coverage -0.725.\n   - Financial mechanism: The negative debt/equity ratio signalled that total liabilities exceeded shareholders’ equity, creating a capital structure imbalance. Negative interest coverage meant operating income was insufficient to cover interest expense; together these metrics signalled elevated default and refinancing risk and constrained capacity to raise additional capital on conventional terms.\n\n3) Operating loss despite positive gross margin (profitability and cost-structure risk)\n   - Supporting metrics: gross margin 41.39% versus operating margin -9.69% and net margin -22.84%.\n   - Financial mechanism: The positive gross margin indicated the core transport product yielded margin at the gross level, but operating and net margins were negative, indicating that operating expenses, overheads, restructuring or other non‑production costs eroded profitability. Persistent operating losses reduced internal cash generation, exacerbating liquidity and solvency stresses.\n\n4) Asset efficiency and return shortfall\n   - Supporting metrics: asset turnover 0.451 and return on assets (ROA) -10.31%.\n   - Financial mechanism: Each KSh1 of assets generated only ~KSh0.45 of revenue while assets produced negative returns, implying an underutilization of the asset base relative to revenue and weakened ability of assets to support profitability and service liabilities.\n\n5) Potential metric distortion from negative equity (interpretation risk)\n   - Supporting metrics: return on equity (ROE) reported 19.25% despite negative net margin and negative equity per debt-to-equity.\n   - Financial mechanism: The positive ROE in the presence of a net loss was consistent mathematically with a negative equity denominator; this signalled that conventional profitability ratios could be misleading and required careful balance-sheet context to interpret solvency and performance accurately.\n\nperiod_specific_actions:\n(Appropriate actions that would have been taken in 2021 to address the stated risks)\n- To address acute liquidity risk (Risk 1): It would have been appropriate in 2021 to prioritize renegotiation of the maturities and payment terms of short-term liabilities and to secure committed short-term liquidity lines or covenant waivers sufficient to cover forecasted cash shortfalls for a defined near-term horizon. These measures would have directly targeted the insufficiency indicated by current and quick ratios ~0.32 and ~0.29.\n- To address solvency and negative equity (Risk 2): Actions that would have been appropriate in 2021 included pursuing balance-sheet recapitalization options (equity injection, convertible instruments, or creditor-for-equity arrangeme ...
#   {'Company': 'Kenya Airways',
#    'Year': 2022,
#    'analysis_profile': 'going_concern_screen',
#    'temporal_mode': 'retrospective',
#    'context_used': {'macro': '2021: Global recovery from COVID-19 uneven; travel restrictions in Europe, Middle East, Asia; economic activity suppressed. 2022: Uneven global recovery; high fuel costs; currency volatility affects USD-denominated debt. 2023: Airline demand rebounds post-pandemic; elevated financing and FX exposure challenge carriers. 2024: Kenyan shilling strengthens vs USD; economic recovery supports demand; global aviation demand robust.',
#     'industry': '2021: Passenger volumes ~65% lower than 2019; airline operations constrained; cargo growth supports revenue. 2022: Domestic demand recovers faster than international; high fuel prices and operating costs persist. 2023: Strong passenger rebound; cargo operations contribute positively; competition stable. 2024: Regional airline industry sees strong passenger and cargo growth; operational efficiency rewarded.',
#     'company_notes': '2021: Revenue up 33% (~KSh 70.2B); operating loss ~KSh 6.8B; net loss ~KSh 15.8B; focus on restructuring and cost control. 2022: Revenue ~KSh 116B; net loss ~KSh 38.2B; Project Kifaru ongoing; cargo operations and Jambojet support revenue. 2023: Operating profit ~KSh 10.5B (first in 7 years) but net loss ~KSh 22.7B; revenue recovery strong; FX losses still weigh. 2024: Net profit ~KSh 5.4B; operating profit ~KSh 16.6B; revenue ~KSh 188B; cargo up 25%, passengers ~5.23M; FX gains drive turnaround.'},
#    'interpretation': "summary:\n  Kenya Airways' 2022 financial condition was severely distressed. The company exhibited acute liquidity shortfalls, sustained operating losses and negative return on assets, and capital-structure weakness consistent with balance-sheet insolvency indicators. The dominant financial pressures were multi-dimensional, with liquidity and solvency risk as the most pronounced issues and profitability losses reinforcing those pressures.\n\nkey_risks:\n  - risk: Balance-sheet solvency / negative equity\n    evidence_and_mechanism:\n      • The debt-to-equity metric (debt_equity = -2.5627) implied equity was negative or materially impaired, which signalled capital erosion.\n      • A negative or extremely depressed equity base increased the risk that losses would exhaust remaining capital and that creditors could exert claims against the company; negative equity also made equity injections or refinancing more difficult and more expensive.\n  - risk: Acute liquidity shortfall\n    evidence_and_mechanism:\n      • The current_ratio (0.3553) and quick_ratio (0.3359) were both materially below 1.0, indicating that short-term assets were substantially insufficient to meet short-term liabilities.\n      • Such low liquidity ratios created a high risk of covenant breaches, acceleration of short-term borrowings, or inability to meet near-term operating cash requirements.\n  - risk: Unsustainable interest and financing burden\n    evidence_and_mechanism:\n      • Interest_coverage was negative (-0.1707), showing operating losses insufficient to cover interest expense.\n      • The combination of negative interest coverage and high leverage implied elevated default risk on debt service obligations and reduced capacity to absorb further financing costs or adverse cash-flow shocks.\n  - risk: Operating unprofitability undermining asset returns\n    evidence_and_mechanism:\n      • Operating_margin was negative (-4.8088%) and net_margin was deeply negative (-32.9300%), while roa was negative (-22.7681%).\n      • These profitability metrics indicated that core operations and the asset base did not generate positive returns in 2022, which contributed to cash outflows and capital depletion.\n  - risk: Misleading equity-return signal due to capital structure\n    evidence_and_mechanism:\n      • Reported roe was positive (0.3558) despite large net losses; this combination, together with negative debt_equity, indicated that roe was distorted by a negative equity denominator.\n      • The positive roe therefore did not represent economically sustainable shareholder returns and created a risk of misinterpretation by stakeholders relying on headline return measures.\n\nperiod_specific_actions:\n  - action: Negotiate short-term creditor forbearance and covenant waivers in 2022\n    rationale:\n      • This action would have addressed the immediate liquidity risk indicated by current_ratio and quick_ratio materially below 1.0 and mitigated the risk of loan acceleration while restructuring liquidity.\n  - action: Pursue immediate debt-restructuring focused on maturities and interest relief in 2022\n    rationale:\n      • Given negative interest_coverage and high leverage (debt_equity negative), renegotiation of maturities and interest terms would have been directly aimed at reducing near-term cash interest burden and lowering default risk.\n  - action: Seek capital infusion or equity recapitalisation in 2022, conditional on creditor alignment\n    rationale:\n      • The negative-equity signal (debt_equity) suggested that an equity cure or fresh capital was required to restore solvency metrics and remove distortions in roe.\n  - action: Implement targeted operating-cost reductions tied to operating_margin drivers in 2022\n    rationale:\n      • With operating_margin negative, actions in 2022 that specifically reduced controllable operating costs (route rationalisation of unprofitable services, temporary capacity reduction) wo ...
#   {'Company': 'Kenya Airways',
#    'Year': 2023,
#    'analysis_profile': 'going_concern_screen',
#    'temporal_mode': 'retrospective',
#    'context_used': {'macro': '2021: Global recovery from COVID-19 uneven; travel restrictions in Europe, Middle East, Asia; economic activity suppressed. 2022: Uneven global recovery; high fuel costs; currency volatility affects USD-denominated debt. 2023: Airline demand rebounds post-pandemic; elevated financing and FX exposure challenge carriers. 2024: Kenyan shilling strengthens vs USD; economic recovery supports demand; global aviation demand robust.',
#     'industry': '2021: Passenger volumes ~65% lower than 2019; airline operations constrained; cargo growth supports revenue. 2022: Domestic demand recovers faster than international; high fuel prices and operating costs persist. 2023: Strong passenger rebound; cargo operations contribute positively; competition stable. 2024: Regional airline industry sees strong passenger and cargo growth; operational efficiency rewarded.',
#     'company_notes': '2021: Revenue up 33% (~KSh 70.2B); operating loss ~KSh 6.8B; net loss ~KSh 15.8B; focus on restructuring and cost control. 2022: Revenue ~KSh 116B; net loss ~KSh 38.2B; Project Kifaru ongoing; cargo operations and Jambojet support revenue. 2023: Operating profit ~KSh 10.5B (first in 7 years) but net loss ~KSh 22.7B; revenue recovery strong; FX losses still weigh. 2024: Net profit ~KSh 5.4B; operating profit ~KSh 16.6B; revenue ~KSh 188B; cargo up 25%, passengers ~5.23M; FX gains drive turnaround.'},
#    'interpretation': 'summary:\nThe company’s 2023 financial condition was distressed and multi-dimensional. Liquidity was impaired (current and quick ratios well below 1.0), solvency showed structural strain (negative debt-to-equity signalling negative or deficient equity capital), and profitability was mixed (positive operating margin but a material net loss). The dominant financial pressures in 2023 were liquidity shortfall and solvency/leverage stress, with profitability and interest-service capacity amplifying those pressures. The risk profile was multi-dimensional rather than concentrated in a single metric.\n\nkey_risks:\n1. Liquidity shortfall\n   - Evidence: current ratio = 0.419; quick ratio = 0.396.\n   - Mechanism: Current assets covered less than half of current liabilities in 2023, indicating an inability to meet short-term obligations from liquid resources. This created risk of covenant breaches, forced asset disposals, or reliance on emergency short-term funding.\n\n2. Solvency / negative equity and high leverage\n   - Evidence: debt_equity = -2.302 (negative value).\n   - Mechanism: The negative debt-to-equity ratio indicated that liabilities exceeded shareholders’ equity (negative or impaired equity capital) in 2023. This condition increased creditor seniority risk, reduced loss-absorption capacity, and raised the probability that further losses would erode going-concern buffers.\n\n3. Interest and financing strain\n   - Evidence: interest_coverage = 0.307.\n   - Mechanism: Operating income covered only about 0.31x of interest expense in 2023, showing that operating earnings were insufficient to service financing costs. This heightened refinancing risk and increased likelihood of additional financing costs or restructuring of debt terms.\n\n4. Profitability volatility due to non-operating losses\n   - Evidence: operating_margin = 0.0578 (positive) while net_margin = -0.1293 (negative); roa = -0.1307 (negative).\n   - Mechanism: The company generated positive operating profits in 2023 but recorded a substantial net loss after non-operating items, producing negative returns on assets. Non-operating losses (for example, financing costs, FX losses or other below-operating-line items reflected in the net margin and ROA) materially undone operating profitability, contributing to negative comprehensive results and worsening equity.\n\nperiod_specific_actions:\n- To address liquidity shortfall in 2023, management would have pursued extension of near-term maturities or negotiated covenant relaxations with lenders to reduce immediate cash outflows and avoid forced asset sales in the reporting year.\n- To mitigate solvency pressure in 2023, management would have sought an equity recapitalization or structured subordinated financing during the year to restore positive net equity and improve the debt-to-equity position.\n- To relieve interest-service strain in 2023, management would have restructured high-cost debt or converted short-term borrowings to longer-maturity instruments to reduce interest expense recognized within the year and improve interest coverage.\n- To contain profitability volatility in 2023, management would have hedged or otherwise reduced identifiable non-operating exposures disclosed for that year (for example, currency or market exposures reported in the 2023 notes) to prevent further erosion of net income that year.\n\nstructural_long_term_implications:\n- The combination of a low current ratio and negative debt-to-equity implied that, absent remediation in 2023, solvency pressures could persist beyond the reporting year because negative equity reduced capacity to absorb subsequent losses. Metric patterns suggested a structural funding mismatch: operating performance (positive operating margin and asset_turnover ~1.01) indicated operational competitiveness, but recurring below-the-line losses and poor liquidity pointed to a structural financing problem rather than purely operational failure.\n- Per ...
#   {'Company': 'Kenya Airways',
#    'Year': 2024,
#    'analysis_profile': 'going_concern_screen',
#    'temporal_mode': 'retrospective',
#    'context_used': {'macro': '2021: Global recovery from COVID-19 uneven; travel restrictions in Europe, Middle East, Asia; economic activity suppressed. 2022: Uneven global recovery; high fuel costs; currency volatility affects USD-denominated debt. 2023: Airline demand rebounds post-pandemic; elevated financing and FX exposure challenge carriers. 2024: Kenyan shilling strengthens vs USD; economic recovery supports demand; global aviation demand robust.',
#     'industry': '2021: Passenger volumes ~65% lower than 2019; airline operations constrained; cargo growth supports revenue. 2022: Domestic demand recovers faster than international; high fuel prices and operating costs persist. 2023: Strong passenger rebound; cargo operations contribute positively; competition stable. 2024: Regional airline industry sees strong passenger and cargo growth; operational efficiency rewarded.',
#     'company_notes': '2021: Revenue up 33% (~KSh 70.2B); operating loss ~KSh 6.8B; net loss ~KSh 15.8B; focus on restructuring and cost control. 2022: Revenue ~KSh 116B; net loss ~KSh 38.2B; Project Kifaru ongoing; cargo operations and Jambojet support revenue. 2023: Operating profit ~KSh 10.5B (first in 7 years) but net loss ~KSh 22.7B; revenue recovery strong; FX losses still weigh. 2024: Net profit ~KSh 5.4B; operating profit ~KSh 16.6B; revenue ~KSh 188B; cargo up 25%, passengers ~5.23M; FX gains drive turnaround.'},
#    'interpretation': 'summary:\n- In 2024 Kenya Airways reported an operating recovery and a small net profit; however, its financial condition remained characterised by acute short-term liquidity constraints and impaired capital structure. Liquidity metrics were severely depressed, solvency indicators reflected negative equity, and interest-bearing obligations had limited coverage. The dominant financial pressures in the reporting year were liquidity and solvency; profitability improvement appeared present but concentrated and partially non-operational. Risk was multi-dimensional but concentrated around liquidity/solvency rather than broad-based operating failure.\n\nkey_risks:\n1) Acute short-term liquidity risk\n   - Evidence: current ratio 0.35 and quick ratio 0.323.\n   - Mechanism: Current and quick ratios substantially below 1.0 indicated that, in 2024, current liabilities materially exceeded readily liquid assets. This imbalance created a risk that the company would have been unable to meet near-term obligations from existing liquid resources, increasing dependence on refinancing, covenant waivers, or asset conversion.\n\n2) Capital structure / solvency risk (negative equity)\n   - Evidence: debt-to-equity ratio -2.51 and return on equity (ROE) -4.54%.\n   - Mechanism: The negative debt-to-equity ratio indicated that shareholders’ equity was a net deficit in 2024; simultaneously a negative ROE despite positive net income signalled that book equity remained negative. These metrics implied constrained solvency and potential limits to accessing debt or equity markets without balance-sheet remediation.\n\n3) Interest-service vulnerability\n   - Evidence: interest coverage ratio 1.49.\n   - Mechanism: EBIT provided only about 1.5 times the interest expense in 2024, giving a narrow margin to absorb earnings declines or interest rate increases. Low interest coverage heightened default and refinancing risk on interest-bearing liabilities if operating performance had weakened.\n\n4) Earnings composition / potential earnings volatility\n   - Evidence: operating margin 8.82% versus net margin 2.85%; company notes indicated FX gains materially contributed to the net profit in 2024.\n   - Mechanism: The gap between operating and net margins, together with disclosure that FX gains drove the turnaround, indicated that a material portion of the reported net profit arose from non-operating items. This suggested that underlying net earnings were thin and could be sensitive to reversals of non-operating gains or to FX movements.\n\nperiod_specific_actions:\n- Appropriate 2024 actions to address liquidity risk included securing or extending committed short-term credit facilities and re-profiling immediate maturities; implementing targeted working-capital measures such as invoice factoring or accelerated receivable collections tied to specific routes; and negotiating short-term supplier payment terms or confirmed trade credit to reduce near-term cash outflows.\n- Appropriate 2024 actions to address negative equity included arranging capital injections or equity conversion alternatives, and pursuing targeted non-core asset disposals with proceeds earmarked for restoring positive net equity.\n- Appropriate 2024 actions to address interest-service vulnerability included renegotiating debt covenants and interest terms to extend maturities or reduce near-term interest expense, and prioritising use of positive operating cash flows to reduce the most expensive short-term borrowings.\n- Appropriate 2024 actions to address earnings composition risk included disclosing the extent of FX and non-operating gains in earnings communications, and, if relied upon for distributions or covenant compliance, segregating one-off FX gains from recurring operating cash flow for planning and covenant testing.\n\nstructural_long_term_implications:\n- If the 2024 pattern of negative equity persisted, the company would have continued to display negative ROE despite p ...
#  'profile_used': 'going_concern_screen'}

# %% [markdown]
# ### Step 9: Compare AI Interpretations Across Profiles
#
# This demonstrates the **profile-aware reasoning differences**.

# %%
for profile, outputs in results_by_profile.items():
    interp_list = outputs["ai_interpretation"]
    print(f"\n=== {profile.upper()} ===")
    for record in interp_list:
        print(f"{record['Company']} ({record['Year']}):")
        print(record["interpretation"][:20000], "...\n")
# Out:
# === FULL_DIAGNOSTIC ===
# Kenya Airways (2021):
# -summary:
#     In 2021 Kenya Airways exhibited a distressed financial profile. Revenue had increased year‑on‑year, but the company recorded an operating loss (approximately KSh 6.8 billion) and a net loss (approximately KSh 15.8 billion). Liquidity was acute (current ratio 0.32; quick ratio 0.29), operating profitability was negative (operating margin ≈ -9.7%), and overall profitability was strongly negative (net margin ≈ -22.8%), while balance‑sheet leverage signalled a capital deficit (debt/equity ≈ -2.87). The dominant financial pressures were liquidity and solvency, with profitability weakness materially reinforcing both. The risk profile in 2021 was multi‑dimensional rather than confined to a single axis.
#
# -key_risks:
#     1) Severe short‑term liquidity shortfall
#        • Supporting metrics: current ratio 0.317 and quick ratio 0.291.
#        • Mechanism: These ratios indicated that available current assets covered only a fraction of current liabilities in 2021, creating a high probability of cash‑flow shortfalls to meet near‑term obligations, payroll, and supplier payments without external funding or asset conversion.
#
#     2) Solvency / negative equity and high leverage risk
#        • Supporting metrics: debt/equity ≈ -2.867 (negative equity implied) and negative ROA (≈ -10.31%).
#        • Mechanism: The negative debt/equity ratio reflected an equity deficit relative to liabilities, which in 2021 increased the risk that cumulative losses could constrain the company’s capacity to absorb further shocks, to access capital markets on normal terms, or to support long‑term operations without balance‑sheet repair.
#
#     3) Earnings and operating profitability risk
#        • Supporting metrics: operating margin ≈ -9.69% and net margin ≈ -22.84%; operating loss ≈ KSh 6.8B; net loss ≈ KSh 15.8B.
#        • Mechanism: Negative operating margin indicated that core operations did not generate sufficient contribution to cover operating expenses; the resulting net loss materially eroded equity and strained cash generation, exacerbating both liquidity and solvency pressures.
#
#     4) Interest coverage / debt service vulnerability
#        • Supporting metrics: interest coverage ≈ -0.725.
#        • Mechanism: A negative interest coverage ratio in 2021 signalled that operating earnings were insufficient to cover interest expense, increasing the likelihood of covenant breaches or requirement for debt renegotiation, and raising default risk if funding sources were constrained.
#
#     5) Asset efficiency insufficient to offset losses
#        • Supporting metrics: asset turnover ≈ 0.451 together with ROA ≈ -10.31%.
#        • Mechanism: Moderate asset turnover indicated that asset use generated revenue at a modest rate, but given negative returns on assets the scale of revenue generation was inadequate to produce positive returns after costs, limiting internal remedy capacity.
#
# -period_specific_actions:
#     (All actions are expressed as measures that would have been appropriate during 2021 to address the stated risks.)
#     • To address liquidity shortfall: seek time‑limited committed liquidity facilities or bridge financing and negotiate extensions of short‑term maturities with creditors to reduce immediate cash‑flow mismatch. These measures would have reduced near‑term funding pressure implied by the current and quick ratios.
#     • To address solvency and negative equity: pursue negotiated equity injections (private investors or shareholder recapitalisation) or debt‑for‑equity conversions to reduce nominal leverage and repair the balance sheet that had produced a negative debt/equity ratio.
#     • To address operating losses: implement targeted route and capacity rationalisation tied to unprofitable operations and accelerate cost re‑profiling (labour, leasing, and fuel procurement terms) concentrated on restoring positive operating margin; actions would have been prioritized where they directly reduced the operating loss reported for 2021.
#     • To address interest coverage risk: renegotiate interest terms or seek temporary relief on covenants (payment deferrals or interest capitalisation) to reduce immediate debt service obligations in light of negative interest coverage.
#     • To address asset efficiency and liquidity generation: identify and execute disposal or monetisation of non‑core assets or subsidiaries to generate cash and improve liquidity ratios without relying solely on additional borrowing.
#
# -structural_long_term_implications:
#     • Persistence of negative equity and high leverage would have constrained capital‑raising options and credit terms beyond 2021, making future financing more expensive or conditional on structural remedies (equity or covenant relief). This inference followed directly from the negative debt/equity metric and the 2021 net loss.
#     • Continued negative operating margins would have tended to erode asset base and cash reserves over time absent remedial action, implying that the company’s capacity for organic recovery was limited in 2021 by operating performance (operating margin ≈ -9.7% and negative ROA).
#     • If liquidity measures had remained at 2021 levels, reliance on short‑term external support or asset disposals would have been required repeatedly, producing a structural shift toward more frequent balance‑sheet restructuring rather than standard operating financing.
#     • Conversely, the 2021 gross margin (≈ 41.4%) and moderate asset turnover (≈ 0.45) suggested that revenue‑generating capability existed; therefore, structural improvement in profitability could have been inferable if operating costs were brought into line with that revenue base. This was an inference based on the coexistence of a reasonable gross margin and negative operating margin in 2021.
#
# -contextual_interpretation:
#     • The provided external context (COVID‑19 impacts on travel, constrained international operations, cargo growth supporting revenue in 2021) informed the interpretation by explaining plausible operational drivers for the 2021 revenue change noted in company disclosures; however, the identified risks were primarily metric‑driven in this analysis. Metrics such as the current and quick ratios, negative operating and net margins, negative interest coverage, and negative debt/equity constituted the principal evidence for risk conclusions.
#     • The context amplified the interpretation of liquidity and profitability pressures (for example, suppressed passenger volumes in 2021 could have reduced cash inflows), but no causal claims beyond the structured context were made. All risk statements remained tied to the 2021 financial metrics.
#
# -confidence_notes:
#     • Single‑year snapshot limitation: Analysis relied principally on 2021 ratios and the limited company notes provided; trends across multiple years were not available within the core metric set for rigorous temporal trend testing.
#     • Missing cash‑flow and maturity detail: Operating cash‑flow, free cash‑flow, and the debt maturity schedule were not provided; therefore, precise quantification of cash‑burn duration and refinancing needs could not be performed.
#     • Metric consistency issues: Some provided metrics contained internal inconsistencies (for example, a positive ROE figure alongside a reported net loss and negative debt/equity), which reduced certainty in attributing shareholder‑return dynamics; such inconsistencies were noted and treated as limitations rather than reconciled assumptions.
#     • Contextual constraint: External context supplied was used only as stated; no additional macroeconomic or industry factors were introduced. Structural implications were inferred conservatively and limited to patterns directly supported by the 2021 metrics. ...
#
# Kenya Airways (2022):
# - summary:
#     Kenya Airways’ 2022 financial condition was distressed. Liquidity was acute, solvency metrics indicated a capital-structure failure, and profitability was strongly negative; the dominant financial pressures were liquidity shortfall and solvency (capital) weakness with material contribution from poor profitability and interest-service capacity. The risk profile was multi-dimensional: severe short-term liquidity stress coincided with negative shareholders’ equity and insufficient earnings to cover interest, rather than a single isolated metric.
#
# - key_risks:
#     1) Severe short-term liquidity risk
#        • Supporting metrics: current ratio = 0.3553; quick ratio = 0.3359.
#        • Mechanism: Current assets were substantially lower than current liabilities (current assets were roughly one-third of current liabilities), indicating limited liquid resources to meet near-term obligations. Low quick assets implied that inventories or non-liquid items did not materially improve the short-term position. This liquidity shortfall increased the probability of covenant breaches, forced refinancing, or reliance on emergency short-term funding in 2022.
#     2) Balance-sheet solvency / negative equity risk
#        • Supporting metrics: debt-to-equity = -2.5627; ROE = 0.3558 (mathematically distorted).
#        • Mechanism: The negative debt-to-equity ratio signaled that shareholders’ equity was negative (liabilities exceeded assets). Negative equity reduced the company’s capacity to absorb losses and constrained access to conventional debt and equity markets. The positive ROE figure was a mathematical artefact resulting from negative equity and did not indicate healthy shareholder returns; it therefore misrepresented underlying solvency weakness.
#     3) Earnings and profitability failure
#        • Supporting metrics: gross margin = 31.70%; operating margin = -4.81%; net margin = -32.93%; reported 2022 net loss ≈ KSh 38.2B on revenue ≈ KSh 116B.
#        • Mechanism: While gross margin suggested per-unit margin on revenue, operating margin was negative, indicating operating expenses (and/or scale inefficiencies) eliminated gross profit. The deep negative net margin and large absolute net loss pointed to significant non-operating charges or operating shortfalls that left no retained earnings and worsened equity and cash positions.
#     4) Interest-service and refinancing risk (including FX amplification)
#        • Supporting metrics: interest coverage = -0.1707; asset turnover = 0.6914; ROA = -22.77%.
#        • Mechanism: Negative interest coverage showed that operating profit was insufficient to cover interest expense, implying reliance on additional financing or principal reductions to meet debt costs. The negative ROA indicated assets produced losses rather than returns. Given the contemporaneous external context of 2022 (currency volatility affecting USD-denominated debt and high fuel costs), interest and FX-related cash outflows likely amplified refinancing pressure (context amplified the metric-driven risk).
#
# - period_specific_actions:
#     (Each item describes actions that would have been appropriate in 2022 to address the stated risks; phrased in past tense.)
#     • To address liquidity risk, management would have sought committed short-term liquidity lines or covenant waivers and prioritized conversion of liquid receivables; contemporaneous measures would have included deferral of non-essential capital expenditures and sale-and-leaseback transactions for aircraft to raise immediate cash.
#     • To address solvency/negative-equity risk, a 2022-appropriate action would have included negotiating a balance-sheet restructuring (for example, debt re-profiling, maturity extension, or debt-for-equity conversions) and pursuing a targeted capital injection or rights issue to restore positive equity.
#     • To address profitability shortfalls, actions in 2022 would have included reallocating capacity toward higher-yield domestic and cargo operations (which the structured context identified as recovering/supportive), cutting specific unprofitable international frequencies, and renegotiating supplier and lease contracts to reduce operating expense load.
#     • To address interest-service and FX exposure, it would have been appropriate in 2022 to seek to hedge USD-denominated exposures where feasible, renegotiate the currency composition or covenants of key debt facilities, and to prioritize refinancing of short-dated USD obligations to reduce immediate FX-driven cash pressure.
#
# - structural_long_term_implications:
#     • The combination of negative equity and persistent operating losses in 2022 suggested a structural capital-structure weakness that could persist absent re-capitalization: negative shareholders’ equity materially constrained conventional funding routes and increased reliance on restructuring or exceptional capital support.
#     • The metric pattern (reasonable gross margin but negative operating and net margins) suggested that cost structure or non-operating charges—rather than top-line unit economics alone—were driving losses; if those structural cost elements remained unaddressed, operating performance could have continued to impair cash generation and solvency.
#     • Negative interest coverage indicated a structural mismatch between recurring earnings capacity and fixed financing costs; absent permanent deleveraging or earnings restoration, refinancing risk and higher financing costs could have become enduring features of the company’s capital profile.
#     • The ROE distortion (positive ROE despite a net loss) indicated that conventional profitability ratios were unreliable in 2022 because of negative equity; this structural distortion would have complicated standard investor and lender assessments until equity was restored.
#
# - contextual_interpretation:
#     • The provided structured context (2022: uneven recovery, high fuel costs, currency volatility; industry: domestic recovery faster than international and cargo support) informed the analysis by identifying plausible amplifiers of metric outcomes. Specifically, currency volatility and USD-denominated debt in 2022 were consistent with the observed negative equity and heavy non-operating losses; high fuel costs were consistent with the gap between gross margin and operating margin.
#     • Nevertheless, the conclusions and primary risk identifications were metric-driven: the liquidity, solvency, profitability, and interest-service weaknesses were supported directly by the reported ratios and the 2022 revenue and net-loss figures. Context was used only to explain how external conditions could have amplified those metric-based risks, not to replace or invent additional metric evidence.
#
# - confidence_notes:
#     • Missing financial detail limited granularity: no 2022 cash-flow statement, debt maturity schedule, interest-rate and currency breakdown of debt, or composition of current assets were provided; those items were material to precise liquidity and refinancing timing assessments.
#     • The provided ratios did not disclose absolute balances for current assets/liabilities or the size and timing of interest and principal payments; sensitivity to short-term maturities could not be quantified.
#     • The ROE figure was mathematically unreliable in 2022 because of negative equity; any inference based on ROE alone would have been misleading.
#     • Structural inferences (persistence or resolution of risks) carried uncertainty because they depended on subsequent actions or external changes not specified in the 2022 data. ...
#
# Kenya Airways (2023):
# - summary:
#     Kenya Airways' 2023 financial condition was mixed: operating activities produced a positive operating profit while the overall financial position exhibited material financial stress. The dominant financial pressures in 2023 were solvency and liquidity strains driven by negative equity indications and inadequate short-term coverage; profitability at the net level was weak due to material non-operating losses. The risk profile was multi-dimensional, with solvency shortfalls, acute liquidity constraints and poor net profitability operating together.
#
# - key_risks:
#     1) Solvency / capital impairment
#        • Supporting metrics: debt-to-equity = -2.302; net_margin = -12.93%; roa = -13.07%.
#        • Mechanism: The negative debt/equity ratio indicated an equity base that was zero or negative in 2023, removing the normal capital buffer for creditors and increasing the risk of covenant breaches or inability to absorb additional losses. The company reported a net loss (net_margin negative and negative ROA), which reduced retained capital and exacerbated the capital shortfall signaled by the negative leverage metric.
#     2) Liquidity shortfall
#        • Supporting metrics: current_ratio = 0.419; quick_ratio = 0.396.
#        • Mechanism: Current and quick ratios materially below 1.0 showed that short-term liquid resources were insufficient to meet short-term liabilities in 2023, creating risk of payment stress on suppliers, lessors, and short-term creditors absent external liquidity support.
#     3) Interest-service / cashflow coverage weakness
#        • Supporting metrics: interest_coverage = 0.307; operating_margin = 5.78%; operating profit (company note) ≈ KSh 10.5B but net loss ≈ KSh 22.7B.
#        • Mechanism: Low interest coverage indicated that operating earnings were insufficient to cover interest expense in 2023. Although operating profit existed, the gap between operating profitability and net loss suggested that non-operating items (notably financing and FX losses per company disclosures) drove cashflow pressure on debt service.
#     4) Profitability volatility driven by non-operating exposures
#        • Supporting metrics: gross_margin = 33.88%; operating_margin = 5.78%; net_margin = -12.93%; asset_turnover = 1.01.
#        • Mechanism: Operating-level margins and asset utilization were positive, but the conversion into net profitability failed because of sizable non-operating losses. This pattern indicated earnings volatility arising from exposures outside core operations (for example, financing and FX items noted in company disclosures), producing a material divergence between operating performance and net results.
#
# - period_specific_actions:
#     (Each item describes actions that would have been appropriate to undertake during 2023 to address the named risk.)
#     1) To address solvency / capital impairment: In 2023 it would have been appropriate to seek an equity recapitalisation or formally agreed capital support from owners/official sponsors and to evaluate sale or monetisation of non-core assets to restore positive equity metrics and protect creditor covenants.
#     2) To address liquidity shortfall: In 2023 it would have been appropriate to secure committed short-term liquidity lines (bank or sponsor facilities) and to renegotiate the timing of near-term payables and lease obligations so that current liabilities better matched available liquid assets.
#     3) To address interest-service weakness: In 2023 it would have been appropriate to pursue debt-reprofiling negotiations (maturity extensions and interest rate adjustments) and to prioritise reduction of near-term cash interest through temporary measures agreed with lenders.
#     4) To address profitability volatility from non-operating exposures: In 2023 it would have been appropriate to implement targeted currency risk reductions for USD-denominated obligations (for example, hedging or natural currency matching where feasible) and to isolate and quantify one-off non-operating losses to improve transparency of operating cash generation.
#
# - structural_long_term_implications:
#     • The combination of negative-equity indications and recurring net losses in 2023 implied a structural capital vulnerability: unless equity was restored, the company’s capital structure would have remained fragile, limiting capacity to absorb further shocks and constraining access to market financing.
#     • Persistently low short-term liquidity metrics in 2023 suggested that, without durable funding solutions, operational continuity could have required repeated external support or recurring refinancing, raising long-term financing costs.
#     • The divergence between positive operating performance and negative net profitability in 2023 indicated a structural mismatch between operating cash generation and non-operating exposures (notably financing/FX). If those non-operating exposures had persisted in similar magnitude beyond 2023, the company’s operating improvements would have been insufficient by themselves to eliminate solvency and liquidity risks.
#     • Asset utilisation (asset_turnover ≈ 1.01) and a reasonable gross margin in 2023 implied that operational capacity existed to generate revenue; structurally, the company’s primary constraints in 2023 were financial (capital and financing structure) rather than purely operational.
#
# - contextual_interpretation:
#     • The provided external context for 2023 (airline demand rebound; elevated financing and FX exposure challenges) aligned with the metrics: operating profit emergence and strong revenue recovery in 2023 were consistent with the industry rebound noted in the context, while the net loss and low interest coverage were consistent with elevated financing and FX pressures explicit in the context and company notes.
#     • The principal risks identified were primarily metric-driven (negative debt/equity, low current/quick ratios, low interest coverage, negative net margin). The provided context amplified interpretation of those metrics by explaining plausible channels (post-pandemic demand rebound driving operating profit; elevated financing/FX exposure explaining non-operating losses), but no additional contextual factors beyond those supplied were assumed.
#
# - confidence_notes:
#     • Missing data: The analysis relied on supplied ratios and selected company notes; absolute balance sheet values (cash balances, total debt breakdown by currency and maturity, equity components), detailed cashflow statement items, and the composition of non-operating losses (precise FX loss amounts, one-off items) were not provided.
#     • Metric-scope limitations: A negative debt/equity ratio and a positive ROE (16.7%) coexisted with a net loss; this combination suggested a very small or negative equity denominator that rendered some return-based ratios potentially misleading. The ROE figure should be interpreted with caution given inconsistency with net loss and the negative debt/equity metric.
#     • Contextual constraints: The interpretation used only the explicitly provided external context (macro, industry, company_notes) and did not assume additional macroeconomic or operational conditions.
#     • Structural inference uncertainty: Long-term structural implications were inferred from 2023 metric patterns; such inferences carried uncertainty without multi-year trend data, debt maturity schedules, or confirmed sponsor support details. ...
#
# Kenya Airways (2024):
# summary:
# Kenya Airways reported a financially mixed position in 2024. The company achieved a positive net profit (KSh 5.4B) and an operating profit (KSh 16.6B) on KSh 188B of revenue, but its balance-sheet and short‑term liquidity metrics pointed to pronounced funding stress. The dominant financial pressures in 2024 were liquidity shortfalls and elevated leverage (solvency) with secondary concerns about earnings quality. The risk profile was multi-dimensional: operating performance had improved, but funding structure and reliance on non‑operational gains constrained financial stability.
#
# key_risks:
# 1) Short‑term liquidity risk
#    - Supporting metrics: current ratio = 0.35; quick ratio = 0.32.
#    - Mechanism: The company held materially less current liquid resources than short‑term obligations (current and quick ratios well below 1.0), which created a high probability of cash‑flow timing mismatches for operating and financing payments in 2024.
#
# 2) Solvency / capital structure risk (high leverage and negative equity implications)
#    - Supporting metrics: debt-to-equity = -2.51; return on equity (ROE) = -4.54% (negative).
#    - Mechanism: The negative debt/equity ratio implied equity was subordinated or deficitary relative to liabilities, and ROE was negative despite a net profit, indicating that equity base was impaired in 2024. This capital structure increased sensitivity to creditor actions, covenant breaches, and constrained access to new financing.
#
# 3) Interest service vulnerability
#    - Supporting metrics: interest coverage = 1.49.
#    - Mechanism: Operating earnings before interest and tax covered interest expense by less than 1.5x in 2024, leaving limited buffer to absorb earnings volatility or higher financing costs and increasing the risk of covenant pressure or refinancing stress.
#
# 4) Earnings‑quality risk (dependence on non‑operational FX gains)
#    - Supporting evidence: net profit was achieved in 2024 alongside company disclosures that FX gains materially contributed to the turnaround; net margin = 2.85% vs operating margin = 8.82%.
#    - Mechanism: The narrow net margin relative to operating margin and explicit attribution to FX gains in company notes indicated that a portion of the reported net profit derived from non‑recurring/FX items rather than core operations, creating risk to sustainable profitability if those gains did not recur.
#
# period_specific_actions (actions that would have been appropriate in 2024):
# - To address short‑term liquidity risk, the company would have sought to convert near‑term maturities into longer‑dated facilities or obtain committed revolving credit lines to improve the current ratio and provide liquidity headroom.
# - To address solvency and leverage, the company would have engaged with creditors on debt‑reprofiling measures (maturity extension, amortisation rescheduling, or covenant resets) and explored equity recapitalisation options to reduce the negative debt/equity ratio and restore positive ROE metrics.
# - To reduce interest service vulnerability, the company would have prioritized lowering interest‑bearing liabilities (through negotiated partial repayments, liability conversion where available, or refinancing at lower fixed rates) to improve interest coverage above a conservative buffer.
# - To strengthen earnings quality, the company would have implemented a formal separation of recurring operating results from non‑operational FX items in external disclosures and pursued FX risk‑management measures (e.g., hedging programmes calibrated to the currency composition of liabilities) to limit earnings volatility attributable to exchange movements.
#
# structural_long_term_implications:
# - If the 2024 pattern of negative equity (implied by debt/equity = -2.51) persisted, capital structure weakness could have structurally constrained Kenya Airways’ ability to obtain unsecured or covenant‑light financing, leading to higher funding costs or increased reliance on sponsor/sovereign support.
# - Continued low short‑term liquidity metrics (current ratio and quick ratio <<1) would have risked recurring operational interruptions or forced non‑strategic asset sales to meet obligations, creating a structural mismatch between asset liquidity and liability maturities.
# - The combination of a positive operating margin (8.82%), gross margin ≈32.3%, and asset turnover ≈1.05 in 2024 suggested that core operational efficiency was sufficient to generate operating cash‑flows under normal conditions; however, structural improvement in balance‑sheet metrics would have been required for those operating gains to translate into sustainable shareholder returns given the impaired equity base.
# - Reliance on FX gains to deliver net profitability in 2024 implied that absent recurring FX benefits, sustainable long‑term net margins would need to be supported by continuing operational improvements or permanent capital structure adjustments.
#
# contextual_interpretation:
# - The provided external context (Kenyan shilling strengthening vs USD in 2024; robust passenger and cargo demand; company notes that FX gains drove the turnaround) informed the interpretation by explaining plausible sources of the 2024 net profit and revenue growth. Specifically, the stronger shilling and stated FX gains were consistent with the observed positive net result despite a weak equity base.
# - The primary risk signals remained metric‑driven: liquidity and leverage metrics provided direct evidence of funding stress and solvency weakness. The supplied context amplified the earnings‑quality concern by indicating that part of the profit was non‑operational (FX gains) rather than changing the metric‑based conclusion about balance‑sheet vulnerability.
#
# confidence_notes:
# - The analysis relied on ratio metrics and company‑level summary figures for 2024; detailed balance‑sheet line items (absolute cash and cash equivalents, short‑term debt by maturity, currency composition of debt, equity balance), consolidated cash‑flow statement, and debt covenant details were not provided and limited precision on refinancing and covenant risk assessment.
# - The interest‑coverage measure used a single ratio; sensitivity to interest‑rate changes and future EBITDA projections could not be modelled without forward cash‑flow or forecast data.
# - Earnings‑quality inference referenced company notes about FX gains (provided in the structured context); the magnitude and recurrence of FX gains could not be quantified from the supplied data.
# - Structural inferences (persistence or remediation of risks) were constrained to patterns observable in the 2024 metrics and the supplied context; no projection beyond 2024 was made. ...
#
#
# === SOLVENCY_FOCUS ===
# Kenya Airways (2021):
# - summary:
#     Kenya Airways' 2021 financial condition was weak. Liquidity was acute, solvency metrics signalled material leverage and interest-service strain, and profitability was negative. The dominant financial pressure in 2021 was liquidity-driven but was multi-dimensional, with solvency and profitability also materially impaired. The risk profile appeared multi-dimensional rather than narrowly concentrated.
#
# - key_risks:
#     1. Severe short-term liquidity shortfall
#        • Supporting metrics: current ratio = 0.317 and quick ratio = 0.291.
#        • Financial mechanism: Current and near-cash assets covered substantially less than one third of current liabilities, which indicated an inability to meet short-term obligations from operating or readily liquid assets. That coverage gap would have increased the risk of missed payments, covenant breaches, or forced asset disposals.
#
#     2. Inadequate interest‑cover and high leverage leading to solvency stress
#        • Supporting metrics: interest coverage = -0.725 and debt-to-equity = -2.867.
#        • Financial mechanism: Operating losses produced negative coverage of interest expense, indicating operating cash flows were insufficient to service financing costs. The markedly negative debt-to-equity ratio was consistent with very high leverage or negative equity, which would have constrained access to new credit and raised the probability of creditor-enforced restructuring if losses persisted.
#
#     3. Loss-making operations eroding asset returns and equity
#        • Supporting metrics: operating margin = -9.69%, net margin = -22.84%, return on assets (ROA) = -10.31%.
#        • Financial mechanism: Operating activities generated losses that resulted in negative returns on the asset base and large net losses relative to revenue. Continued operating deficits would have depleted equity and cash reserves, compounding liquidity and solvency pressures.
#
#     4. Moderate asset efficiency with limited ability to offset losses
#        • Supporting metrics: asset turnover = 0.451 and gross margin = 41.39%.
#        • Financial mechanism: While gross margin indicated positive gross profit per unit of revenue, relatively low asset turnover implied modest revenue generation per unit of assets. That combination suggested that gross profitability was being absorbed by operating and financing costs rather than by efficiency gains, limiting available internal funds to reduce leverage or restore liquidity.
#
# - period_specific_actions:
#     (All items stated in past tense as actions that would have been appropriate in 2021.)
#     1. To address liquidity shortfalls, management would have pursued short-term covenant relief and maturity extensions with key creditors and lessors, and sought temporary working-capital facilities or bridge financing to cover near-term cash requirements.
#     2. To address interest‑service and leverage risk, management would have negotiated debt‑reprofiling (maturity extensions and interest capitalisation) and explored partial debt-for-equity conversions or equity injections to improve the debt-to-equity position.
#     3. To address operating losses, management would have accelerated identified cost-reduction measures in the restructuring programme, reduced non-essential operating capacity, and reallocated capacity to higher-margin cargo and Jambojet operations that were already supporting revenue.
#     4. To preserve cash, management would have deferred non-critical capital expenditures and pursued asset disposals of non-core items to raise liquidity and lower leverage.
#
# - structural_long_term_implications:
#     • If the 2021 pattern of low current asset coverage and negative interest coverage had persisted, the company would have faced progressively greater insolvency risk, including constrained financing access and increasing probability of creditor-led restructuring. This inference followed from the contemporaneous inability to service interest and the very low short-term liquidity coverage.
#     • The combination of a positive gross margin (41.39%) and negative operating and net margins implied that fixed operating costs, other operating charges, or financing costs were the proximate drivers of losses. Structurally, that pattern suggested that improvements in operating cost structure or reductions in financing burden would have been required to convert gross profit into positive operating and net results.
#     • Moderate asset turnover (0.451) implied limited revenue generation capacity per unit of assets; structurally, sustained low asset efficiency would have made internal deleveraging slower and increased reliance on external capital to restore solvency.
#     • The provided metrics indicated a multi-factor structural fragility (liquidity, leverage, and operating profitability). The persistence or resolution of those structural issues would have depended on the company’s ability in subsequent periods to convert gross profitability into operating profitability and to reduce debt or raise equity.
#
# - contextual_interpretation:
#     • The provided structured external context (2021: uneven global recovery, travel restrictions, ~65% lower passenger volumes, cargo support) was used to contextualise why operational revenues and passenger demand were suppressed in 2021. That context amplified the interpretation of the liquidity and profitability metrics because demand weakness in 2021 was consistent with constrained cash generation.
#     • The company-specific note that revenue rose ~33% to KSh 70.2B while net loss was ~KSh 15.8B was consistent with the metric-driven conclusion that revenue recovery in 2021 had not restored operating or net profitability.
#     • Overall, the principal conclusions remained metric-driven; the external context explained plausible demand-side pressure that likely amplified the observed liquidity and profitability stresses but did not replace the direct evidence from the financial ratios.
#
# - confidence_notes:
#     • The analysis was limited to the supplied 2021 ratios and structured contextual notes. Key missing items included the full 2021 balance sheet and income-statement line items, cash-flow statement (operating, investing, financing), the maturity schedule of liabilities, currency composition of debt, and contingent liabilities—each of which materially affected liquidity and solvency assessment.
#     • There was an internal data inconsistency: the supplied ROE (≈19.25%) conflicted with the reported net loss for 2021 (net loss ≈ KSh 15.8B). That inconsistency limited confidence in equity‑based ratio interpretations and suggested one or more inputs may have been anomalous or calculated on a non-standard basis.
#     • Structural inferences were constrained by single‑year snapshot characteristics; trend-based certainty required multi-year cash‑flow and balance‑sheet trajectories which were not the primary inputs for the 2021-only analysis. ...
#
# Kenya Airways (2022):
# summary:
# - Kenya Airways' 2022 financial condition was distressed. The company exhibited acute short-term liquidity insufficiency and balance-sheet solvency stress while recording large operating and net losses. The dominant financial pressures were solvency (negative equity and excessive leverage) and liquidity (very low current and quick ratios), with profitability weakness reinforcing those pressures. The risk profile was multi-dimensional rather than concentrated in a single metric.
#
# key_risks:
# 1) Balance-sheet solvency risk (most severe)
#    - Evidence: debt-to-equity was -2.5627, indicating negative shareholders' equity (liabilities exceeded equity).
#    - Mechanism: Negative equity reduced the company's capital buffer to absorb further losses and limited balance-sheet capacity to support new financing; lenders and counterparties typically treated negative equity as heightened default risk and potential covenant breach.
#
# 2) Acute short-term liquidity shortfall
#    - Evidence: current ratio was 0.3553 and quick ratio was 0.3359.
#    - Mechanism: Current assets were substantially insufficient to cover current liabilities, raising the risk that the company would have faced difficulty meeting maturing obligations (payables, short-term debt, lease payments) without refinancing, asset disposals, or third-party support.
#
# 3) Earnings weakness and interest-servicing insufficiency
#    - Evidence: operating margin was -0.0481 (operating loss) and net margin was -0.3293 (large net loss); interest coverage was -0.1707.
#    - Mechanism: Operating losses and a large net loss reduced internal cash generation; negative interest coverage signaled that operating income was insufficient to cover interest expense, increasing the probability of refinancing stress and higher financing costs.
#
# 4) Distorted return metrics masking underlying performance
#    - Evidence: return on assets (ROA) was -0.2277 (negative) while return on equity (ROE) was 0.3558 (positive).
#    - Mechanism: The combination of negative ROA and positive ROE was consistent with negative equity driving a mathematically positive ROE despite operational losses. This created a risk of misleading profitability signals to stakeholders and complicated assessment of true economic performance.
#
# period_specific_actions (actions that would have been appropriate in 2022):
# - To address liquidity shortfall: accelerate collection of receivables and suspend non-critical payments, and pursue short-term secured liquidity facilities or debtor-in-possession style arrangements that specifically targeted maturing obligations identified in the 2022 balance sheet.
# - To address solvency/leverage: negotiate restructuring of debt maturities (including conversion of near-term debt into longer maturities or equity-linked instruments) with major creditors and lessors to reduce immediate leverage and relieve covenant pressure evident from negative equity.
# - To address interest-servicing insufficiency: seek temporary interest-payment waivers or interest capitalization agreements with lenders to improve interest coverage metrics in the 2022 reporting period.
# - To address earnings losses: implement route/network rationalization and capacity adjustments tied to underperforming assets (consistent with Project Kifaru objectives noted in company disclosures) to reduce operating losses reflected in the negative operating margin.
# - To address reporting and stakeholder clarity: provide reconciliations and disclosures explaining the ROE/ROA divergence and the composition of negative equity so that creditors and investors could have properly assessed economic performance in 2022.
#
# structural_long_term_implications:
# - Persistence of negative equity implied a structural solvency vulnerability: if losses at the scale shown by the 2022 net margin were sustained, the capital deficit would have remained a recurring constraint on financing flexibility and on the ability to absorb shocks.
# - Very low liquidity ratios in 2022 suggested ongoing refinancing and rollover risk; absent material reductions in short-term liabilities or material improvements in operating cash flow, liquidity pressure was likely to persist into subsequent periods.
# - Negative interest coverage in 2022 implied a structural mismatch between earnings capacity and finance costs; unless operating profitability improved or finance costs were reduced via restructuring, interest-servicing stress would have continued to depress free cash flow and increase the cost of capital.
# - The ROA/ROE divergence in 2022 indicated that equity-based performance measures were unreliable as standalone indicators; structural reliance on accounting or capital adjustments (e.g., equity write-downs or creditor-for-equity swaps) would have been necessary before ROE could be interpreted as reflecting genuine profitability.
#
# contextual_interpretation:
# - The provided external context for 2022 (uneven recovery, high fuel costs, and currency volatility; domestic demand recovering faster; cargo and Jambojet contribution; Project Kifaru ongoing) was used to interpret how operating and financing pressures may have been amplified.
#   • The metric-driven assessment remained primary: the insolvency, liquidity shortfall, and earnings weakness were evident from 2022 ratios and were the basis for conclusions.
#   • The external context amplified those metric-based risks: high fuel costs and currency volatility in 2022 (explicitly provided) plausibly increased operating expenses and the burden on USD-denominated debt, making the observed negative margins and weak interest coverage more consequential for liquidity and solvency in that year.
#   • The context also explained revenue-side mitigants noted in company disclosures (cargo and Jambojet supporting revenue and Project Kifaru as an ongoing restructuring effort), but these were treated as explanatory background rather than primary evidence.
#
# confidence_notes:
# - The analysis was based on provided 2022 ratios and structured contextual notes; missing detailed financial statements limited granularity:
#   • Absent a full balance-sheet schedule and maturity profile, specific short-term liability amounts and currency composition were not available to quantify rollover risk precisely.
#   • Cash-flow statement details (operating cash flow, capex, financing cash flows) were not provided, restricting precise assessment of cash burn and refinancing needs.
#   • No creditor/covenant schedule was available; therefore, covenant breach probability and specific creditor actions could not be determined.
#   • The ROE/ROA divergence suggested negative equity interacting with negative net income; without line-item equity movements and comprehensive notes, the precise accounting drivers could not be fully reconciled.
# - Structural inferences were constrained to logical implications of the 2022 metrics; projections of future outcomes were not made beyond inferable persistence or escalation of observed metric patterns. ...
#
# Kenya Airways (2023):
# - summary:
#     Kenya Airways' 2023 financial condition was strained. Operating performance had returned to positive territory, but overall financial health in 2023 was dominated by solvency and liquidity pressures driven by financing and non-operating losses. The risk profile was multi-dimensional: severe solvency/leverage weakness and interest-service stress were the dominant pressures, accompanied by acute liquidity shortfalls and a profitability mismatch between operating results and net income.
#
# - key_risks:
#     1) Solvency and negative-equity geometry (most severe)
#        • Supporting metrics: debt_equity = -2.302; roe = 0.167; roa = -0.1307.
#        • Mechanism: The negative debt/equity ratio signalled that shareholders' equity was negative (or that the ratio produced a negative value), creating an accounting geometry where return-on-equity appeared positive while return-on-assets was negative. Negative equity reduced the company's financial buffer against losses and implied elevated default risk on creditor claims because capital absorbency was impaired.
#     2) Interest-service incapacity
#        • Supporting metrics: interest_coverage = 0.307.
#        • Mechanism: Interest coverage materially below 1.0 indicated operating income in 2023 was insufficient to meet interest expense by a large margin, increasing the probability of covenant breaches, higher refinancing costs, or forced restructuring of debt if lenders demanded remediation.
#     3) Acute liquidity shortage
#        • Supporting metrics: current_ratio = 0.419; quick_ratio = 0.396.
#        • Mechanism: Both short-term liquidity ratios were substantially below 1.0, indicating that current assets were insufficient to cover current liabilities. This created short-term funding pressure for working capital and near-term cash obligations independent of operating profitability.
#     4) Profitability mismatch driven by non-operating items
#        • Supporting metrics: operating_margin = 0.0578 (positive); net_margin = -0.1293 (negative); roa = -0.1307.
#        • Mechanism: A positive operating margin concurrent with a negative net margin and negative ROA showed that non-operating expenses (for example, financing costs or FX-related losses) exceeded operating profit in 2023, converting operational gains into a significant net loss and weakening asset returns.
#     5) Financial-statement interpretive risk (covenant and stakeholder signalling)
#        • Supporting metrics: inconsistency among roe = 0.167, net_margin = -0.1293, and debt_equity = -2.302.
#        • Mechanism: The combination of a positive ROE amid a net loss and negative debt/equity could have caused misinterpretation by creditors and investors and increased the likelihood of covenant triggers or rating pressures, because headline profitability metrics did not align with capital adequacy metrics.
#
# - period_specific_actions:
#     (Each item describes actions that would have been appropriate in 2023 to address the associated risk.)
#     1) To address solvency and negative-equity geometry, a 2023 capital recapitalisation or equity injection would have been appropriate to restore positive shareholders' equity and re-establish a conventional debt/equity relationship.
#     2) To address interest-service incapacity, 2023 refinancing or restructuring of high-cost or near-term debt obligations would have been appropriate, including negotiating maturity extensions or interest-rate/repayment profile changes to reduce immediate interest outflows.
#     3) To address acute liquidity shortages, securing secured short‑term facilities or bridge financing in 2023 and prioritising conversion of non-core current assets to cash would have been appropriate to cover current liabilities and reduce rollover risk.
#     4) To address the profitability mismatch from non-operating losses, targeting a 2023 reduction in net financing outflows would have been appropriate—examples included pursuing creditor waivers, converting short-term debt into longer-term instruments in 2023, or using identified cash resources to lower high-cost obligations.
#     5) To reduce interpretive and covenant risk, obtaining covenant waivers or formal forbearance agreements during 2023 and improving disclosure around the drivers of negative equity and FX/financing losses would have been appropriate to limit contract breaches and investor uncertainty.
#
# ...
#   - implication: Elevated financing costs and constrained access to capital
#     • The combination of high leverage (negative debt_equity) and negative interest_coverage implied that, absent corrective measures, the company would likely have faced higher borrowing costs or restricted access to refinancing in subsequent periods.
#   - implication: Operating model required re‑calibration for sustainable margins
#     • Gross_margin (31.70%) indicated that gross profitability before operating costs was positive, but operating_margin was negative; this pattern suggested that structural improvements needed to focus on reducing operating overhead or improving revenue mix to restore operating profitability over time.
#   - implication: Financial ratios were partially distorted by capital structure
#     • The anomalous positive roe amid large net losses reflected a structural reporting distortion caused by negative equity; this distortion reduced the usefulness of some return metrics for monitoring long-term recovery without balance-sheet repair.
#
# contextual_interpretation:
#   • The provided external context (2022: uneven recovery, high fuel costs, currency volatility; company notes: revenue ~KSh116B, net loss ~KSh38.2B, Project Kifaru ongoing, cargo and Jambojet support) was considered in interpretation.
#   • The contextual information explained potential operational and FX pressures present in 2022 that could have amplified the metric-driven risks (for example, currency volatility increasing USD-denominated debt burdens and high fuel costs pressuring margins), but the identification of risks remained primarily driven by the financial metrics provided.
#   • Company-specific notes (revenue recovery and project initiatives) were acknowledged as partial mitigation factors for top-line support, but they did not eliminate the metric evidence of liquidity shortfall, negative operating and net margins, and impaired capital structure in 2022.
#
# confidence_notes:
#   • Missing or limited data: The analysis relied on ratio-level metrics without access to the full 2022 financial statements (balance-sheet itemisation, cash-flow statement, interest expense breakdown, debt maturity schedule, and detailed segment results). This constrained precision in assessing timing and magnitude of cash shortfalls and required interventions.
#   • Metric-scope limitations: Some ratios (notably roe) were subject to distortion because of negative equity implied by debt_equity; such ratios were treated cautiously and identified as potentially misleading.
#   • Contextual constraints: The analysis used only the supplied external context and company notes; no additional macroeconomic or company information was assumed or introduced.
#   • Structural inference uncertainty: Projections about structural evolution were limited to inferences directly supported by the 2022 metrics; longer-term trajectories could not be confirmed without later-period financials and cash-flow outcomes. ...
#
# Kenya Airways (2023):
# summary:
# The company’s 2023 financial condition was distressed and multi-dimensional. Liquidity was impaired (current and quick ratios well below 1.0), solvency showed structural strain (negative debt-to-equity signalling negative or deficient equity capital), and profitability was mixed (positive operating margin but a material net loss). The dominant financial pressures in 2023 were liquidity shortfall and solvency/leverage stress, with profitability and interest-service capacity amplifying those pressures. The risk profile was multi-dimensional rather than concentrated in a single metric.
#
# key_risks:
# 1. Liquidity shortfall
#    - Evidence: current ratio = 0.419; quick ratio = 0.396.
#    - Mechanism: Current assets covered less than half of current liabilities in 2023, indicating an inability to meet short-term obligations from liquid resources. This created risk of covenant breaches, forced asset disposals, or reliance on emergency short-term funding.
#
# 2. Solvency / negative equity and high leverage
#    - Evidence: debt_equity = -2.302 (negative value).
#    - Mechanism: The negative debt-to-equity ratio indicated that liabilities exceeded shareholders’ equity (negative or impaired equity capital) in 2023. This condition increased creditor seniority risk, reduced loss-absorption capacity, and raised the probability that further losses would erode going-concern buffers.
#
# 3. Interest and financing strain
#    - Evidence: interest_coverage = 0.307.
#    - Mechanism: Operating income covered only about 0.31x of interest expense in 2023, showing that operating earnings were insufficient to service financing costs. This heightened refinancing risk and increased likelihood of additional financing costs or restructuring of debt terms.
#
# 4. Profitability volatility due to non-operating losses
#    - Evidence: operating_margin = 0.0578 (positive) while net_margin = -0.1293 (negative); roa = -0.1307 (negative).
#    - Mechanism: The company generated positive operating profits in 2023 but recorded a substantial net loss after non-operating items, producing negative returns on assets. Non-operating losses (for example, financing costs, FX losses or other below-operating-line items reflected in the net margin and ROA) materially undone operating profitability, contributing to negative comprehensive results and worsening equity.
#
# period_specific_actions:
# - To address liquidity shortfall in 2023, management would have pursued extension of near-term maturities or negotiated covenant relaxations with lenders to reduce immediate cash outflows and avoid forced asset sales in the reporting year.
# - To mitigate solvency pressure in 2023, management would have sought an equity recapitalization or structured subordinated financing during the year to restore positive net equity and improve the debt-to-equity position.
# - To relieve interest-service strain in 2023, management would have restructured high-cost debt or converted short-term borrowings to longer-maturity instruments to reduce interest expense recognized within the year and improve interest coverage.
# - To contain profitability volatility in 2023, management would have hedged or otherwise reduced identifiable non-operating exposures disclosed for that year (for example, currency or market exposures reported in the 2023 notes) to prevent further erosion of net income that year.
#
# structural_long_term_implications:
# - The combination of a low current ratio and negative debt-to-equity implied that, absent remediation in 2023, solvency pressures could persist beyond the reporting year because negative equity reduced capacity to absorb subsequent losses. Metric patterns suggested a structural funding mismatch: operating performance (positive operating margin and asset_turnover ~1.01) indicated operational competitiveness, but recurring below-the-line losses and poor liquidity pointed to a structural financing problem rather than purely operational failure.
# - Persistently weak interest coverage in 2023 implied that future earnings would need to either increase materially or financing costs decline for interest-service risk to abate; otherwise, leverage would likely remain elevated and creditor remedies or refinancing at higher cost could be required.
# - The metric profile in 2023 implied that any recovery in operating performance alone would not have guaranteed balance-sheet stabilization unless non-operating losses and capital structure deficits were addressed.
#
# contextual_interpretation:
# - The provided structured context (notably that 2023 saw a passenger rebound and that FX exposure and elevated financing pressures were cited) informed interpretation by aligning with metric evidence: positive operating margin and asset turnover were consistent with improved operational demand in 2023, while the negative net margin and solvency indicators were consistent with material non-operating losses and financing/FX impacts noted in the context.
# - Overall, the identified risks were primarily metric-driven (liquidity ratios, leverage, and coverage metrics supplied the principal evidence). The external context amplified the plausibility of specific mechanisms (for example, FX and financing pressures as drivers of the negative net margin) but did not replace the metric-based risk assessment.
#
# confidence_notes:
# - The analysis relied on ratio-level data only; detailed absolute amounts (cash balances, current liabilities breakdown, maturity schedule of debt, and equity components) were not provided and limited granularity.
# - The set of ratios contained internal inconsistency (ROE = 0.1671 despite net_margin = -0.1293 and negative ROA), which reduced confidence in interpretation of equity returns and required treating ROE with caution.
# - There was no access to the full 2023 notes that would identify the composition of non-operating items (e.g., realized FX losses, one-off impairments, or restructuring costs), which limited the ability to quantify drivers of the net loss.
# - No post-2023 remediation outcomes were provided; structural inferences about persistence of risks assumed only the metric patterns observable in 2023 and did not incorporate events after the reporting year. ...
#
# Kenya Airways (2024):
# summary:
# - In 2024 Kenya Airways reported an operating recovery and a small net profit; however, its financial condition remained characterised by acute short-term liquidity constraints and impaired capital structure. Liquidity metrics were severely depressed, solvency indicators reflected negative equity, and interest-bearing obligations had limited coverage. The dominant financial pressures in the reporting year were liquidity and solvency; profitability improvement appeared present but concentrated and partially non-operational. Risk was multi-dimensional but concentrated around liquidity/solvency rather than broad-based operating failure.
#
# key_risks:
# 1) Acute short-term liquidity risk
#    - Evidence: current ratio 0.35 and quick ratio 0.323.
#    - Mechanism: Current and quick ratios substantially below 1.0 indicated that, in 2024, current liabilities materially exceeded readily liquid assets. This imbalance created a risk that the company would have been unable to meet near-term obligations from existing liquid resources, increasing dependence on refinancing, covenant waivers, or asset conversion.
#
# 2) Capital structure / solvency risk (negative equity)
#    - Evidence: debt-to-equity ratio -2.51 and return on equity (ROE) -4.54%.
#    - Mechanism: The negative debt-to-equity ratio indicated that shareholders’ equity was a net deficit in 2024; simultaneously a negative ROE despite positive net income signalled that book equity remained negative. These metrics implied constrained solvency and potential limits to accessing debt or equity markets without balance-sheet remediation.
#
# 3) Interest-service vulnerability
#    - Evidence: interest coverage ratio 1.49.
#    - Mechanism: EBIT provided only about 1.5 times the interest expense in 2024, giving a narrow margin to absorb earnings declines or interest rate increases. Low interest coverage heightened default and refinancing risk on interest-bearing liabilities if operating performance had weakened.
#
# 4) Earnings composition / potential earnings volatility
#    - Evidence: operating margin 8.82% versus net margin 2.85%; company notes indicated FX gains materially contributed to the net profit in 2024.
#    - Mechanism: The gap between operating and net margins, together with disclosure that FX gains drove the turnaround, indicated that a material portion of the reported net profit arose from non-operating items. This suggested that underlying net earnings were thin and could be sensitive to reversals of non-operating gains or to FX movements.
#
# period_specific_actions:
# - Appropriate 2024 actions to address liquidity risk included securing or extending committed short-term credit facilities and re-profiling immediate maturities; implementing targeted working-capital measures such as invoice factoring or accelerated receivable collections tied to specific routes; and negotiating short-term supplier payment terms or confirmed trade credit to reduce near-term cash outflows.
# - Appropriate 2024 actions to address negative equity included arranging capital injections or equity conversion alternatives, and pursuing targeted non-core asset disposals with proceeds earmarked for restoring positive net equity.
# - Appropriate 2024 actions to address interest-service vulnerability included renegotiating debt covenants and interest terms to extend maturities or reduce near-term interest expense, and prioritising use of positive operating cash flows to reduce the most expensive short-term borrowings.
# - Appropriate 2024 actions to address earnings composition risk included disclosing the extent of FX and non-operating gains in earnings communications, and, if relied upon for distributions or covenant compliance, segregating one-off FX gains from recurring operating cash flow for planning and covenant testing.
#
# structural_long_term_implications:
# - If the 2024 pattern of negative equity persisted, the company would have continued to display negative ROE despite periodic net profits, constraining conventional equity financing and increasing reliance on creditor concessions or non-standard capital measures.
# - Continued low liquidity ratios could have led to recurring refinancing dependence; frequent reliance on short-term relief would have increased refinancing exposure and possibly raised effective financing costs over time.
# - Interest coverage near 1.5 in 2024 implied limited resilience to earnings shocks; absent structural margin improvement or debt reprofiling, the company’s ability to service debt sustainably could have remained fragile.
# - The divergence between operating profitability (positive operating margin and reasonable asset turnover) and low net margin suggested that operational performance alone was not sufficient to resolve balance-sheet deficits; therefore, structural repair would have required explicit balance-sheet actions rather than relying solely on operating improvements.
#
# contextual_interpretation:
# - The provided external context (robust 2024 industry demand, strengthened Kenyan shilling, and company disclosures that FX gains contributed to the turnaround) informed interpretation by explaining plausible drivers of the 2024 revenue and net-profit outcomes. Specifically, the context supported the observation that non-operating FX gains materially affected 2024 net income.
# - Despite that contextual support for revenue and one-off gains, the principal risks identified (liquidity shortfall, negative equity, limited interest coverage) were primarily metric-driven: they derived from balance-sheet and coverage ratios rather than from contextual factors. The context amplified interpretation of earnings composition risk but did not negate the solvency and liquidity signals present in the financial metrics.
#
# confidence_notes:
# - The analysis was limited to ratios and structured notes provided for 2024; material missing information included the 2024 cash flow statement, detailed maturity schedule of debt, cash and short-term investment balances, contingent liabilities, and notes on related-party financing.
# - Ratios represented a single reporting year and did not reveal intra-year cash flow timing, concentration of maturities, or subsequent covenant waivers that could have materially affected actual near-term default risk.
# - The structured external context was used only as provided; no additional macroeconomic or industry developments beyond that context were assumed.
# - Structural inferences about persistence or future trajectory were constrained by the absence of multi-year trend data and by lack of visibility on management actions taken after the 2024 reporting date. ...

# %%
import pandas as pd

# List to collect all interpretations
all_records = []

for profile, outputs in results_by_profile.items():
    for record in outputs["ai_interpretation"]:
        all_records.append({
            "Profile": profile,
            "Company": record["Company"],
            "Year": record["Year"],
            "Interpretation": record["interpretation"]
        })

# Convert to DataFrame
df_interp = pd.DataFrame(all_records)

# Save to CSV
df_interp.to_csv("afap_ai_interpretations.csv", index=False, encoding="utf-8")

print("✅ CSV saved as 'afap_ai_interpretations.csv'")
# Out:
# ✅ CSV saved as 'afap_ai_interpretations.csv'
